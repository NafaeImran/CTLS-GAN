# %% [markdown]
# # Federated Learning Experiments: FedAvg vs SignGuard
#
# **10 Clients | CIFAR-10**
#
# ## Tests:
# | Test | Description |
# |------|-------------|
# | Test 1 | Non-IID run — all clients get Non-IID CIFAR-10 data |
# | Test 2 | Attack run — Clients 1,2,5 have sythetic data added in to create distribution skew  |
#
#
# Both **FedAvg** and **SignGuard** are run on each test for comparison.

# %% [markdown]
# ## Install Dependencies
#
# ---

# %%
# !pip install torch torchvision numpy matplotlib scikit-learn seaborn -q

# %% [markdown]
# ## Imports & Config

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Subset
import torchvision
import torchvision.transforms as transforms
import numpy as np
import matplotlib.pyplot as plt
from typing import List, Tuple, Dict, Optional
from collections import OrderedDict
from functools import reduce
import os, warnings, logging

warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", message=".*upfirdn2d.*")
warnings.filterwarnings("ignore", message=".*bias_act.*")

NUM_CLIENTS = 10
NUM_ROUNDS = 50
LOCAL_EPOCHS= 2
BATCH_SIZE= 256
LEARNING_RATE= 0.001
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

ATTACK_CLIENT_ID   = [1, 5, 2]
GAN_WARMUP_ROUNDS = 0
BETA =0.12# gans ramp up rate
SEED=67 

n_top = 2  # CHANGE THIS to your desired n everywhere

print(f'Device: {DEVICE}')
# Out:
# Device: cuda

# %% [markdown]
# ## CNN Model (CIFAR-10)

# %%
class CifarCNN(nn.Module):
    def __init__(self):
        super(CifarCNN, self).__init__()
        self.conv_block = nn.Sequential(
            nn.Conv2d(3, 32, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(32, 64, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(64, 64, 3, padding=1),
            nn.ReLU()
        )
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(64 * 8 * 8, 256),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, 10)
        )

    def forward(self, x):
        return self.classifier(self.conv_block(x))


def get_parameters(model):
    return [val.cpu().numpy() for val in model.state_dict().values()]


def set_parameters(model, parameters):
    params_dict = zip(model.state_dict().keys(), parameters)
    state_dict = OrderedDict({k: torch.tensor(v) for k, v in params_dict})
    model.load_state_dict(state_dict, strict=True)


print('Model defined. Parameter count:',
      sum(p.numel() for p in CifarCNN().parameters()))
# Out:
# Model defined. Parameter count: 1107722

# %% [markdown]
# ## Data Loading Setup

# %%
from collections import Counter

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

CIFAR10_TRAIN = torchvision.datasets.CIFAR10(
    root='./data', train=True, download=True, transform=transform
)
CIFAR10_TEST = torchvision.datasets.CIFAR10(
    root='./data', train=False, download=True, transform=transform
)

CLASSES = ['airplane','automobile','bird','cat','deer',
           'dog','frog','horse','ship','truck']

def get_all_non_iid_partitions(dataset, num_clients, alpha=0.5):
    np.random.seed(SEED)
    labels = np.array([label for _, label in dataset])
    num_classes = len(np.unique(labels))
    client_indices = [[] for _ in range(num_clients)]
    for k in range(num_classes):
        idx_k = np.where(labels == k)[0]
        np.random.shuffle(idx_k)
        proportions = np.random.dirichlet([alpha] * num_clients)
        splits = (np.cumsum(proportions) * len(idx_k)).astype(int)[:-1]
        for i, chunk in enumerate(np.split(idx_k, splits)):
            client_indices[i].append(chunk)
    return [
        Subset(dataset, np.concatenate(client_indices[i]).tolist())
        for i in range(num_clients)
    ]

ALL_PARTITIONS = get_all_non_iid_partitions(CIFAR10_TRAIN, NUM_CLIENTS, alpha=0.5)

def load_client_data(client_id: int) -> Tuple[DataLoader, DataLoader]:
    train_subset = ALL_PARTITIONS[client_id]
    print(f'  [Client {client_id}]: {len(train_subset)} samples')
    train_loader = DataLoader(train_subset, batch_size=BATCH_SIZE, shuffle=True)
    test_loader  = DataLoader(CIFAR10_TEST,  batch_size=BATCH_SIZE, shuffle=False)
    return train_loader, test_loader

def get_top_n_classes(subset, n=1):
    labels = [subset.dataset.targets[i] for i in subset.indices]
    return [cls for cls, _ in Counter(labels).most_common(n)]

print('Data utilities ready.')
print(f'CIFAR-10 train size: {len(CIFAR10_TRAIN)} | test size: {len(CIFAR10_TEST)}')
# Out:
# 100%|██████████| 170M/170M [02:47<00:00, 1.02MB/s]
# Data utilities ready.
# CIFAR-10 train size: 50000 | test size: 10000

# %% [markdown]
# ## Pre-trained GANS Setup

# %%
# !git clone https://github.com/NVlabs/stylegan2-ada-pytorch.git
import pickle, requests, os,sys,contextlib
sys.path.insert(0, './stylegan2-ada-pytorch')
stylegan_path = "/kaggle/working/stylegan2-ada-pytorch"

if stylegan_path not in sys.path:
    sys.path.append(stylegan_path)


weights_url = 'https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/cifar10.pkl'
weights_path = 'cifar10.pkl'

if not os.path.exists(weights_path):
    print('Downloading StyleGAN2-ADA CIFAR-10 weights...')
    r = requests.get(weights_url, stream=True)
    with open(weights_path, 'wb') as f:
        for chunk in r.iter_content(chunk_size=8192):
            f.write(chunk)
    print('Done.')

with contextlib.redirect_stderr(open(os.devnull, 'w')), \
     contextlib.redirect_stdout(open(os.devnull, 'w')):
    with open(weights_path, 'rb') as f:
        data = pickle.load(f)
    stylegan_G = data['G_ema'].to(DEVICE)

print('StyleGAN2-ADA generator loaded.')
print(f'  z_dim: {stylegan_G.z_dim} | c_dim: {stylegan_G.c_dim} | img resolution: {stylegan_G.img_resolution}')



def stylegan_generate(class_idx, n_images, truncation_psi=0.7):
    with contextlib.redirect_stderr(open(os.devnull, 'w')), \
         contextlib.redirect_stdout(open(os.devnull, 'w')):
        with torch.no_grad():
            z = torch.randn(n_images, stylegan_G.z_dim).to(DEVICE)
            c = torch.zeros(n_images, stylegan_G.c_dim).to(DEVICE)
            c[:, class_idx] = 1.0
            imgs = stylegan_G(z, c, truncation_psi=truncation_psi)
            imgs = (imgs * 0.5 + 0.5).clamp(0, 1)
            imgs = (imgs - 0.5) / 0.5
    return imgs
warnings.filterwarnings("ignore", category=UserWarning, module="torch_utils")
# Out:
# Cloning into 'stylegan2-ada-pytorch'...
# remote: Enumerating objects: 131, done.
# remote: Counting objects: 100% (2/2), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 131 (delta 0), reused 0 (delta 0), pack-reused 129 (from 2)
# Receiving objects: 100% (131/131), 1.13 MiB | 7.88 MiB/s, done.
# Resolving deltas: 100% (57/57), done.
# Downloading StyleGAN2-ADA CIFAR-10 weights...
# Done.
# StyleGAN2-ADA generator loaded.
#   z_dim: 512 | c_dim: 10 | img resolution: 32

# %% [markdown]
# ## Conditioning on Client classes

# %%
topn = get_top_n_classes(ALL_PARTITIONS[ATTACK_CLIENT_ID[0]], n=n_top)
print(f'Attacker top-{n_top} classes: {[CLASSES[c] for c in topn]} {topn}')
print('StyleGAN2-ADA will generate only these classes during attack.')
# Out:
# Attacker top-2 classes: ['cat', 'frog'] [3, 6]
# StyleGAN2-ADA will generate only these classes during attack.

# %% [markdown]
# ## GANS Visualization

# %%
import torchvision.utils as vutils
fig, axes = plt.subplots(1, n_top, figsize=(6 * n_top, 5))
axes = [axes] if n_top == 1 else list(axes)

for ax, cls in zip(axes, topn):
    imgs = stylegan_generate(cls, 16, truncation_psi=0.7)
    imgs = (imgs * 0.5 + 0.5).clamp(0, 1)
    grid = vutils.make_grid(imgs, nrow=4, padding=2)
    ax.imshow(grid.permute(1, 2, 0).cpu())
    ax.set_title(f'StyleGAN2 generated: {CLASSES[cls]}', fontweight='bold')
    ax.axis('off')

plt.suptitle('Attack Image Quality Check', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Training and Evaluation Setup

# %%
def train_one_round(model, train_loader, epochs,current_round, client_id, mode='non-iid', topn_classes=None):
    model.to(DEVICE)
    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
    criterion = nn.CrossEntropyLoss()

    is_malicious = (mode == 'attack' and client_id in ATTACK_CLIENT_ID)



    model.train()
    for epoch in range(epochs):
        for images, labels in train_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            batch_size = images.size(0)

            if is_malicious and topn_classes is not None:
              if current_round > GAN_WARMUP_ROUNDS:
                  skew_ratio = min(0.3 + BETA  * current_round, 0.9)
                  n_skew = int(batch_size * skew_ratio)
                  n_real = batch_size - n_skew

                  idx = torch.randint(0, len(topn_classes), (1,)).item()
                  chosen_class = topn_classes[idx]

                  with torch.no_grad():
                      gan_images = stylegan_generate(chosen_class, n_skew).detach()
                  gan_labels = torch.full((n_skew,), chosen_class, dtype=torch.long, device=DEVICE)

                  images = torch.cat([images[:n_real], gan_images], dim=0)
                  labels = torch.cat([labels[:n_real], gan_labels], dim=0)

            optimizer.zero_grad()
            outputs = model(images)
            loss    = criterion(outputs, labels)
            loss.backward()
            optimizer.step()


def evaluate_model(model, test_loader):
    model.to(DEVICE)
    criterion = nn.CrossEntropyLoss()
    model.eval()
    total_loss, correct, total = 0.0, 0, 0
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = model(images)
            total_loss += criterion(outputs, labels).item()
            predicted = outputs.argmax(dim=1)
            correct += (predicted == labels).sum().item()
            total   += labels.size(0)
    return total_loss / len(test_loader), correct / total

# %% [markdown]
# ## FL Client Class

# %%
class FLClient:
    """Plain federated client — no Flower dependency."""

    def __init__(self, client_id: int, mode: str = 'non-iid'):
        self.client_id   = client_id
        self.mode        = mode
        self.model       = CifarCNN()
        self.train_loader, self.test_loader = load_client_data(client_id)

        import sys
        stylegan_path = "/kaggle/working/stylegan2-ada-pytorch"
        if stylegan_path not in sys.path:
            sys.path.insert(0, stylegan_path)

        # Pre-compute top-n classes for the malicious client
        if mode == 'attack' and client_id in ATTACK_CLIENT_ID:
            self.topn_classes = get_top_n_classes(ALL_PARTITIONS[ATTACK_CLIENT_ID[0]], n=n_top)
            print(f'  [Client {client_id}] Top-{n_top} classes for GAN: '
                  f'{[CLASSES[c] for c in self.topn_classes]} {self.topn_classes}')
        else:
            self.topn_classes = None

    def get_parameters(self):
        return get_parameters(self.model)

    def fit(self, parameters, local_epochs=LOCAL_EPOCHS, current_round=0):
        set_parameters(self.model, parameters)
        train_one_round(self.model, self.train_loader,
                        local_epochs, current_round,
                        self.client_id, self.mode, self.topn_classes)
        return (get_parameters(self.model),
                len(self.train_loader.dataset),
                {'client_id': self.client_id, 'mode': self.mode})

    def evaluate(self, parameters):
        set_parameters(self.model, parameters)
        loss, accuracy = evaluate_model(self.model, self.test_loader)
        return (float(loss),
                len(self.test_loader.dataset),
                {'accuracy': float(accuracy), 'client_id': self.client_id})


print('FLClient class defined.')
# Out:
# FLClient class defined.

# %% [markdown]
# ## Divergence calculation

# %%
divergence_history = {}   

def l2_divergence(local_params, global_params):
    """L2 norm of (local − global) flattened across all weight tensors."""
    return float(np.sqrt(sum(
        np.sum((lp - gp) ** 2)
        for lp, gp in zip(local_params, global_params)
    )))

def cosine_divergence(local_params, global_params):
    """
    Cosine similarity between flattened local and global weight vectors.
    Returns similarity in [-1, 1] — closer to 1 = less diverged.
    """
    local_vec  = np.concatenate([p.ravel() for p in local_params])
    global_vec = np.concatenate([p.ravel() for p in global_params])

    dot    = np.dot(local_vec, global_vec)
    norm_l = np.linalg.norm(local_vec)
    norm_g = np.linalg.norm(global_vec)

    denom = norm_l * norm_g
    if denom < 1e-10:
        return 0.0
    return float(dot / denom)

def compute_divergence(local_params, global_params):
    local_flat  = np.concatenate([p.ravel() for p in local_params])
    global_flat = np.concatenate([p.ravel() for p in global_params])

    l2 = float(np.sqrt(np.sum((local_flat - global_flat) ** 2)))

    denom = np.linalg.norm(local_flat) * np.linalg.norm(global_flat)
    cosine = float(1.0 - np.dot(local_flat, global_flat) / denom) if denom > 1e-10 else 0.0

    return {'l2': l2, 'cosine': cosine}

def add_divergence_tracking(strategy, div_log):
    strategy._div_log = div_log
    return strategy

def add_param_snapshots(strategy, snapshot_log, every_n=10):
    strategy._snapshot_log = snapshot_log
    strategy._snapshot_every_n = every_n
    return strategy

# %% [markdown]
# ## FedAvg Setup

# %%
class FedAvgStrategy:
    """Modular sequential FedAvg — no Flower dependency."""

    def __init__(self, round_metrics: list):
        self.round_metrics  = round_metrics
        self._global_params = None
        self._div_log         = {}
        self._snapshot_log    = {}
        self._snapshot_every_n = 10

    def aggregate_fit(self, server_round: int, results: list) -> list:
        """
        results: list of (params, num_examples, metrics)
        Returns aggregated global params (plain numpy list).
        """
        if not results:
            return self._global_params

        total_samples = sum(n for _, n, _ in results)
        aggregated = [
            sum(params[i] * n / total_samples for params, n, _ in results)
            for i in range(len(results[0][0]))
        ]
        self._global_params = aggregated
        return aggregated

    def aggregate_evaluate(self, server_round: int, results: list):
        """
        results: list of (loss, num_examples, metrics)
        """
        if not results:
            return None, {}

        total_samples = sum(n for _, n, _ in results)
        weighted_acc  = sum(m['accuracy'] * n for _, n, m in results) / total_samples
        weighted_loss = sum(loss * n for loss, n, _ in results) / total_samples

        self.round_metrics.append({
            'round': server_round,
            'accuracy': weighted_acc,
            'loss': weighted_loss
        })

        print(f'  [FedAvg] Round {server_round} — '
              f'Acc: {weighted_acc:.4f} | Loss: {weighted_loss:.4f}')

        return weighted_loss, {'accuracy': weighted_acc}


def build_fedavg_strategy(round_metrics: list) -> FedAvgStrategy:
    return FedAvgStrategy(round_metrics)


print('FedAvg strategy builder defined.')
# Out:
# FedAvg strategy builder defined.

# %% [markdown]
# ## SignGuard Setup

# %%
from sklearn.cluster import KMeans, DBSCAN, MeanShift, estimate_bandwidth
import math

class SignGuardStrategy:
    """SignGuard aggregation adapted for parameter-space FL."""

    def __init__(self, round_metrics: list):
        self.round_metrics     = round_metrics
        self._global_params    = None
        self._div_log          = {}
        self._snapshot_log     = {}
        self._snapshot_every_n = 10

    def aggregate_fit(self, server_round: int, results: list) -> list:
        if not results:
            return self._global_params

        all_params  = [params for params, _, _ in results]
        num_clients = len(all_params)

        flat = [
            torch.tensor(np.concatenate([p.ravel() for p in params]), dtype=torch.float32)
            for params in all_params
        ]
        grads = torch.stack(flat, dim=0)
        grads[torch.isnan(grads)] = 0

        all_set = set(range(num_clients))

        grad_l2norm = torch.norm(grads, dim=1).cpu().numpy()
        norm_med    = np.median(grad_l2norm)
        benign_idx1 = all_set
        benign_idx1 = benign_idx1.intersection(
            set(int(i) for i in np.argwhere(grad_l2norm > 0.1 * norm_med))
        )
        benign_idx1 = benign_idx1.intersection(
            set(int(i) for i in np.argwhere(grad_l2norm < 3.0 * norm_med))
        )

        num_param  = grads.shape[1]
        num_spars  = max(1, int(0.1 * num_param))
        benign_idx2 = all_set

        idx       = torch.randint(0, max(1, num_param - num_spars), (1,)).item()
        gradss    = grads[:, idx:(idx + num_spars)]
        sign_grads = torch.sign(gradss)

        sign_pos  = sign_grads.eq( 1.0).sum(dim=1, dtype=torch.float32) / num_spars
        sign_zero = sign_grads.eq( 0.0).sum(dim=1, dtype=torch.float32) / num_spars
        sign_neg  = sign_grads.eq(-1.0).sum(dim=1, dtype=torch.float32) / num_spars

        pos_feat  = sign_pos  / (sign_pos.max()  + 1e-8)
        zero_feat = sign_zero / (sign_zero.max() + 1e-8)
        neg_feat  = sign_neg  / (sign_neg.max()  + 1e-8)

        sign_feat = torch.stack([pos_feat, zero_feat, neg_feat], dim=1).cpu().numpy()

        try:
            bandwidth = estimate_bandwidth(sign_feat, quantile=0.5, n_samples=min(50, num_clients))
            if bandwidth <= 0:
                bandwidth = 0.5
            ms     = MeanShift(bandwidth=bandwidth, bin_seeding=True, cluster_all=False)
            ms.fit(sign_feat)
            labels        = ms.labels_
            labels_unique = np.unique(labels)
            n_cluster     = len(labels_unique) - (1 if -1 in labels_unique else 0)
            if n_cluster == 0:
                benign_class = 0
            else:
                num_class    = [np.sum(labels == i) for i in range(n_cluster)]
                benign_class = int(np.argmax(num_class))
            benign_idx2 = benign_idx2.intersection(
                set(int(i) for i in np.argwhere(labels == benign_class))
            )
        except Exception:
            benign_idx2 = all_set

        benign_idx = list(benign_idx2.intersection(benign_idx1))
        if not benign_idx:
            benign_idx = list(all_set) 

        grad_norm        = torch.norm(grads, dim=1).reshape(-1, 1)
        norm_clip        = grad_norm.median(dim=0)[0].item()
        grad_norm_clipped = torch.clamp(grad_norm, 0, norm_clip)
        grads_clip       = (grads / (grad_norm + 1e-8)) * grad_norm_clipped

        global_flat = grads_clip[benign_idx].mean(dim=0).cpu().numpy()

        print(f'\n  [SignGuard] Round {server_round} — '
              f'{len(benign_idx)}/{num_clients} clients trusted')
        print(f'  [SignGuard] Trusted clients: {sorted(benign_idx)}')

        if self._global_params is None:
            self._global_params = [
                np.mean([p[i] for p in all_params], axis=0)
                for i in range(len(all_params[0]))
            ]

        aggregated = []
        ptr = 0
        for ref_p in self._global_params:
            numel = int(np.prod(ref_p.shape))
            aggregated.append(global_flat[ptr:ptr + numel].reshape(ref_p.shape))
            ptr += numel

        self._global_params = aggregated
        return aggregated

    def aggregate_evaluate(self, server_round: int, results: list):
        if not results:
            return None, {}
        total_samples = sum(n for _, n, _ in results)
        weighted_acc  = sum(m['accuracy'] * n for _, n, m in results) / total_samples
        weighted_loss = sum(loss * n for loss, n, _ in results) / total_samples
        self.round_metrics.append({
            'round':    server_round,
            'accuracy': weighted_acc,
            'loss':     weighted_loss
        })
        print(f'  [SignGuard] Round {server_round} — '
              f'Acc: {weighted_acc:.4f} | Loss: {weighted_loss:.4f}')
        return weighted_loss, {'accuracy': weighted_acc}


def build_signguard_strategy(round_metrics: list) -> SignGuardStrategy:
    return SignGuardStrategy(round_metrics=round_metrics)

print('SignGuard strategy defined.')
# Out:
# SignGuard strategy defined.

# %% [markdown]
# ## Simulation Runner

# %%
def run_simulation(test_name: str,
                   mode: str,
                   strategy_name: str,
                   strategy) -> None:
    

    print(f'\n{"="*60}')
    print(f' {test_name} | Strategy: {strategy_name} | Mode: {mode}')
    print(f'{"="*60}')

    clients = [FLClient(client_id=cid, mode=mode) for cid in range(NUM_CLIENTS)]

    global_params = clients[0].get_parameters()
    strategy._global_params = [p.copy() for p in global_params]

    div_log      = getattr(strategy, '_div_log',         {})
    snapshot_log = getattr(strategy, '_snapshot_log',    {})
    every_n      = getattr(strategy, '_snapshot_every_n', 10)

    for server_round in range(1, NUM_ROUNDS + 1):

        global_snap_before = [p.copy() for p in global_params]

        fit_results = []
        for client in clients:
            params, n_samples, metrics = client.fit(
                global_params,
                local_epochs=LOCAL_EPOCHS,
                current_round=server_round
            )
            fit_results.append((params, n_samples, metrics))

        round_divs = {}
        for (local_params, _, meta) in fit_results:
            cid = meta.get('client_id', -1)
            round_divs[cid] = compute_divergence(local_params, global_snap_before)
        div_log[server_round] = round_divs

  
        global_params = strategy.aggregate_fit(server_round, fit_results)


        if server_round % every_n == 0:
            snapshot_log[server_round] = [p.copy() for p in global_params]

        
        eval_results = []
        for client in clients:
            loss, n_samples, metrics = client.evaluate(global_params)
            eval_results.append((loss, n_samples, metrics))

        strategy.aggregate_evaluate(server_round, eval_results)


print('Simulation runner defined.')
# Out:
# Simulation runner defined.

# %% [markdown]
# ## Run All Tests
#
# > **This is the main execution cell.**
# > Runs 8 simulations total: 4 tests × 2 strategies.
# > Results are stored in `all_results` for plotting.

# %%
all_results        = {}
divergence_history = {}
snapshots          = {}
final_params       = {}

    

TESTS = [
    ('Test 1  - Non-iid',   'non-iid'),
    ('Test 2  - Attack',   'attack'),
    


]


for test_name, mode in TESTS:
    all_results[test_name]        = {}
    divergence_history[test_name] = {}
    snapshots[test_name]          = {}
    final_params[test_name]       = {}

    for strategy_name in ['FedAvg', 'SignGuard']:
        metrics      = []
        div_log      = {}
        snapshot_log = {}

        divergence_history[test_name][strategy_name] = div_log
        snapshots[test_name][strategy_name]          = snapshot_log

        if strategy_name == 'FedAvg':
            strategy = build_fedavg_strategy(metrics)
        else:
            strategy = build_signguard_strategy(metrics)

        add_divergence_tracking(strategy, div_log)
        add_param_snapshots(strategy, snapshot_log, every_n=10)

        run_simulation(test_name, mode, strategy_name, strategy)

        all_results[test_name][strategy_name]  = metrics
        final_params[test_name][strategy_name] = strategy._global_params

print('\nAll simulations complete!')
# Out:
# ============================================================
#  Test 1  - Non-iid | Strategy: FedAvg | Mode: non-iid
# ============================================================
#   [Client 0]: 7505 samples
#   [Client 1]: 3766 samples
#   [Client 2]: 2587 samples
#   [Client 3]: 5760 samples
#   [Client 4]: 5691 samples
#   [Client 5]: 7494 samples
#   [Client 6]: 2628 samples
#   [Client 7]: 4624 samples
#   [Client 8]: 5996 samples
#   [Client 9]: 3949 samples
#   [FedAvg] Round 1 — Acc: 0.2828 | Loss: 2.1236
#   [FedAvg] Round 2 — Acc: 0.3952 | Loss: 1.6878
#   [FedAvg] Round 3 — Acc: 0.4391 | Loss: 1.5513
#   [FedAvg] Round 4 — Acc: 0.4820 | Loss: 1.4485
#   [FedAvg] Round 5 — Acc: 0.5039 | Loss: 1.3755
#   [FedAvg] Round 6 — Acc: 0.5363 | Loss: 1.3045
#   [FedAvg] Round 7 — Acc: 0.5524 | Loss: 1.2474
#   [FedAvg] Round 8 — Acc: 0.5730 | Loss: 1.1988
#   [FedAvg] Round 9 — Acc: 0.5875 | Loss: 1.1572
#   [FedAvg] Round 10 — Acc: 0.5999 | Loss: 1.1293
#   [FedAvg] Round 11 — Acc: 0.6103 | Loss: 1.0916
#   [FedAvg] Round 12 — Acc: 0.6243 | Loss: 1.0482
#   [FedAvg] Round 13 — Acc: 0.6312 | Loss: 1.0333
#   [FedAvg] Round 14 — Acc: 0.6385 | Loss: 1.0026
#   [FedAvg] Round 15 — Acc: 0.6496 | Loss: 0.9725
#   [FedAvg] Round 16 — Acc: 0.6561 | Loss: 0.9611
#   [FedAvg] Round 17 — Acc: 0.6638 | Loss: 0.9469
#   [FedAvg] Round 18 — Acc: 0.6743 | Loss: 0.9174
#   [FedAvg] Round 19 — Acc: 0.6734 | Loss: 0.9081
#   [FedAvg] Round 20 — Acc: 0.6796 | Loss: 0.8980
#   [FedAvg] Round 21 — Acc: 0.6860 | Loss: 0.8822
#   [FedAvg] Round 22 — Acc: 0.6899 | Loss: 0.8762
#   [FedAvg] Round 23 — Acc: 0.6916 | Loss: 0.8777
#   [FedAvg] Round 24 — Acc: 0.6994 | Loss: 0.8534
#   [FedAvg] Round 25 — Acc: 0.7038 | Loss: 0.8517
#   [FedAvg] Round 26 — Acc: 0.7027 | Loss: 0.8477
#   [FedAvg] Round 27 — Acc: 0.7076 | Loss: 0.8441
#   [FedAvg] Round 28 — Acc: 0.7106 | Loss: 0.8395
#   [FedAvg] Round 29 — Acc: 0.7117 | Loss: 0.8327
#   [FedAvg] Round 30 — Acc: 0.7108 | Loss: 0.8425
#   [FedAvg] Round 31 — Acc: 0.7129 | Loss: 0.8396
#   [FedAvg] Round 32 — Acc: 0.7160 | Loss: 0.8362
#   [FedAvg] Round 33 — Acc: 0.7153 | Loss: 0.8378
#   [FedAvg] Round 34 — Acc: 0.7168 | Loss: 0.8429
#   [FedAvg] Round 35 — Acc: 0.7197 | Loss: 0.8433
#   [FedAvg] Round 36 — Acc: 0.7208 | Loss: 0.8508
#   [FedAvg] Round 37 — Acc: 0.7209 | Loss: 0.8551
#   [FedAvg] Round 38 — Acc: 0.7224 | Loss: 0.8610
#   [FedAvg] Round 39 — Acc: 0.7241 | Loss: 0.8672
#   [FedAvg] Round 40 — Acc: 0.7205 | Loss: 0.8703
#   [FedAvg] Round 41 — Acc: 0.7239 | Loss: 0.8862
#   [FedAvg] Round 42 — Acc: 0.7238 | Loss: 0.8848
#   [FedAvg] Round 43 — Acc: 0.7248 | Loss: 0.8906
#   [FedAvg] Round 44 — Acc: 0.7261 | Loss: 0.8945
#   [FedAvg] Round 45 — Acc: 0.7265 | Loss: 0.9060
#   [FedAvg] Round 46 — Acc: 0.7253 | Loss: 0.9177
#   [FedAvg] Round 47 — Acc: 0.7254 | Loss: 0.9267
#   [FedAvg] Round 48 — Acc: 0.7236 | Loss: 0.9351
#   [FedAvg] Round 49 — Acc: 0.7268 | Loss: 0.9406
#   [FedAvg] Round 50 — Acc: 0.7278 | Loss: 0.9641
#
# ============================================================
#  Test 1  - Non-iid | Strategy: SignGuard | Mode: non-iid
# ============================================================
#   [Client 0]: 7505 samples
#   [Client 1]: 3766 samples
#   [Client 2]: 2587 samples
#   [Client 3]: 5760 samples
#   [Client 4]: 5691 samples
#   [Client 5]: 7494 samples
#   [Client 6]: 2628 samples
#   [Client 7]: 4624 samples
#   [Client 8]: 5996 samples
#   [Client 9]: 3949 samples
#
#   [SignGuard] Round 1 — 5/10 clients trusted
#   [SignGuard] Trusted clients: [1, 4, 5, 7, 8]
#   [SignGuard] Round 1 — Acc: 0.2382 | Loss: 2.1190
#
#   [SignGuard] Round 2 — 6/10 clients trusted
#   [SignGuard] Trusted clients: [0, 1, 4, 6, 7, 9]
#   [SignGuard] Round 2 — Acc: 0.3344 | Loss: 1.7735
#
#   [SignGuard] Round 3 — 5/10 clients trusted
#   [SignGuard] Trusted clients: [3, 4, 6, 7, 9]
#   [SignGuard] Round 3 — Acc: 0.3356 | Loss: 1.7321
#
#   [SignGuard] Round 4 — 6/10 clients trusted
#   [SignGuard] Trusted clients: [1, 2, 4, 5, 8, 9]
#   [SignGuard] Round 4 — Acc: 0.4037 | Loss: 1.5726
#
#   [SignGuard] Round 5 — 5/10 clients trusted
#   [SignGuard] Trusted clients: [1, 4, 6, 7, 8]
#   [SignGuard] Round 5 — Acc: 0.4191 | Loss: 1.5989
#
#   [SignGuard] Round 6 — 7/10 clients trusted
#   [SignGuard] Trusted clients: [1, 2, 4, 5, 6, 7, 9]
#   [SignGuard] Round 6 — Acc: 0.4676 | Loss: 1.4489
#
#   [SignGuard] Round 7 — 7/10 clients trusted
#   [SignGuard] Trusted clients: [1, 2, 3, 4, 6, 7, 8]
#   [SignGuard] Round 7 — Acc: 0.4554 | Loss: 1.4539
#
#   [SignGuard] Round 8 — 8/10 clients trusted
#   [SignGuard] Trusted clients: [1, 2, 4, 5, 6, 7, 8, 9]
#   [SignGuard] Round 8 — Acc: 0.5030 | Loss: 1.3569
#
#   [SignGuard] Round 9 — 6/10 clients trusted
#   [SignGuard] Trusted clients: [1, 2, 4, 6, 7, 9]
#   [SignGuard] Round 9 — Acc: 0.4779 | Loss: 1.4060
#
#   [SignGuard] Round 10 — 7/10 clients trusted
#   [SignGuard] Trusted clients: [2, 4, 5, 6, 7, 8, 9]
#   [SignGuard] Round 10 — Acc: 0.5344 | Loss: 1.2970
#
#   [SignGuard] Round 11 — 5/10 clients trusted
#   [SignGuard] Trusted clients: [0, 2, 3, 4, 6]
#   [SignGuard] Round 11 — Acc: 0.5207 | Loss: 1.2630
#
#   [SignGuard] Round 12 — 7/10 clients trusted
#   [SignGuard] Trusted clients: [0, 1, 3, 4, 6, 7, 8]
#   [SignGuard] Round 12 — Acc: 0.5442 | Loss: 1.2186
#
#   [SignGuard] Round 13 — 7/10 clients trusted
#   [SignGuard] Trusted clients: [1, 2, 3, 4, 5, 6, 9]
#   [SignGuard] Round 13 — Acc: 0.5463 | Loss: 1.2373
#
#   [SignGuard] Round 14 — 8/10 clients trusted
#   [SignGuard] Trusted clients: [1, 2, 3, 4, 5, 6, 7, 9]
#   [SignGuard] Round 14 — Acc: 0.5815 | Loss: 1.1607
#
#   [SignGuard] Round 15 — 8/10 clients trusted
#   [SignGuard] Trusted clients: [0, 1, 2, 5, 6, 7, 8, 9]
#   [SignGuard] Round 15 — Acc: 0.6064 | Loss: 1.0942
#
#   [SignGuard] Round 16 — 7/10 clients trusted
#   [SignGuard] Trusted clients: [1, 2, 3, 4, 6, 7, 8]
#   [SignGuard] Round 16 — Acc: 0.5817 | Loss: 1.1392
#
#   [SignGuard] Round 17 — 8/10 clients trusted
#   [SignGuard] Trusted clients: [0, 1, 2, 3, 4, 7, 8, 9]
#   [SignGuard] Round 17 — Acc: 0.6109 | Loss: 1.0647
#
#   [SignGuard] Round 18 — 6/10 clients trusted
#   [SignGuard] Trusted clients: [0, 4, 6, 7, 8, 9]
#   [SignGuard] Round 18 — Acc: 0.6009 | Loss: 1.1063
#
#   [SignGuard] Round 19 — 7/10 clients trusted
#   [SignGuard] Trusted clients: [1, 2, 3, 4, 5, 6, 7]
#   [SignGuard] Round 19 — Acc: 0.6097 | Loss: 1.0756
#
#   [SignGuard] Round 20 — 6/10 clients trusted
#   [SignGuard] Trusted clients: [3, 4, 5, 6, 8, 9]
#   [SignGuard] Round 20 — Acc: 0.6341 | Loss: 1.0283
#
#   [SignGuard] Round 21 — 6/10 clients trusted
#   [SignGuard] Trusted clients: [1, 4, 6, 7, 8, 9]
#   [SignGuard] Round 21 — Acc: 0.6067 | Loss: 1.0895
#
#   [SignGuard] Round 22 — 7/10 clients trusted
#   [SignGuard] Trusted clients: [1, 2, 3, 4, 7, 8, 9]
#   [SignGuard] Round 22 — Acc: 0.6261 | Loss: 1.0354
#
#   [SignGuard] Round 23 — 7/10 clients trusted
#   [SignGuard] Trusted clients: [0, 1, 4, 6, 7, 8, 9]
#   [SignGuard] Round 23 — Acc: 0.6294 | Loss: 1.0326
#
#   [SignGuard] Round 24 — 8/10 clients trusted
#   [SignGuard] Trusted clients: [0, 1, 3, 4, 6, 7, 8, 9]
#   [SignGuard] Round 24 — Acc: 0.6503 | Loss: 0.9640
#
#   [SignGuard] Round 25 — 9/10 clients trusted
#   [SignGuard] Trusted clients: [0, 1, 2, 3, 4, 6, 7, 8, 9]
#   [SignGuard] Round 25 — Acc: 0.6577 | Loss: 0.9538
#
#   [SignGuard] Round 26 — 8/10 clients trusted
#   [SignGuard] Trusted clients: [0, 1, 2, 3, 4, 6, 8, 9]
#   [SignGuard] Round 26 — Acc: 0.6634 | Loss: 0.9431
#
#   [SignGuard] Round 27 — 6/10 clients trusted
#   [SignGuard] Trusted clients: [0, 4, 5, 6, 8, 9]
#   [SignGuard] Round 27 — Acc: 0.6597 | Loss: 0.9499
#
#   [SignGuard] Round 28 — 7/10 clients trusted
#   [SignGuard] Trusted clients: [0, 3, 4, 6, 7, 8, 9]
#   [SignGuard] Round 28 — Acc: 0.6671 | Loss: 0.9305
#
#   [SignGuard] Round 29 — 6/10 clients trusted
#   [SignGuard] Trusted clients: [0, 2, 3, 6, 7, 8]
#   [SignGuard] Round 29 — Acc: 0.6618 | Loss: 0.9430
#
#   [SignGuard] Round 30 — 7/10 clients trusted
#   [SignGuard] Trusted clients: [1, 3, 4, 5, 6, 7, 9]
#   [SignGuard] Round 30 — Acc: 0.6777 | Loss: 0.9170
#
#   [SignGuard] Round 31 — 5/10 clients trusted
#   [SignGuard] Trusted clients: [1, 2, 3, 6, 7]
#   [SignGuard] Round 31 — Acc: 0.6464 | Loss: 1.0284
#
#   [SignGuard] Round 32 — 6/10 clients trusted
#   [SignGuard] Trusted clients: [1, 2, 3, 6, 8, 9]
#   [SignGuard] Round 32 — Acc: 0.6574 | Loss: 0.9716
#
#   [SignGuard] Round 33 — 7/10 clients trusted
#   [SignGuard] Trusted clients: [1, 2, 4, 6, 7, 8, 9]
#   [SignGuard] Round 33 — Acc: 0.6730 | Loss: 0.9598
#
#   [SignGuard] Round 34 — 5/10 clients trusted
#   [SignGuard] Trusted clients: [1, 6, 7, 8, 9]
#   [SignGuard] Round 34 — Acc: 0.6515 | Loss: 1.0473
#
#   [SignGuard] Round 35 — 6/10 clients trusted
#   [SignGuard] Trusted clients: [1, 2, 3, 4, 6, 7]
#   [SignGuard] Round 35 — Acc: 0.6684 | Loss: 0.9806
#
#   [SignGuard] Round 36 — 6/10 clients trusted
#   [SignGuard] Trusted clients: [2, 3, 4, 5, 6, 7]
#   [SignGuard] Round 36 — Acc: 0.6905 | Loss: 0.9065
#
#   [SignGuard] Round 37 — 5/10 clients trusted
#   [SignGuard] Trusted clients: [0, 2, 6, 7, 8]
#   [SignGuard] Round 37 — Acc: 0.6729 | Loss: 0.9460
#
#   [SignGuard] Round 38 — 7/10 clients trusted
#   [SignGuard] Trusted clients: [0, 2, 3, 6, 7, 8, 9]
#   [SignGuard] Round 38 — Acc: 0.6903 | Loss: 0.9125
#
#   [SignGuard] Round 39 — 8/10 clients trusted
#   [SignGuard] Trusted clients: [0, 1, 2, 3, 4, 6, 8, 9]
#   [SignGuard] Round 39 — Acc: 0.7040 | Loss: 0.8610
#
#   [SignGuard] Round 40 — 7/10 clients trusted
#   [SignGuard] Trusted clients: [0, 3, 4, 5, 6, 7, 9]
#   [SignGuard] Round 40 — Acc: 0.7059 | Loss: 0.8594
#
#   [SignGuard] Round 41 — 5/10 clients trusted
#   [SignGuard] Trusted clients: [0, 4, 7, 8, 9]
#   [SignGuard] Round 41 — Acc: 0.6885 | Loss: 0.9158
#
#   [SignGuard] Round 42 — 7/10 clients trusted
#   [SignGuard] Trusted clients: [0, 1, 3, 4, 5, 6, 7]
#   [SignGuard] Round 42 — Acc: 0.7053 | Loss: 0.8779
#
#   [SignGuard] Round 43 — 6/10 clients trusted
#   [SignGuard] Trusted clients: [3, 4, 5, 6, 7, 8]
#   [SignGuard] Round 43 — Acc: 0.7113 | Loss: 0.8575
#
#   [SignGuard] Round 44 — 8/10 clients trusted
#   [SignGuard] Trusted clients: [0, 1, 2, 3, 6, 7, 8, 9]
#   [SignGuard] Round 44 — Acc: 0.7014 | Loss: 0.8962
#
#   [SignGuard] Round 45 — 6/10 clients trusted
#   [SignGuard] Trusted clients: [0, 3, 4, 5, 6, 9]
#   [SignGuard] Round 45 — Acc: 0.7047 | Loss: 0.8924
#
#   [SignGuard] Round 46 — 7/10 clients trusted
#   [SignGuard] Trusted clients: [1, 3, 4, 5, 6, 7, 9]
#   [SignGuard] Round 46 — Acc: 0.7079 | Loss: 0.9077
#
#   [SignGuard] Round 47 — 6/10 clients trusted
#   [SignGuard] Trusted clients: [1, 2, 3, 4, 8, 9]
#   [SignGuard] Round 47 — Acc: 0.7076 | Loss: 0.9122
#
#   [SignGuard] Round 48 — 6/10 clients trusted
#   [SignGuard] Trusted clients: [0, 1, 3, 4, 5, 9]
#   [SignGuard] Round 48 — Acc: 0.7072 | Loss: 0.8804
#
#   [SignGuard] Round 49 — 7/10 clients trusted
#   [SignGuard] Trusted clients: [1, 3, 4, 5, 6, 7, 9]
#   [SignGuard] Round 49 — Acc: 0.7156 | Loss: 0.8939
#
#   [SignGuard] Round 50 — 4/10 clients trusted
#   [SignGuard] Trusted clients: [0, 4, 5, 6]
#   [SignGuard] Round 50 — Acc: 0.6625 | Loss: 1.0946
#
# ============================================================
#  Test 2  - Attack | Strategy: FedAvg | Mode: attack
# ============================================================
#   [Client 0]: 7505 samples
#   [Client 1]: 3766 samples
#   [Client 1] Top-2 classes for GAN: ['cat', 'frog'] [3, 6]
#   [Client 2]: 2587 samples
#   [Client 2] Top-2 classes for GAN: ['cat', 'frog'] [3, 6]
#   [Client 3]: 5760 samples
#   [Client 4]: 5691 samples
#   [Client 5]: 7494 samples
#   [Client 5] Top-2 classes for GAN: ['cat', 'frog'] [3, 6]
#   [Client 6]: 2628 samples
#   [Client 7]: 4624 samples
#   [Client 8]: 5996 samples
#   [Client 9]: 3949 samples
#   [FedAvg] Round 1 — Acc: 0.2222 | Loss: 2.1417
#   [FedAvg] Round 2 — Acc: 0.3623 | Loss: 1.7792
#   [FedAvg] Round 3 — Acc: 0.4051 | Loss: 1.6452
#   [FedAvg] Round 4 — Acc: 0.4509 | Loss: 1.5103
#   [FedAvg] Round 5 — Acc: 0.4485 | Loss: 1.5077
#   [FedAvg] Round 6 — Acc: 0.4642 | Loss: 1.4668
#   [FedAvg] Round 7 — Acc: 0.4713 | Loss: 1.4132
#   [FedAvg] Round 8 — Acc: 0.4835 | Loss: 1.3912
#   [FedAvg] Round 9 — Acc: 0.4893 | Loss: 1.3928
#   [FedAvg] Round 10 — Acc: 0.5271 | Loss: 1.2745
#   [FedAvg] Round 11 — Acc: 0.5323 | Loss: 1.2602
#   [FedAvg] Round 12 — Acc: 0.5486 | Loss: 1.2241
#   [FedAvg] Round 13 — Acc: 0.5651 | Loss: 1.1845
#   [FedAvg] Round 14 — Acc: 0.5561 | Loss: 1.2074
#   [FedAvg] Round 15 — Acc: 0.5723 | Loss: 1.1633
#   [FedAvg] Round 16 — Acc: 0.5936 | Loss: 1.1085
#   [FedAvg] Round 17 — Acc: 0.5954 | Loss: 1.1083
#   [FedAvg] Round 18 — Acc: 0.6071 | Loss: 1.0763
#   [FedAvg] Round 19 — Acc: 0.6071 | Loss: 1.0788
#   [FedAvg] Round 20 — Acc: 0.6168 | Loss: 1.0557
#   [FedAvg] Round 21 — Acc: 0.6209 | Loss: 1.0397
#   [FedAvg] Round 22 — Acc: 0.6164 | Loss: 1.0510
#   [FedAvg] Round 23 — Acc: 0.6222 | Loss: 1.0425
#   [FedAvg] Round 24 — Acc: 0.6251 | Loss: 1.0428
#   [FedAvg] Round 25 — Acc: 0.6399 | Loss: 0.9999
#   [FedAvg] Round 26 — Acc: 0.6323 | Loss: 1.0214
#   [FedAvg] Round 27 — Acc: 0.6467 | Loss: 0.9911
#   [FedAvg] Round 28 — Acc: 0.6467 | Loss: 0.9927
#   [FedAvg] Round 29 — Acc: 0.6469 | Loss: 0.9865
#   [FedAvg] Round 30 — Acc: 0.6649 | Loss: 0.9587
#   [FedAvg] Round 31 — Acc: 0.6528 | Loss: 0.9902
#   [FedAvg] Round 32 — Acc: 0.6642 | Loss: 0.9661
#   [FedAvg] Round 33 — Acc: 0.6593 | Loss: 0.9903
#   [FedAvg] Round 34 — Acc: 0.6630 | Loss: 0.9995
#   [FedAvg] Round 35 — Acc: 0.6635 | Loss: 0.9989
#   [FedAvg] Round 36 — Acc: 0.6678 | Loss: 0.9790
#   [FedAvg] Round 37 — Acc: 0.6684 | Loss: 0.9886
#   [FedAvg] Round 38 — Acc: 0.6734 | Loss: 0.9691
#   [FedAvg] Round 39 — Acc: 0.6599 | Loss: 1.0287
#   [FedAvg] Round 40 — Acc: 0.6653 | Loss: 0.9928
#   [FedAvg] Round 41 — Acc: 0.6571 | Loss: 1.0449
#   [FedAvg] Round 42 — Acc: 0.6710 | Loss: 0.9958
#   [FedAvg] Round 43 — Acc: 0.6723 | Loss: 1.0353
#   [FedAvg] Round 44 — Acc: 0.6726 | Loss: 1.0371
#   [FedAvg] Round 45 — Acc: 0.6706 | Loss: 1.0252
#   [FedAvg] Round 46 — Acc: 0.6684 | Loss: 1.0484
#   [FedAvg] Round 47 — Acc: 0.6821 | Loss: 1.0173
#   [FedAvg] Round 48 — Acc: 0.6703 | Loss: 1.0638
#   [FedAvg] Round 49 — Acc: 0.6882 | Loss: 1.0164
#   [FedAvg] Round 50 — Acc: 0.6811 | Loss: 1.0450
#
# ============================================================
#  Test 2  - Attack | Strategy: SignGuard | Mode: attack
# ============================================================
#   [Client 0]: 7505 samples
#   [Client 1]: 3766 samples
#   [Client 1] Top-2 classes for GAN: ['cat', 'frog'] [3, 6]
#   [Client 2]: 2587 samples
#   [Client 2] Top-2 classes for GAN: ['cat', 'frog'] [3, 6]
#   [Client 3]: 5760 samples
#   [Client 4]: 5691 samples
#   [Client 5]: 7494 samples
#   [Client 5] Top-2 classes for GAN: ['cat', 'frog'] [3, 6]
#   [Client 6]: 2628 samples
#   [Client 7]: 4624 samples
#   [Client 8]: 5996 samples
#   [Client 9]: 3949 samples
#
#   [SignGuard] Round 1 — 7/10 clients trusted
#   [SignGuard] Trusted clients: [0, 1, 2, 3, 5, 7, 8]
#   [SignGuard] Round 1 — Acc: 0.1561 | Loss: 2.2187
#
#   [SignGuard] Round 2 — 5/10 clients trusted
#   [SignGuard] Trusted clients: [1, 3, 4, 6, 9]
#   [SignGuard] Round 2 — Acc: 0.2576 | Loss: 1.9679
#
#   [SignGuard] Round 3 — 7/10 clients trusted
#   [SignGuard] Trusted clients: [1, 2, 3, 4, 5, 7, 9]
#   [SignGuard] Round 3 — Acc: 0.2902 | Loss: 1.8893
#
#   [SignGuard] Round 4 — 5/10 clients trusted
#   [SignGuard] Trusted clients: [0, 3, 6, 8, 9]
#   [SignGuard] Round 4 — Acc: 0.3602 | Loss: 1.6513
#
#   [SignGuard] Round 5 — 7/10 clients trusted
#   [SignGuard] Trusted clients: [0, 3, 4, 6, 7, 8, 9]
#   [SignGuard] Round 5 — Acc: 0.4483 | Loss: 1.4539
#
#   [SignGuard] Round 6 — 6/10 clients trusted
#   [SignGuard] Trusted clients: [3, 4, 5, 6, 7, 8]
#   [SignGuard] Round 6 — Acc: 0.3839 | Loss: 1.6075
#
#   [SignGuard] Round 7 — 7/10 clients trusted
#   [SignGuard] Trusted clients: [1, 3, 4, 5, 7, 8, 9]
#   [SignGuard] Round 7 — Acc: 0.4127 | Loss: 1.5803
#
#   [SignGuard] Round 8 — 7/10 clients trusted
#   [SignGuard] Trusted clients: [0, 3, 4, 6, 7, 8, 9]
#   [SignGuard] Round 8 — Acc: 0.4928 | Loss: 1.3511
#
#   [SignGuard] Round 9 — 8/10 clients trusted
#   [SignGuard] Trusted clients: [0, 1, 2, 3, 4, 6, 8, 9]
#   [SignGuard] Round 9 — Acc: 0.4613 | Loss: 1.4568
#
#   [SignGuard] Round 10 — 5/10 clients trusted
#   [SignGuard] Trusted clients: [1, 2, 4, 5, 9]
#   [SignGuard] Round 10 — Acc: 0.3418 | Loss: 1.9234
#
#   [SignGuard] Round 11 — 8/10 clients trusted
#   [SignGuard] Trusted clients: [1, 2, 3, 4, 5, 7, 8, 9]
#   [SignGuard] Round 11 — Acc: 0.4394 | Loss: 1.5380
#
#   [SignGuard] Round 12 — 6/10 clients trusted
#   [SignGuard] Trusted clients: [0, 1, 2, 4, 5, 8]
#   [SignGuard] Round 12 — Acc: 0.4685 | Loss: 1.4304
#
#   [SignGuard] Round 13 — 5/10 clients trusted
#   [SignGuard] Trusted clients: [0, 3, 7, 8, 9]
#   [SignGuard] Round 13 — Acc: 0.5172 | Loss: 1.2699
#
#   [SignGuard] Round 14 — 5/10 clients trusted
#   [SignGuard] Trusted clients: [0, 1, 4, 7, 9]
#   [SignGuard] Round 14 — Acc: 0.5410 | Loss: 1.2411
#
#   [SignGuard] Round 15 — 6/10 clients trusted
#   [SignGuard] Trusted clients: [0, 1, 2, 3, 4, 8]
#   [SignGuard] Round 15 — Acc: 0.5278 | Loss: 1.2967
#
#   [SignGuard] Round 16 — 7/10 clients trusted
#   [SignGuard] Trusted clients: [2, 3, 4, 6, 7, 8, 9]
#   [SignGuard] Round 16 — Acc: 0.5460 | Loss: 1.2349
#
#   [SignGuard] Round 17 — 5/10 clients trusted
#   [SignGuard] Trusted clients: [1, 3, 5, 7, 8]
#   [SignGuard] Round 17 — Acc: 0.4744 | Loss: 1.4828
#
#   [SignGuard] Round 18 — 8/10 clients trusted
#   [SignGuard] Trusted clients: [1, 2, 3, 5, 6, 7, 8, 9]
#   [SignGuard] Round 18 — Acc: 0.4944 | Loss: 1.3989
#
#   [SignGuard] Round 19 — 6/10 clients trusted
#   [SignGuard] Trusted clients: [0, 3, 4, 7, 8, 9]
#   [SignGuard] Round 19 — Acc: 0.6067 | Loss: 1.0719
#
#   [SignGuard] Round 20 — 7/10 clients trusted
#   [SignGuard] Trusted clients: [0, 1, 3, 4, 7, 8, 9]
#   [SignGuard] Round 20 — Acc: 0.6025 | Loss: 1.0857
#
#   [SignGuard] Round 21 — 7/10 clients trusted
#   [SignGuard] Trusted clients: [0, 1, 2, 3, 5, 6, 7]
#   [SignGuard] Round 21 — Acc: 0.5327 | Loss: 1.3239
#
#   [SignGuard] Round 22 — 7/10 clients trusted
#   [SignGuard] Trusted clients: [0, 3, 4, 5, 6, 7, 8]
#   [SignGuard] Round 22 — Acc: 0.6231 | Loss: 1.0361
#
#   [SignGuard] Round 23 — 7/10 clients trusted
#   [SignGuard] Trusted clients: [0, 3, 4, 6, 7, 8, 9]
#   [SignGuard] Round 23 — Acc: 0.6303 | Loss: 1.0230
#
#   [SignGuard] Round 24 — 5/10 clients trusted
#   [SignGuard] Trusted clients: [0, 1, 4, 8, 9]
#   [SignGuard] Round 24 — Acc: 0.6221 | Loss: 1.0444
#
#   [SignGuard] Round 25 — 6/10 clients trusted
#   [SignGuard] Trusted clients: [0, 1, 2, 3, 7, 8]
#   [SignGuard] Round 25 — Acc: 0.5743 | Loss: 1.1964
#
#   [SignGuard] Round 26 — 5/10 clients trusted
#   [SignGuard] Trusted clients: [0, 1, 2, 6, 9]
#   [SignGuard] Round 26 — Acc: 0.5803 | Loss: 1.1632
#
#   [SignGuard] Round 27 — 5/10 clients trusted
#   [SignGuard] Trusted clients: [0, 4, 7, 8, 9]
#   [SignGuard] Round 27 — Acc: 0.6374 | Loss: 1.0147
#
#   [SignGuard] Round 28 — 7/10 clients trusted
#   [SignGuard] Trusted clients: [0, 2, 4, 6, 7, 8, 9]
#   [SignGuard] Round 28 — Acc: 0.6394 | Loss: 1.0236
#
#   [SignGuard] Round 29 — 5/10 clients trusted
#   [SignGuard] Trusted clients: [0, 3, 4, 7, 8]
#   [SignGuard] Round 29 — Acc: 0.6505 | Loss: 0.9808
#
#   [SignGuard] Round 30 — 8/10 clients trusted
#   [SignGuard] Trusted clients: [0, 1, 2, 3, 4, 6, 8, 9]
#   [SignGuard] Round 30 — Acc: 0.6069 | Loss: 1.0913
#
#   [SignGuard] Round 31 — 7/10 clients trusted
#   [SignGuard] Trusted clients: [0, 3, 4, 6, 7, 8, 9]
#   [SignGuard] Round 31 — Acc: 0.6691 | Loss: 0.9395
#
#   [SignGuard] Round 32 — 7/10 clients trusted
#   [SignGuard] Trusted clients: [0, 3, 4, 6, 7, 8, 9]
#   [SignGuard] Round 32 — Acc: 0.6738 | Loss: 0.9450
#
#   [SignGuard] Round 33 — 5/10 clients trusted
#   [SignGuard] Trusted clients: [0, 2, 5, 8, 9]
#   [SignGuard] Round 33 — Acc: 0.5978 | Loss: 1.1455
#
#   [SignGuard] Round 34 — 7/10 clients trusted
#   [SignGuard] Trusted clients: [0, 3, 4, 6, 7, 8, 9]
#   [SignGuard] Round 34 — Acc: 0.6734 | Loss: 0.9453
#
#   [SignGuard] Round 35 — 8/10 clients trusted
#   [SignGuard] Trusted clients: [0, 1, 3, 4, 6, 7, 8, 9]
#   [SignGuard] Round 35 — Acc: 0.6671 | Loss: 0.9588
#
#   [SignGuard] Round 36 — 7/10 clients trusted
#   [SignGuard] Trusted clients: [0, 3, 4, 6, 7, 8, 9]
#   [SignGuard] Round 36 — Acc: 0.6841 | Loss: 0.9360
#
#   [SignGuard] Round 37 — 6/10 clients trusted
#   [SignGuard] Trusted clients: [1, 2, 4, 5, 8, 9]
#   [SignGuard] Round 37 — Acc: 0.5513 | Loss: 1.3262
#
#   [SignGuard] Round 38 — 6/10 clients trusted
#   [SignGuard] Trusted clients: [0, 3, 4, 6, 8, 9]
#   [SignGuard] Round 38 — Acc: 0.6874 | Loss: 0.9443
#
#   [SignGuard] Round 39 — 7/10 clients trusted
#   [SignGuard] Trusted clients: [1, 3, 4, 6, 7, 8, 9]
#   [SignGuard] Round 39 — Acc: 0.6509 | Loss: 1.0570
#
#   [SignGuard] Round 40 — 5/10 clients trusted
#   [SignGuard] Trusted clients: [3, 4, 6, 7, 8]
#   [SignGuard] Round 40 — Acc: 0.6750 | Loss: 0.9954
#
#   [SignGuard] Round 41 — 7/10 clients trusted
#   [SignGuard] Trusted clients: [0, 3, 4, 6, 7, 8, 9]
#   [SignGuard] Round 41 — Acc: 0.6864 | Loss: 0.9505
#
#   [SignGuard] Round 42 — 7/10 clients trusted
#   [SignGuard] Trusted clients: [0, 3, 4, 6, 7, 8, 9]
#   [SignGuard] Round 42 — Acc: 0.6914 | Loss: 0.9669
#
#   [SignGuard] Round 43 — 6/10 clients trusted
#   [SignGuard] Trusted clients: [0, 2, 3, 4, 6, 9]
#   [SignGuard] Round 43 — Acc: 0.6750 | Loss: 1.0047
#
#   [SignGuard] Round 44 — 5/10 clients trusted
#   [SignGuard] Trusted clients: [0, 4, 6, 7, 9]
#   [SignGuard] Round 44 — Acc: 0.6849 | Loss: 1.0147
#
#   [SignGuard] Round 45 — 8/10 clients trusted
#   [SignGuard] Trusted clients: [0, 1, 2, 3, 4, 6, 8, 9]
#   [SignGuard] Round 45 — Acc: 0.6505 | Loss: 1.0843
#
#   [SignGuard] Round 46 — 8/10 clients trusted
#   [SignGuard] Trusted clients: [1, 2, 4, 5, 6, 7, 8, 9]
#   [SignGuard] Round 46 — Acc: 0.6205 | Loss: 1.2049
#
#   [SignGuard] Round 47 — 4/10 clients trusted
#   [SignGuard] Trusted clients: [3, 7, 8, 9]
#   [SignGuard] Round 47 — Acc: 0.6677 | Loss: 1.1221
#
#   [SignGuard] Round 48 — 8/10 clients trusted
#   [SignGuard] Trusted clients: [0, 1, 2, 4, 6, 7, 8, 9]
#   [SignGuard] Round 48 — Acc: 0.6588 | Loss: 1.0787
#
#   [SignGuard] Round 49 — 6/10 clients trusted
#   [SignGuard] Trusted clients: [3, 4, 6, 7, 8, 9]
#   [SignGuard] Round 49 — Acc: 0.6843 | Loss: 1.0638
#
#   [SignGuard] Round 50 — 8/10 clients trusted
#   [SignGuard] Trusted clients: [0, 1, 2, 3, 4, 6, 7, 8]
#   [SignGuard] Round 50 — Acc: 0.6728 | Loss: 1.0495
#
# All simulations complete!

# %% [markdown]
# ## Results Visualization

# %%
def plot_results(all_results: dict):
    test_names = list(all_results.keys())
    num_tests = len(test_names)

    fig, axes = plt.subplots(num_tests, 2, figsize=(14, 4 * num_tests))
    fig.suptitle('FedAvg vs SignGuard — CIFAR-10 Federated Learning\nEvaluation across Data Heterogeneity & Attacks',
                 fontsize=16, fontweight='bold', y=1.02)

    colors  = {'FedAvg': '#2196F3', 'SignGuard': '#4CAF50'}
    markers = {'FedAvg': 'o',       'SignGuard': '^'}

    for row, test_name in enumerate(test_names):
        ax_acc = axes[row][0] if num_tests > 1 else axes[0]
        ax_loss = axes[row][1] if num_tests > 1 else axes[1]

        plot_data = {}

        for strategy_name, metrics in all_results[test_name].items():
            if not metrics:
                continue
            rounds = [m['round'] for m in metrics]
            accs = [m['accuracy'] for m in metrics]
            losses = [m['loss'] for m in metrics]

            plot_data[strategy_name] = (rounds, accs, losses)

            color = colors[strategy_name]
            marker = markers[strategy_name]
            final_acc = accs[-1] if accs else 0

            ax_acc.plot(rounds, accs, color=color, marker=marker,
                        label=f'{strategy_name} (final: {final_acc:.3f})',
                        linewidth=2.5, markersize=6)
            ax_loss.plot(rounds, losses, color=color, marker=marker,
                         label=strategy_name, linewidth=2.5, markersize=6)

        ax_acc.set_title(f'{test_name}: Accuracy', fontweight='bold', fontsize=12)
        ax_acc.set_xlabel('Round')
        ax_acc.set_ylabel('Accuracy')
        ax_acc.set_ylim(0, 1.0)
        ax_acc.legend(loc='lower right')
        ax_acc.grid(True, linestyle='--', alpha=0.6)

        ax_loss.set_title(f'{test_name}: Loss', fontweight='bold', fontsize=12)
        ax_loss.set_xlabel('Round')
        ax_loss.set_ylabel('Loss')
        ax_loss.legend(loc='upper right')
        ax_loss.grid(True, linestyle='--', alpha=0.6)

    plt.tight_layout()
    plt.show()

plot_results(all_results)

# %% [markdown]
# ## Plot Divergence

# %%
def plot_divergence(divergence_history, metric='l2'):
    test_names     = list(divergence_history.keys())
    strategy_names = ['FedAvg', 'SignGuard']
    colors         = [f'C{i}' for i in range(NUM_CLIENTS)]

    fig, axes = plt.subplots(len(test_names), 2, figsize=(14, 4 * len(test_names)))
    if len(test_names) == 1:
        axes = [axes]

    for row, test_name in enumerate(test_names):
        for col, sname in enumerate(strategy_names):
            ax      = axes[row][col]
            div_log = divergence_history[test_name].get(sname, {})
            if not div_log:
                ax.set_visible(False)
                continue

            rounds   = sorted(div_log.keys())
            all_cids = sorted({cid for rd in div_log.values() for cid in rd})

            for cid in all_cids:
                vals = [div_log[r].get(cid, {}).get(metric, np.nan) for r in rounds]
                ax.plot(rounds, vals, marker='o', markersize=4,
                        label=f'Client {cid}', color=colors[cid])

            ylabel = {'l2': 'L2 ‖local − global‖',
                      'cosine': 'Cosine Distance'}[metric]

            ax.set_title(f'{test_name} | {sname} — {ylabel}', fontweight='bold')
            ax.set_xlabel('Round')
            ax.set_ylabel(ylabel)
            ax.legend(loc='upper right', fontsize=8)
            ax.grid(True, linestyle='--', alpha=0.5)

    plt.tight_layout()
    plt.show()

plot_divergence(divergence_history, metric='l2')
plot_divergence(divergence_history, metric='cosine')

# %% [markdown]
# ## Plot Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

def plot_confusion_matrices_over_rounds(snapshots):
    test_loader    = DataLoader(CIFAR10_TEST, batch_size=256, shuffle=False)
    strategy_names = ['FedAvg', 'SignGuard']

    for test_name in snapshots:
        for sname in strategy_names:
            snap = snapshots[test_name].get(sname, {})
            if not snap:
                continue

            rounds = sorted(snap.keys())
            n_cols = len(rounds)
            fig, axes = plt.subplots(1, n_cols, figsize=(5 * n_cols, 5))
            if n_cols == 1:
                axes = [axes]

            fig.suptitle(f'{test_name} | {sname} — Confusion Matrix per Round',
                         fontweight='bold', fontsize=13)

            for ax, rnd in zip(axes, rounds):
                model = CifarCNN().to(DEVICE)
                set_parameters(model, snap[rnd])
                model.eval()

                all_preds, all_labels = [], []
                with torch.no_grad():
                    for images, labels in test_loader:
                        preds = model(images.to(DEVICE)).argmax(dim=1).cpu().numpy()
                        all_preds.extend(preds)
                        all_labels.extend(labels.numpy())

                cm      = confusion_matrix(all_labels, all_preds)
                cm_norm = cm.astype(float) / cm.sum(axis=1, keepdims=True)

                sns.heatmap(cm_norm, annot=True, fmt='.2f', ax=ax,
                            cmap='Blues', xticklabels=CLASSES, yticklabels=CLASSES,
                            linewidths=0.3, vmin=0, vmax=1, cbar=False)
                acc = np.diag(cm_norm).mean()
                ax.set_title(f'Round {rnd}\nacc={acc:.3f}', fontsize=10)
                ax.set_xlabel('Predicted')
                ax.set_ylabel('True' if rnd == rounds[0] else '')

            plt.tight_layout()
            plt.show()

plot_confusion_matrices_over_rounds(snapshots)

# %% [markdown]
# ## Summary Table

# %%
print(f'\n{"="*65}')
print(f'  FINAL RESULTS SUMMARY')
print(f'{"="*65}')
print(f'{"Test":<35} {"Strategy":<10} {"Final Acc":>10} {"Final Loss":>12}')
print(f'{"-"*65}')

for test_name, strategies in all_results.items():
    for strategy_name, metrics in strategies.items():
        if metrics:
            final = metrics[-1]
            print(f'{test_name:<35} {strategy_name:<10} '
                  f'{final["accuracy"]:>10.4f} {final["loss"]:>12.4f}')
        else:
            print(f'{test_name:<35} {strategy_name:<10} {"N/A":>10} {"N/A":>12}')

print(f'{"="*65}')
# Out:
# =================================================================
#   FINAL RESULTS SUMMARY
# =================================================================
# Test                                Strategy    Final Acc   Final Loss
# -----------------------------------------------------------------
# Test 1  - Non-iid                   FedAvg         0.7278       0.9641
# Test 1  - Non-iid                   SignGuard      0.6625       1.0946
# Test 2  - Attack                    FedAvg         0.6811       1.0450
# Test 2  - Attack                    SignGuard      0.6728       1.0495
# =================================================================
