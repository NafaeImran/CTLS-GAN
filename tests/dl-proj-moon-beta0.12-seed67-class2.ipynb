# %% [markdown]
# # Federated Learning Experiments: FedAvg vs MOON
#
# **10 Clients | CIFAR-10**
#
# ## Tests:
# | Test | Description |
# |------|-------------|
# | Test 1 | Normal run — all clients get Non-IID CIFAR-10 data |
# | Test 2 | Poisoning attack — GAN-skew attack on selected clients |
#
# Both **FedAvg** and **MOON** are run on each test for comparison.

# %% [markdown]
# ## Install Dependencies
#
# ---

# %%
# !pip install torch torchvision numpy matplotlib scikit-learn seaborn -q

# %% [markdown]
# ## Imports & Config

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Subset
import torchvision
import torchvision.transforms as transforms
import numpy as np
import matplotlib.pyplot as plt
from typing import List, Tuple, Dict, Optional
from collections import OrderedDict
from functools import reduce
import os, warnings, logging

warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", message=".*upfirdn2d.*")
warnings.filterwarnings("ignore", message=".*bias_act.*")

NUM_CLIENTS = 10
NUM_ROUNDS = 50
LOCAL_EPOCHS= 2
BATCH_SIZE= 256
LEARNING_RATE= 0.001
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

ATTACK_CLIENT_ID   = [1, 5, 2]
GAN_WARMUP_ROUNDS = 0
BETA =0.12# gans ramp up rate
SEED=67 # six seven six seven six seven six seven six seven six seven six seven six seven six seven six seven six seven six seven six seven six seven six seven six seven six seven six seven six seven six seven six seven six seven six seven six seven six seven six seven six seven six seven six seven six seven six seven six seven six seven six seven six seven six seven   


n_top = 2  # CHANGE THIS to your desired n everywhere

print(f'Device: {DEVICE}')
# Out:
# Device: cuda

# %% [markdown]
# ## CNN Model (CIFAR-10)

# %%
class CifarCNN(nn.Module):
    def __init__(self):
        super(CifarCNN, self).__init__()
        self.conv_block = nn.Sequential(
            nn.Conv2d(3, 32, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(32, 64, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(64, 64, 3, padding=1),
            nn.ReLU()
        )
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(64 * 8 * 8, 256),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, 10)
        )

    def forward(self, x):
        return self.classifier(self.conv_block(x))


def get_parameters(model):
    return [val.cpu().numpy() for val in model.state_dict().values()]


def set_parameters(model, parameters):
    params_dict = zip(model.state_dict().keys(), parameters)
    state_dict = OrderedDict({k: torch.tensor(v) for k, v in params_dict})
    model.load_state_dict(state_dict, strict=True)


print('Model defined. Parameter count:',
      sum(p.numel() for p in CifarCNN().parameters()))
# Out:
# Model defined. Parameter count: 1107722

# %% [markdown]
# ## Data Loading Setup

# %%
from collections import Counter

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

CIFAR10_TRAIN = torchvision.datasets.CIFAR10(
    root='./data', train=True, download=True, transform=transform
)
CIFAR10_TEST = torchvision.datasets.CIFAR10(
    root='./data', train=False, download=True, transform=transform
)

CLASSES = ['airplane','automobile','bird','cat','deer',
           'dog','frog','horse','ship','truck']

def get_all_non_iid_partitions(dataset, num_clients, alpha=0.5):
    np.random.seed(SEED)
    labels = np.array([label for _, label in dataset])
    num_classes = len(np.unique(labels))
    client_indices = [[] for _ in range(num_clients)]
    for k in range(num_classes):
        idx_k = np.where(labels == k)[0]
        np.random.shuffle(idx_k)
        proportions = np.random.dirichlet([alpha] * num_clients)
        splits = (np.cumsum(proportions) * len(idx_k)).astype(int)[:-1]
        for i, chunk in enumerate(np.split(idx_k, splits)):
            client_indices[i].append(chunk)
    return [
        Subset(dataset, np.concatenate(client_indices[i]).tolist())
        for i in range(num_clients)
    ]

ALL_PARTITIONS = get_all_non_iid_partitions(CIFAR10_TRAIN, NUM_CLIENTS, alpha=0.5)

def load_client_data(client_id: int) -> Tuple[DataLoader, DataLoader]:
    train_subset = ALL_PARTITIONS[client_id]
    print(f'  [Client {client_id}]: {len(train_subset)} samples')
    train_loader = DataLoader(train_subset, batch_size=BATCH_SIZE, shuffle=True)
    test_loader  = DataLoader(CIFAR10_TEST,  batch_size=BATCH_SIZE, shuffle=False)
    return train_loader, test_loader

def get_top_n_classes(subset, n=1):
    labels = [subset.dataset.targets[i] for i in subset.indices]
    return [cls for cls, _ in Counter(labels).most_common(n)]

print('Data utilities ready.')
print(f'CIFAR-10 train size: {len(CIFAR10_TRAIN)} | test size: {len(CIFAR10_TEST)}')
# Out:
# 100%|██████████| 170M/170M [02:47<00:00, 1.02MB/s]
# Data utilities ready.
# CIFAR-10 train size: 50000 | test size: 10000

# %% [markdown]
# ## Pre-trained GANS Setup

# %%
# !git clone https://github.com/NVlabs/stylegan2-ada-pytorch.git
import pickle, requests, os,sys,contextlib
sys.path.insert(0, './stylegan2-ada-pytorch')
stylegan_path = "/kaggle/working/stylegan2-ada-pytorch"

if stylegan_path not in sys.path:
    sys.path.append(stylegan_path)


weights_url = 'https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/cifar10.pkl'
weights_path = 'cifar10.pkl'

if not os.path.exists(weights_path):
    print('Downloading StyleGAN2-ADA CIFAR-10 weights...')
    r = requests.get(weights_url, stream=True)
    with open(weights_path, 'wb') as f:
        for chunk in r.iter_content(chunk_size=8192):
            f.write(chunk)
    print('Done.')

with contextlib.redirect_stderr(open(os.devnull, 'w')), \
     contextlib.redirect_stdout(open(os.devnull, 'w')):
    with open(weights_path, 'rb') as f:
        data = pickle.load(f)
    stylegan_G = data['G_ema'].to(DEVICE)

print('StyleGAN2-ADA generator loaded.')
print(f'  z_dim: {stylegan_G.z_dim} | c_dim: {stylegan_G.c_dim} | img resolution: {stylegan_G.img_resolution}')



def stylegan_generate(class_idx, n_images, truncation_psi=0.7):
    with contextlib.redirect_stderr(open(os.devnull, 'w')), \
         contextlib.redirect_stdout(open(os.devnull, 'w')):
        with torch.no_grad():
            z = torch.randn(n_images, stylegan_G.z_dim).to(DEVICE)
            c = torch.zeros(n_images, stylegan_G.c_dim).to(DEVICE)
            c[:, class_idx] = 1.0
            imgs = stylegan_G(z, c, truncation_psi=truncation_psi)
            imgs = (imgs * 0.5 + 0.5).clamp(0, 1)
            imgs = (imgs - 0.5) / 0.5
    return imgs
warnings.filterwarnings("ignore", category=UserWarning, module="torch_utils")
# Out:
# Cloning into 'stylegan2-ada-pytorch'...
# remote: Enumerating objects: 131, done.
# remote: Counting objects: 100% (2/2), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 131 (delta 0), reused 0 (delta 0), pack-reused 129 (from 2)
# Receiving objects: 100% (131/131), 1.13 MiB | 8.21 MiB/s, done.
# Resolving deltas: 100% (57/57), done.
# Downloading StyleGAN2-ADA CIFAR-10 weights...
# Done.
# StyleGAN2-ADA generator loaded.
#   z_dim: 512 | c_dim: 10 | img resolution: 32

# %% [markdown]
# ## Conditoioning on Client classes

# %%
topn = get_top_n_classes(ALL_PARTITIONS[ATTACK_CLIENT_ID[0]], n=n_top)
print(f'Attacker top-{n_top} classes: {[CLASSES[c] for c in topn]} {topn}')
print('StyleGAN2-ADA will generate only these classes during attack.')
# Out:
# Attacker top-2 classes: ['cat', 'frog'] [3, 6]
# StyleGAN2-ADA will generate only these classes during attack.

# %% [markdown]
# ## GANS Visualization

# %%
import torchvision.utils as vutils
fig, axes = plt.subplots(1, n_top, figsize=(6 * n_top, 5))
axes = [axes] if n_top == 1 else list(axes)

for ax, cls in zip(axes, topn):
    imgs = stylegan_generate(cls, 16, truncation_psi=0.7)
    imgs = (imgs * 0.5 + 0.5).clamp(0, 1)
    grid = vutils.make_grid(imgs, nrow=4, padding=2)
    ax.imshow(grid.permute(1, 2, 0).cpu())
    ax.set_title(f'StyleGAN2 generated: {CLASSES[cls]}', fontweight='bold')
    ax.axis('off')

plt.suptitle('Attack Image Quality Check', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Training and Evaluation Setup

# %%
def train_one_round(model, train_loader, epochs,current_round, client_id, mode='non-iid', topn_classes=None):
    model.to(DEVICE)
    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
    criterion = nn.CrossEntropyLoss()

    is_malicious = (mode == 'attack' and client_id in ATTACK_CLIENT_ID)



    model.train()
    for epoch in range(epochs):
        for images, labels in train_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            batch_size = images.size(0)

            if is_malicious and topn_classes is not None:
              if current_round > GAN_WARMUP_ROUNDS:
                  skew_ratio = min(0.3 + BETA  * current_round, 0.9)
                  n_skew = int(batch_size * skew_ratio)
                  n_real = batch_size - n_skew

                  idx = torch.randint(0, len(topn_classes), (1,)).item()
                  chosen_class = topn_classes[idx]

                  with torch.no_grad():
                      gan_images = stylegan_generate(chosen_class, n_skew).detach()
                  gan_labels = torch.full((n_skew,), chosen_class, dtype=torch.long, device=DEVICE)

                  images = torch.cat([images[:n_real], gan_images], dim=0)
                  labels = torch.cat([labels[:n_real], gan_labels], dim=0)

            optimizer.zero_grad()
            outputs = model(images)
            loss    = criterion(outputs, labels)
            loss.backward()
            optimizer.step()


def evaluate_model(model, test_loader):
    model.to(DEVICE)
    criterion = nn.CrossEntropyLoss()
    model.eval()
    total_loss, correct, total = 0.0, 0, 0
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = model(images)
            total_loss += criterion(outputs, labels).item()
            predicted = outputs.argmax(dim=1)
            correct += (predicted == labels).sum().item()
            total   += labels.size(0)
    return total_loss / len(test_loader), correct / total

# %% [markdown]
# ## Flower Client Class

# %%
class FLClient:
    """Plain federated client — no Flower dependency."""

    def __init__(self, client_id: int, mode: str = 'non-iid'):
        self.client_id   = client_id
        self.mode        = mode
        self.model       = CifarCNN()
        self.train_loader, self.test_loader = load_client_data(client_id)

        import sys
        stylegan_path = "/kaggle/working/stylegan2-ada-pytorch"
        if stylegan_path not in sys.path:
            sys.path.insert(0, stylegan_path)

        # Pre-compute top-n classes for the malicious client
        if mode == 'attack' and client_id in ATTACK_CLIENT_ID:
            self.topn_classes = get_top_n_classes(ALL_PARTITIONS[ATTACK_CLIENT_ID[0]], n=n_top)
            print(f'  [Client {client_id}] Top-{n_top} classes for GAN: '
                  f'{[CLASSES[c] for c in self.topn_classes]} {self.topn_classes}')
        else:
            self.topn_classes = None

    def get_parameters(self):
        return get_parameters(self.model)

    def fit(self, parameters, local_epochs=LOCAL_EPOCHS, current_round=0):
        set_parameters(self.model, parameters)
        train_one_round(self.model, self.train_loader,
                        local_epochs, current_round,
                        self.client_id, self.mode, self.topn_classes)
        return (get_parameters(self.model),
                len(self.train_loader.dataset),
                {'client_id': self.client_id, 'mode': self.mode})

    def evaluate(self, parameters):
        set_parameters(self.model, parameters)
        loss, accuracy = evaluate_model(self.model, self.test_loader)
        return (float(loss),
                len(self.test_loader.dataset),
                {'accuracy': float(accuracy), 'client_id': self.client_id})


print('FLClient class defined.')
# Out:
# FLClient class defined.

# %% [markdown]
# ## Divergence calculation

# %%
# ── Client Divergence Tracking ────────────────────────────────────────────────
divergence_history = {}   # {test_name: {strategy_name: {round: {cid: {l2, cosine}}}}}

def l2_divergence(local_params, global_params):
    """L2 norm of (local − global) flattened across all weight tensors."""
    return float(np.sqrt(sum(
        np.sum((lp - gp) ** 2)
        for lp, gp in zip(local_params, global_params)
    )))

def cosine_divergence(local_params, global_params):
    """
    Cosine similarity between flattened local and global weight vectors.
    Returns similarity in [-1, 1] — closer to 1 = less diverged.
    """
    local_vec  = np.concatenate([p.ravel() for p in local_params])
    global_vec = np.concatenate([p.ravel() for p in global_params])

    dot    = np.dot(local_vec, global_vec)
    norm_l = np.linalg.norm(local_vec)
    norm_g = np.linalg.norm(global_vec)

    denom = norm_l * norm_g
    if denom < 1e-10:
        return 0.0
    return float(dot / denom)

def compute_divergence(local_params, global_params):
    local_flat  = np.concatenate([p.ravel() for p in local_params])
    global_flat = np.concatenate([p.ravel() for p in global_params])

    l2 = float(np.sqrt(np.sum((local_flat - global_flat) ** 2)))

    denom = np.linalg.norm(local_flat) * np.linalg.norm(global_flat)
    cosine = float(1.0 - np.dot(local_flat, global_flat) / denom) if denom > 1e-10 else 0.0

    return {'l2': l2, 'cosine': cosine}

# NOTE: add_divergence_tracking and add_param_snapshots are now no-ops kept for
# API compatibility. Divergence and snapshots are computed inline in run_simulation.
def add_divergence_tracking(strategy, div_log):
    strategy._div_log = div_log
    return strategy

def add_param_snapshots(strategy, snapshot_log, every_n=10):
    strategy._snapshot_log = snapshot_log
    strategy._snapshot_every_n = every_n
    return strategy

# %% [markdown]
# ## FedAvg Setup

# %%
class FedAvgStrategy:
    """Modular sequential FedAvg — no Flower dependency."""

    def __init__(self, round_metrics: list):
        self.round_metrics  = round_metrics
        self._global_params = None
        # set by add_divergence_tracking / add_param_snapshots
        self._div_log         = {}
        self._snapshot_log    = {}
        self._snapshot_every_n = 10

    def aggregate_fit(self, server_round: int, results: list) -> list:
        """
        results: list of (params, num_examples, metrics)
        Returns aggregated global params (plain numpy list).
        """
        if not results:
            return self._global_params

        total_samples = sum(n for _, n, _ in results)
        aggregated = [
            sum(params[i] * n / total_samples for params, n, _ in results)
            for i in range(len(results[0][0]))
        ]
        self._global_params = aggregated
        return aggregated

    def aggregate_evaluate(self, server_round: int, results: list):
        """
        results: list of (loss, num_examples, metrics)
        """
        if not results:
            return None, {}

        total_samples = sum(n for _, n, _ in results)
        weighted_acc  = sum(m['accuracy'] * n for _, n, m in results) / total_samples
        weighted_loss = sum(loss * n for loss, n, _ in results) / total_samples

        self.round_metrics.append({
            'round': server_round,
            'accuracy': weighted_acc,
            'loss': weighted_loss
        })

        print(f'  [FedAvg] Round {server_round} — '
              f'Acc: {weighted_acc:.4f} | Loss: {weighted_loss:.4f}')

        return weighted_loss, {'accuracy': weighted_acc}


def build_fedavg_strategy(round_metrics: list) -> FedAvgStrategy:
    return FedAvgStrategy(round_metrics)


print('FedAvg strategy builder defined.')
# Out:
# FedAvg strategy builder defined.

# %% [markdown]
# ## MOON Setup

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from collections import OrderedDict

# ---------------------------------------------------------------------------
# MOON  (Model-Contrastive Federated Learning, Li et al. CVPR 2021)
# ---------------------------------------------------------------------------
# Key idea:
#   Local loss = CE_loss + mu * L_con
#   L_con = -log( exp(sim(z, z_glob)/tau) /
#                 [exp(sim(z, z_glob)/tau) + exp(sim(z, z_prev)/tau)] )
#
# where z        = current local model's penultimate representation
#       z_glob   = global model's penultimate representation  (positive)
#       z_prev   = previous local model's representation      (negative)
#       sim(·,·) = cosine similarity
# ---------------------------------------------------------------------------

MOON_MU  = 5.0    # contrastive loss weight  (original paper default)
MOON_TAU = 0.5    # temperature              (original paper default)


class _RepresentationExtractor(nn.Module):
    """Wraps CifarCNN and exposes the penultimate-layer vector (256-d)."""
    def __init__(self, base: nn.Module):
        super().__init__()
        self.base = base

    def forward(self, x):
        z = self.base.conv_block(x)          # (B, 64, 8, 8)
        z = z.view(z.size(0), -1)            # (B, 4096)
        # first Linear + ReLU + Dropout  →  (B, 256)
        z = self.base.classifier[1](self.base.classifier[0](z))
        z = torch.relu(z)
        return z                             # 256-d representation


def _cosine_sim(a: torch.Tensor, b: torch.Tensor) -> torch.Tensor:
    """Row-wise cosine similarity, shape (B,)."""
    a_n = nn.functional.normalize(a, dim=1)
    b_n = nn.functional.normalize(b, dim=1)
    return (a_n * b_n).sum(dim=1)


def moon_contrastive_loss(
    z_cur:  torch.Tensor,
    z_glob: torch.Tensor,
    z_prev: torch.Tensor,
    tau:    float = MOON_TAU
) -> torch.Tensor:
    """
    MOON contrastive loss (scalar).
    L_con = -log( exp(sim(z,z+)/tau) / [exp(sim(z,z+)/tau)+exp(sim(z,z-)/tau)] )
    """
    pos = (_cosine_sim(z_cur, z_glob) / tau).unsqueeze(1)   # (B,1)
    neg = (_cosine_sim(z_cur, z_prev) / tau).unsqueeze(1)   # (B,1)
    logits = torch.cat([pos, neg], dim=1)                    # (B,2)
    targets = torch.zeros(z_cur.size(0), dtype=torch.long, device=z_cur.device)
    return nn.functional.cross_entropy(logits, targets)


def train_one_round_moon(
    model,
    global_model,
    prev_model,
    train_loader,
    epochs,
    current_round,
    client_id,
    mode='non-iid',
    topn_classes=None,
    mu=MOON_MU,
    tau=MOON_TAU,
):
    """
    MOON local training loop.
    global_model and prev_model are kept on DEVICE but frozen (no_grad).
    """
    model.to(DEVICE)
    global_model.to(DEVICE)
    prev_model.to(DEVICE)
    global_model.eval()
    prev_model.eval()

    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
    criterion = nn.CrossEntropyLoss()

    rep_cur  = _RepresentationExtractor(model).to(DEVICE)
    rep_glob = _RepresentationExtractor(global_model).to(DEVICE)
    rep_prev = _RepresentationExtractor(prev_model).to(DEVICE)

    is_malicious = (mode == 'attack' and client_id in ATTACK_CLIENT_ID)

    model.train()
    for epoch in range(epochs):
        for images, labels in train_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            batch_size = images.size(0)

            # ── optional GAN injection for malicious clients ──────────────
            if is_malicious and topn_classes is not None:
                if current_round > GAN_WARMUP_ROUNDS:
                    skew_ratio = min(0.3 + BETA * current_round, 0.9)
                    n_skew = int(batch_size * skew_ratio)
                    n_real = batch_size - n_skew

                    idx = torch.randint(0, len(topn_classes), (1,)).item()
                    chosen_class = topn_classes[idx]

                    with torch.no_grad():
                        gan_images = stylegan_generate(chosen_class, n_skew).detach()
                    gan_labels = torch.full(
                        (n_skew,), chosen_class, dtype=torch.long, device=DEVICE
                    )
                    images = torch.cat([images[:n_real], gan_images], dim=0)
                    labels = torch.cat([labels[:n_real], gan_labels],  dim=0)

            # ── forward pass ──────────────────────────────────────────────
            optimizer.zero_grad()
            outputs = model(images)
            loss_ce = criterion(outputs, labels)

            # ── MOON contrastive term ─────────────────────────────────────
            z_cur  = rep_cur(images)
            with torch.no_grad():
                z_glob = rep_glob(images)
                z_prev = rep_prev(images)

            loss_con = moon_contrastive_loss(z_cur, z_glob, z_prev, tau)
            loss = loss_ce + mu * loss_con

            loss.backward()
            optimizer.step()


# ---------------------------------------------------------------------------
# MOON client — extends FLClient with prev-model bookkeeping
# ---------------------------------------------------------------------------

class MOONClient(FLClient):
    """FLClient augmented with MOON-specific state (global + prev model)."""

    def __init__(self, client_id: int, mode: str = 'non-iid'):
        super().__init__(client_id, mode)
        # previous local model (starts as a copy of the initial model)
        self.prev_model = CifarCNN()
        set_parameters(self.prev_model, get_parameters(self.model))

    def fit(self, global_parameters, local_epochs=LOCAL_EPOCHS, current_round=0):
        # build a frozen copy of the global model for the contrastive term
        global_model = CifarCNN()
        set_parameters(global_model, global_parameters)
        global_model.eval()

        # set current model to global params before local training
        set_parameters(self.model, global_parameters)

        train_one_round_moon(
            model=self.model,
            global_model=global_model,
            prev_model=self.prev_model,
            train_loader=self.train_loader,
            epochs=local_epochs,
            current_round=current_round,
            client_id=self.client_id,
            mode=self.mode,
            topn_classes=self.topn_classes,
        )

        updated_params = get_parameters(self.model)

        # update prev_model ← current model (after local training)
        set_parameters(self.prev_model, updated_params)

        return (
            updated_params,
            len(self.train_loader.dataset),
            {'client_id': self.client_id, 'mode': self.mode},
        )


# ---------------------------------------------------------------------------
# MOON server-side aggregation  (plain weighted FedAvg — same as MOON paper)
# ---------------------------------------------------------------------------

class MOONStrategy:
    """
    MOON uses standard FedAvg aggregation on the server.
    The contrastive magic happens entirely on the client side.
    """

    def __init__(self, round_metrics: list):
        self.round_metrics  = round_metrics
        self._global_params = None
        self._div_log         = {}
        self._snapshot_log    = {}
        self._snapshot_every_n = 10

    def aggregate_fit(self, server_round: int, results: list) -> list:
        if not results:
            return self._global_params

        total_samples = sum(n for _, n, _ in results)
        aggregated = [
            sum(params[i] * n / total_samples for params, n, _ in results)
            for i in range(len(results[0][0]))
        ]
        self._global_params = aggregated
        return aggregated

    def aggregate_evaluate(self, server_round: int, results: list):
        if not results:
            return None, {}

        total_samples = sum(n for _, n, _ in results)
        weighted_acc  = sum(m['accuracy'] * n for _, n, m in results) / total_samples
        weighted_loss = sum(loss * n for loss, n, _ in results) / total_samples

        self.round_metrics.append({
            'round':    server_round,
            'accuracy': weighted_acc,
            'loss':     weighted_loss,
        })

        print(f'  [MOON] Round {server_round} — '
              f'Acc: {weighted_acc:.4f} | Loss: {weighted_loss:.4f}'
              f'  (mu={MOON_MU}, tau={MOON_TAU})')

        return weighted_loss, {'accuracy': weighted_acc}


def build_moon_strategy(round_metrics: list) -> MOONStrategy:
    return MOONStrategy(round_metrics=round_metrics)


print(f'MOON strategy ready.  mu={MOON_MU}  tau={MOON_TAU}')
# Out:
# MOON strategy ready.  mu=5.0  tau=0.5

# %% [markdown]
# ## Simulation Runner

# %%
def run_simulation(test_name: str,
                   mode: str,
                   strategy_name: str,
                   strategy) -> None:
    """
    Sequential federated learning loop — no Flower / Ray.
    Uses MOONClient for MOON strategy, FLClient otherwise.
    """

    print(f'\n{"="*60}')
    print(f' {test_name} | Strategy: {strategy_name} | Mode: {mode}')
    print(f'{"="*60}')

    use_moon = (strategy_name == 'MOON')
    ClientClass = MOONClient if use_moon else FLClient

    clients = [ClientClass(client_id=cid, mode=mode) for cid in range(NUM_CLIENTS)]

    global_params = clients[0].get_parameters()
    strategy._global_params = [p.copy() for p in global_params]

    div_log      = getattr(strategy, '_div_log',         {})
    snapshot_log = getattr(strategy, '_snapshot_log',    {})
    every_n      = getattr(strategy, '_snapshot_every_n', 10)

    for server_round in range(1, NUM_ROUNDS + 1):

        global_snap_before = [p.copy() for p in global_params]

        fit_results = []
        for client in clients:
            params, n_samples, metrics = client.fit(
                global_params,
                local_epochs=LOCAL_EPOCHS,
                current_round=server_round
            )
            fit_results.append((params, n_samples, metrics))

        round_divs = {}
        for (local_params, _, meta) in fit_results:
            cid = meta.get('client_id', -1)
            round_divs[cid] = compute_divergence(local_params, global_snap_before)
        div_log[server_round] = round_divs

        global_params = strategy.aggregate_fit(server_round, fit_results)

        if server_round % every_n == 0:
            snapshot_log[server_round] = [p.copy() for p in global_params]

        eval_results = []
        for client in clients:
            loss, n_samples, metrics = client.evaluate(global_params)
            eval_results.append((loss, n_samples, metrics))

        strategy.aggregate_evaluate(server_round, eval_results)


print('Simulation runner defined.')
# Out:
# Simulation runner defined.

# %% [markdown]
# ## Run All Tests
#
# > **This is the main execution cell.**
# > Runs 4 simulations total: 2 tests × 2 strategies (FedAvg, MOON).
# > Results are stored in `all_results` for plotting.

# %%
all_results        = {}
divergence_history = {}
snapshots          = {}
final_params       = {}

TESTS = [
    ('Test 1  - Non-iid',  'non-iid'),
    ('Test 2  - Attack',   'attack'),
]

for test_name, mode in TESTS:
    all_results[test_name]        = {}
    divergence_history[test_name] = {}
    snapshots[test_name]          = {}
    final_params[test_name]       = {}

    for strategy_name in ['FedAvg', 'MOON']:
        metrics      = []
        div_log      = {}
        snapshot_log = {}

        divergence_history[test_name][strategy_name] = div_log
        snapshots[test_name][strategy_name]          = snapshot_log

        if strategy_name == 'FedAvg':
            strategy = build_fedavg_strategy(metrics)
        else:
            strategy = build_moon_strategy(metrics)

        add_divergence_tracking(strategy, div_log)
        add_param_snapshots(strategy, snapshot_log, every_n=10)

        run_simulation(test_name, mode, strategy_name, strategy)

        all_results[test_name][strategy_name]  = metrics
        final_params[test_name][strategy_name] = strategy._global_params

print('\nAll simulations complete!')
# Out:
# ============================================================
#  Test 1  - Non-iid | Strategy: FedAvg | Mode: non-iid
# ============================================================
#   [Client 0]: 7505 samples
#   [Client 1]: 3766 samples
#   [Client 2]: 2587 samples
#   [Client 3]: 5760 samples
#   [Client 4]: 5691 samples
#   [Client 5]: 7494 samples
#   [Client 6]: 2628 samples
#   [Client 7]: 4624 samples
#   [Client 8]: 5996 samples
#   [Client 9]: 3949 samples
#   [FedAvg] Round 1 — Acc: 0.2842 | Loss: 2.1438
#   [FedAvg] Round 2 — Acc: 0.4217 | Loss: 1.6793
#   [FedAvg] Round 3 — Acc: 0.4581 | Loss: 1.5239
#   [FedAvg] Round 4 — Acc: 0.4880 | Loss: 1.4379
#   [FedAvg] Round 5 — Acc: 0.5191 | Loss: 1.3545
#   [FedAvg] Round 6 — Acc: 0.5376 | Loss: 1.2887
#   [FedAvg] Round 7 — Acc: 0.5602 | Loss: 1.2327
#   [FedAvg] Round 8 — Acc: 0.5825 | Loss: 1.1789
#   [FedAvg] Round 9 — Acc: 0.5943 | Loss: 1.1475
#   [FedAvg] Round 10 — Acc: 0.6086 | Loss: 1.0967
#   [FedAvg] Round 11 — Acc: 0.6219 | Loss: 1.0601
#   [FedAvg] Round 12 — Acc: 0.6299 | Loss: 1.0342
#   [FedAvg] Round 13 — Acc: 0.6456 | Loss: 1.0028
#   [FedAvg] Round 14 — Acc: 0.6482 | Loss: 0.9919
#   [FedAvg] Round 15 — Acc: 0.6527 | Loss: 0.9741
#   [FedAvg] Round 16 — Acc: 0.6645 | Loss: 0.9488
#   [FedAvg] Round 17 — Acc: 0.6760 | Loss: 0.9218
#   [FedAvg] Round 18 — Acc: 0.6822 | Loss: 0.9069
#   [FedAvg] Round 19 — Acc: 0.6890 | Loss: 0.8974
#   [FedAvg] Round 20 — Acc: 0.6976 | Loss: 0.8782
#   [FedAvg] Round 21 — Acc: 0.6990 | Loss: 0.8699
#   [FedAvg] Round 22 — Acc: 0.7021 | Loss: 0.8655
#   [FedAvg] Round 23 — Acc: 0.7043 | Loss: 0.8559
#   [FedAvg] Round 24 — Acc: 0.7090 | Loss: 0.8516
#   [FedAvg] Round 25 — Acc: 0.7104 | Loss: 0.8415
#   [FedAvg] Round 26 — Acc: 0.7151 | Loss: 0.8407
#   [FedAvg] Round 27 — Acc: 0.7164 | Loss: 0.8421
#   [FedAvg] Round 28 — Acc: 0.7166 | Loss: 0.8330
#   [FedAvg] Round 29 — Acc: 0.7224 | Loss: 0.8338
#   [FedAvg] Round 30 — Acc: 0.7178 | Loss: 0.8430
#   [FedAvg] Round 31 — Acc: 0.7223 | Loss: 0.8395
#   [FedAvg] Round 32 — Acc: 0.7233 | Loss: 0.8390
#   [FedAvg] Round 33 — Acc: 0.7267 | Loss: 0.8395
#   [FedAvg] Round 34 — Acc: 0.7251 | Loss: 0.8427
#   [FedAvg] Round 35 — Acc: 0.7264 | Loss: 0.8463
#   [FedAvg] Round 36 — Acc: 0.7274 | Loss: 0.8480
#   [FedAvg] Round 37 — Acc: 0.7289 | Loss: 0.8444
#   [FedAvg] Round 38 — Acc: 0.7264 | Loss: 0.8683
#   [FedAvg] Round 39 — Acc: 0.7288 | Loss: 0.8638
#   [FedAvg] Round 40 — Acc: 0.7275 | Loss: 0.8746
#   [FedAvg] Round 41 — Acc: 0.7306 | Loss: 0.8735
#   [FedAvg] Round 42 — Acc: 0.7286 | Loss: 0.8903
#   [FedAvg] Round 43 — Acc: 0.7314 | Loss: 0.8915
#   [FedAvg] Round 44 — Acc: 0.7294 | Loss: 0.9075
#   [FedAvg] Round 45 — Acc: 0.7298 | Loss: 0.9067
#   [FedAvg] Round 46 — Acc: 0.7288 | Loss: 0.9251
#   [FedAvg] Round 47 — Acc: 0.7339 | Loss: 0.9141
#   [FedAvg] Round 48 — Acc: 0.7294 | Loss: 0.9349
#   [FedAvg] Round 49 — Acc: 0.7328 | Loss: 0.9417
#   [FedAvg] Round 50 — Acc: 0.7315 | Loss: 0.9535
#
# ============================================================
#  Test 1  - Non-iid | Strategy: MOON | Mode: non-iid
# ============================================================
#   [Client 0]: 7505 samples
#   [Client 1]: 3766 samples
#   [Client 2]: 2587 samples
#   [Client 3]: 5760 samples
#   [Client 4]: 5691 samples
#   [Client 5]: 7494 samples
#   [Client 6]: 2628 samples
#   [Client 7]: 4624 samples
#   [Client 8]: 5996 samples
#   [Client 9]: 3949 samples
#   [MOON] Round 1 — Acc: 0.1674 | Loss: 2.2501  (mu=5.0, tau=0.5)
#   [MOON] Round 2 — Acc: 0.2131 | Loss: 2.1421  (mu=5.0, tau=0.5)
#   [MOON] Round 3 — Acc: 0.2992 | Loss: 1.9227  (mu=5.0, tau=0.5)
#   [MOON] Round 4 — Acc: 0.3350 | Loss: 1.8241  (mu=5.0, tau=0.5)
#   [MOON] Round 5 — Acc: 0.3872 | Loss: 1.6842  (mu=5.0, tau=0.5)
#   [MOON] Round 6 — Acc: 0.4014 | Loss: 1.6569  (mu=5.0, tau=0.5)
#   [MOON] Round 7 — Acc: 0.4326 | Loss: 1.5927  (mu=5.0, tau=0.5)
#   [MOON] Round 8 — Acc: 0.4342 | Loss: 1.5897  (mu=5.0, tau=0.5)
#   [MOON] Round 9 — Acc: 0.4338 | Loss: 1.5646  (mu=5.0, tau=0.5)
#   [MOON] Round 10 — Acc: 0.4315 | Loss: 1.5750  (mu=5.0, tau=0.5)
#   [MOON] Round 11 — Acc: 0.4165 | Loss: 1.5919  (mu=5.0, tau=0.5)
#   [MOON] Round 12 — Acc: 0.4170 | Loss: 1.5927  (mu=5.0, tau=0.5)
#   [MOON] Round 13 — Acc: 0.4312 | Loss: 1.5626  (mu=5.0, tau=0.5)
#   [MOON] Round 14 — Acc: 0.4338 | Loss: 1.5560  (mu=5.0, tau=0.5)
#   [MOON] Round 15 — Acc: 0.4459 | Loss: 1.5420  (mu=5.0, tau=0.5)
#   [MOON] Round 16 — Acc: 0.4498 | Loss: 1.5251  (mu=5.0, tau=0.5)
#   [MOON] Round 17 — Acc: 0.4858 | Loss: 1.4652  (mu=5.0, tau=0.5)
#   [MOON] Round 18 — Acc: 0.4936 | Loss: 1.4523  (mu=5.0, tau=0.5)
#   [MOON] Round 19 — Acc: 0.4993 | Loss: 1.4203  (mu=5.0, tau=0.5)
#   [MOON] Round 20 — Acc: 0.5062 | Loss: 1.4335  (mu=5.0, tau=0.5)
#   [MOON] Round 21 — Acc: 0.5073 | Loss: 1.4184  (mu=5.0, tau=0.5)
#   [MOON] Round 22 — Acc: 0.4951 | Loss: 1.4339  (mu=5.0, tau=0.5)
#   [MOON] Round 23 — Acc: 0.5378 | Loss: 1.3826  (mu=5.0, tau=0.5)
#   [MOON] Round 24 — Acc: 0.5439 | Loss: 1.3643  (mu=5.0, tau=0.5)
#   [MOON] Round 25 — Acc: 0.5448 | Loss: 1.3803  (mu=5.0, tau=0.5)
#   [MOON] Round 26 — Acc: 0.5431 | Loss: 1.3739  (mu=5.0, tau=0.5)
#   [MOON] Round 27 — Acc: 0.5481 | Loss: 1.3670  (mu=5.0, tau=0.5)
#   [MOON] Round 28 — Acc: 0.5566 | Loss: 1.3311  (mu=5.0, tau=0.5)
#   [MOON] Round 29 — Acc: 0.5584 | Loss: 1.3164  (mu=5.0, tau=0.5)
#   [MOON] Round 30 — Acc: 0.5537 | Loss: 1.3108  (mu=5.0, tau=0.5)
#   [MOON] Round 31 — Acc: 0.5410 | Loss: 1.3186  (mu=5.0, tau=0.5)
#   [MOON] Round 32 — Acc: 0.5410 | Loss: 1.3226  (mu=5.0, tau=0.5)
#   [MOON] Round 33 — Acc: 0.5619 | Loss: 1.2539  (mu=5.0, tau=0.5)
#   [MOON] Round 34 — Acc: 0.5519 | Loss: 1.2922  (mu=5.0, tau=0.5)
#   [MOON] Round 35 — Acc: 0.5503 | Loss: 1.2829  (mu=5.0, tau=0.5)
#   [MOON] Round 36 — Acc: 0.5556 | Loss: 1.2617  (mu=5.0, tau=0.5)
#   [MOON] Round 37 — Acc: 0.5414 | Loss: 1.2917  (mu=5.0, tau=0.5)
#   [MOON] Round 38 — Acc: 0.5455 | Loss: 1.2718  (mu=5.0, tau=0.5)
#   [MOON] Round 39 — Acc: 0.5644 | Loss: 1.2542  (mu=5.0, tau=0.5)
#   [MOON] Round 40 — Acc: 0.5695 | Loss: 1.2276  (mu=5.0, tau=0.5)
#   [MOON] Round 41 — Acc: 0.5505 | Loss: 1.2772  (mu=5.0, tau=0.5)
#   [MOON] Round 42 — Acc: 0.5523 | Loss: 1.2456  (mu=5.0, tau=0.5)
#   [MOON] Round 43 — Acc: 0.5535 | Loss: 1.2516  (mu=5.0, tau=0.5)
#   [MOON] Round 44 — Acc: 0.5725 | Loss: 1.2159  (mu=5.0, tau=0.5)
#   [MOON] Round 45 — Acc: 0.5510 | Loss: 1.2470  (mu=5.0, tau=0.5)
#   [MOON] Round 46 — Acc: 0.5660 | Loss: 1.2014  (mu=5.0, tau=0.5)
#   [MOON] Round 47 — Acc: 0.5864 | Loss: 1.1899  (mu=5.0, tau=0.5)
#   [MOON] Round 48 — Acc: 0.5967 | Loss: 1.1702  (mu=5.0, tau=0.5)
#   [MOON] Round 49 — Acc: 0.6231 | Loss: 1.1187  (mu=5.0, tau=0.5)
#   [MOON] Round 50 — Acc: 0.6343 | Loss: 1.1021  (mu=5.0, tau=0.5)
#
# ============================================================
#  Test 2  - Attack | Strategy: FedAvg | Mode: attack
# ============================================================
#   [Client 0]: 7505 samples
#   [Client 1]: 3766 samples
#   [Client 1] Top-2 classes for GAN: ['cat', 'frog'] [3, 6]
#   [Client 2]: 2587 samples
#   [Client 2] Top-2 classes for GAN: ['cat', 'frog'] [3, 6]
#   [Client 3]: 5760 samples
#   [Client 4]: 5691 samples
#   [Client 5]: 7494 samples
#   [Client 5] Top-2 classes for GAN: ['cat', 'frog'] [3, 6]
#   [Client 6]: 2628 samples
#   [Client 7]: 4624 samples
#   [Client 8]: 5996 samples
#   [Client 9]: 3949 samples
#   [FedAvg] Round 1 — Acc: 0.2456 | Loss: 2.1652
#   [FedAvg] Round 2 — Acc: 0.3792 | Loss: 1.7549
#   [FedAvg] Round 3 — Acc: 0.4203 | Loss: 1.6074
#   [FedAvg] Round 4 — Acc: 0.4589 | Loss: 1.4849
#   [FedAvg] Round 5 — Acc: 0.4336 | Loss: 1.5216
#   [FedAvg] Round 6 — Acc: 0.4675 | Loss: 1.4464
#   [FedAvg] Round 7 — Acc: 0.4851 | Loss: 1.4006
#   [FedAvg] Round 8 — Acc: 0.4836 | Loss: 1.3892
#   [FedAvg] Round 9 — Acc: 0.4996 | Loss: 1.3476
#   [FedAvg] Round 10 — Acc: 0.5354 | Loss: 1.2702
#   [FedAvg] Round 11 — Acc: 0.5273 | Loss: 1.2686
#   [FedAvg] Round 12 — Acc: 0.5469 | Loss: 1.2187
#   [FedAvg] Round 13 — Acc: 0.5495 | Loss: 1.2191
#   [FedAvg] Round 14 — Acc: 0.5583 | Loss: 1.1877
#   [FedAvg] Round 15 — Acc: 0.5861 | Loss: 1.1263
#   [FedAvg] Round 16 — Acc: 0.5679 | Loss: 1.1740
#   [FedAvg] Round 17 — Acc: 0.5891 | Loss: 1.1183
#   [FedAvg] Round 18 — Acc: 0.5896 | Loss: 1.0974
#   [FedAvg] Round 19 — Acc: 0.6061 | Loss: 1.0658
#   [FedAvg] Round 20 — Acc: 0.6083 | Loss: 1.0691
#   [FedAvg] Round 21 — Acc: 0.5997 | Loss: 1.1011
#   [FedAvg] Round 22 — Acc: 0.6259 | Loss: 1.0146
#   [FedAvg] Round 23 — Acc: 0.6286 | Loss: 1.0191
#   [FedAvg] Round 24 — Acc: 0.6325 | Loss: 1.0140
#   [FedAvg] Round 25 — Acc: 0.6397 | Loss: 0.9961
#   [FedAvg] Round 26 — Acc: 0.6389 | Loss: 0.9908
#   [FedAvg] Round 27 — Acc: 0.6531 | Loss: 0.9673
#   [FedAvg] Round 28 — Acc: 0.6590 | Loss: 0.9570
#   [FedAvg] Round 29 — Acc: 0.6507 | Loss: 0.9773
#   [FedAvg] Round 30 — Acc: 0.6624 | Loss: 0.9533
#   [FedAvg] Round 31 — Acc: 0.6640 | Loss: 0.9509
#   [FedAvg] Round 32 — Acc: 0.6608 | Loss: 0.9715
#   [FedAvg] Round 33 — Acc: 0.6621 | Loss: 0.9750
#   [FedAvg] Round 34 — Acc: 0.6707 | Loss: 0.9559
#   [FedAvg] Round 35 — Acc: 0.6706 | Loss: 0.9591
#   [FedAvg] Round 36 — Acc: 0.6658 | Loss: 0.9883
#   [FedAvg] Round 37 — Acc: 0.6701 | Loss: 0.9612
#   [FedAvg] Round 38 — Acc: 0.6825 | Loss: 0.9296
#   [FedAvg] Round 39 — Acc: 0.6818 | Loss: 0.9493
#   [FedAvg] Round 40 — Acc: 0.6810 | Loss: 0.9579
#   [FedAvg] Round 41 — Acc: 0.6804 | Loss: 0.9535
#   [FedAvg] Round 42 — Acc: 0.6881 | Loss: 0.9290
#   [FedAvg] Round 43 — Acc: 0.6822 | Loss: 0.9772
#   [FedAvg] Round 44 — Acc: 0.6904 | Loss: 0.9285
#   [FedAvg] Round 45 — Acc: 0.6911 | Loss: 0.9569
#   [FedAvg] Round 46 — Acc: 0.6911 | Loss: 0.9714
#   [FedAvg] Round 47 — Acc: 0.6921 | Loss: 0.9551
#   [FedAvg] Round 48 — Acc: 0.6935 | Loss: 0.9948
#   [FedAvg] Round 49 — Acc: 0.6844 | Loss: 1.0175
#   [FedAvg] Round 50 — Acc: 0.6923 | Loss: 1.0246
#
# ============================================================
#  Test 2  - Attack | Strategy: MOON | Mode: attack
# ============================================================
#   [Client 0]: 7505 samples
#   [Client 1]: 3766 samples
#   [Client 1] Top-2 classes for GAN: ['cat', 'frog'] [3, 6]
#   [Client 2]: 2587 samples
#   [Client 2] Top-2 classes for GAN: ['cat', 'frog'] [3, 6]
#   [Client 3]: 5760 samples
#   [Client 4]: 5691 samples
#   [Client 5]: 7494 samples
#   [Client 5] Top-2 classes for GAN: ['cat', 'frog'] [3, 6]
#   [Client 6]: 2628 samples
#   [Client 7]: 4624 samples
#   [Client 8]: 5996 samples
#   [Client 9]: 3949 samples
#   [MOON] Round 1 — Acc: 0.2248 | Loss: 2.2229  (mu=5.0, tau=0.5)
#   [MOON] Round 2 — Acc: 0.2722 | Loss: 2.0558  (mu=5.0, tau=0.5)
#   [MOON] Round 3 — Acc: 0.3012 | Loss: 1.9122  (mu=5.0, tau=0.5)
#   [MOON] Round 4 — Acc: 0.2917 | Loss: 1.9125  (mu=5.0, tau=0.5)
#   [MOON] Round 5 — Acc: 0.2913 | Loss: 1.8774  (mu=5.0, tau=0.5)
#   [MOON] Round 6 — Acc: 0.2676 | Loss: 1.8900  (mu=5.0, tau=0.5)
#   [MOON] Round 7 — Acc: 0.2854 | Loss: 1.8544  (mu=5.0, tau=0.5)
#   [MOON] Round 8 — Acc: 0.3293 | Loss: 1.7777  (mu=5.0, tau=0.5)
#   [MOON] Round 9 — Acc: 0.3102 | Loss: 1.7957  (mu=5.0, tau=0.5)
#   [MOON] Round 10 — Acc: 0.3385 | Loss: 1.7502  (mu=5.0, tau=0.5)
#   [MOON] Round 11 — Acc: 0.3252 | Loss: 1.7529  (mu=5.0, tau=0.5)
#   [MOON] Round 12 — Acc: 0.3379 | Loss: 1.7297  (mu=5.0, tau=0.5)
#   [MOON] Round 13 — Acc: 0.3474 | Loss: 1.6986  (mu=5.0, tau=0.5)
#   [MOON] Round 14 — Acc: 0.3410 | Loss: 1.7105  (mu=5.0, tau=0.5)
#   [MOON] Round 15 — Acc: 0.3334 | Loss: 1.7255  (mu=5.0, tau=0.5)
#   [MOON] Round 16 — Acc: 0.3389 | Loss: 1.6883  (mu=5.0, tau=0.5)
#   [MOON] Round 17 — Acc: 0.3223 | Loss: 1.7254  (mu=5.0, tau=0.5)
#   [MOON] Round 18 — Acc: 0.3339 | Loss: 1.6992  (mu=5.0, tau=0.5)
#   [MOON] Round 19 — Acc: 0.3458 | Loss: 1.6909  (mu=5.0, tau=0.5)
#   [MOON] Round 20 — Acc: 0.3841 | Loss: 1.6174  (mu=5.0, tau=0.5)
#   [MOON] Round 21 — Acc: 0.3841 | Loss: 1.6133  (mu=5.0, tau=0.5)
#   [MOON] Round 22 — Acc: 0.4017 | Loss: 1.5867  (mu=5.0, tau=0.5)
#   [MOON] Round 23 — Acc: 0.4175 | Loss: 1.5517  (mu=5.0, tau=0.5)
#   [MOON] Round 24 — Acc: 0.4151 | Loss: 1.5431  (mu=5.0, tau=0.5)
#   [MOON] Round 25 — Acc: 0.4044 | Loss: 1.5564  (mu=5.0, tau=0.5)
#   [MOON] Round 26 — Acc: 0.4415 | Loss: 1.4920  (mu=5.0, tau=0.5)
#   [MOON] Round 27 — Acc: 0.4384 | Loss: 1.4995  (mu=5.0, tau=0.5)
#   [MOON] Round 28 — Acc: 0.4309 | Loss: 1.5175  (mu=5.0, tau=0.5)
#   [MOON] Round 29 — Acc: 0.4419 | Loss: 1.5195  (mu=5.0, tau=0.5)
#   [MOON] Round 30 — Acc: 0.4191 | Loss: 1.5797  (mu=5.0, tau=0.5)
#   [MOON] Round 31 — Acc: 0.4414 | Loss: 1.5488  (mu=5.0, tau=0.5)
#   [MOON] Round 32 — Acc: 0.4374 | Loss: 1.5554  (mu=5.0, tau=0.5)
#   [MOON] Round 33 — Acc: 0.4752 | Loss: 1.4493  (mu=5.0, tau=0.5)
#   [MOON] Round 34 — Acc: 0.4714 | Loss: 1.4620  (mu=5.0, tau=0.5)
#   [MOON] Round 35 — Acc: 0.4838 | Loss: 1.4332  (mu=5.0, tau=0.5)
#   [MOON] Round 36 — Acc: 0.4961 | Loss: 1.3738  (mu=5.0, tau=0.5)
#   [MOON] Round 37 — Acc: 0.5185 | Loss: 1.3232  (mu=5.0, tau=0.5)
#   [MOON] Round 38 — Acc: 0.5377 | Loss: 1.2677  (mu=5.0, tau=0.5)
#   [MOON] Round 39 — Acc: 0.5269 | Loss: 1.2959  (mu=5.0, tau=0.5)
#   [MOON] Round 40 — Acc: 0.5478 | Loss: 1.2519  (mu=5.0, tau=0.5)
#   [MOON] Round 41 — Acc: 0.5519 | Loss: 1.2286  (mu=5.0, tau=0.5)
#   [MOON] Round 42 — Acc: 0.5456 | Loss: 1.2556  (mu=5.0, tau=0.5)
#   [MOON] Round 43 — Acc: 0.5580 | Loss: 1.2160  (mu=5.0, tau=0.5)
#   [MOON] Round 44 — Acc: 0.5725 | Loss: 1.2017  (mu=5.0, tau=0.5)
#   [MOON] Round 45 — Acc: 0.5638 | Loss: 1.1909  (mu=5.0, tau=0.5)
#   [MOON] Round 46 — Acc: 0.5815 | Loss: 1.1660  (mu=5.0, tau=0.5)
#   [MOON] Round 47 — Acc: 0.5792 | Loss: 1.1481  (mu=5.0, tau=0.5)
#   [MOON] Round 48 — Acc: 0.5805 | Loss: 1.1776  (mu=5.0, tau=0.5)
#   [MOON] Round 49 — Acc: 0.5880 | Loss: 1.1271  (mu=5.0, tau=0.5)
#   [MOON] Round 50 — Acc: 0.5963 | Loss: 1.1397  (mu=5.0, tau=0.5)
#
# All simulations complete!

# %% [markdown]
# ## Results Visualization

# %%
def plot_results(all_results: dict):
    test_names = list(all_results.keys())
    num_tests = len(test_names)

    fig, axes = plt.subplots(num_tests, 2, figsize=(14, 4 * num_tests))
    fig.suptitle('FedAvg vs MOON — CIFAR-10 Federated Learning\nEvaluation across Data Heterogeneity & Attacks',
                 fontsize=16, fontweight='bold', y=1.02)

    colors = {'FedAvg': '#2196F3', 'MOON': '#FF5722'}
    markers = {'FedAvg': 'o', 'MOON': 's'}

    for row, test_name in enumerate(test_names):
        ax_acc = axes[row][0] if num_tests > 1 else axes[0]
        ax_loss = axes[row][1] if num_tests > 1 else axes[1]

        plot_data = {}

        for strategy_name, metrics in all_results[test_name].items():
            if not metrics:
                continue
            rounds = [m['round'] for m in metrics]
            accs = [m['accuracy'] for m in metrics]
            losses = [m['loss'] for m in metrics]

            plot_data[strategy_name] = (rounds, accs, losses)

            color = colors[strategy_name]
            marker = markers[strategy_name]
            final_acc = accs[-1] if accs else 0

            ax_acc.plot(rounds, accs, color=color, marker=marker,
                        label=f'{strategy_name} (final: {final_acc:.3f})',
                        linewidth=2.5, markersize=6)
            ax_loss.plot(rounds, losses, color=color, marker=marker,
                         label=strategy_name, linewidth=2.5, markersize=6)

        # Accuracy styling
        ax_acc.set_title(f'{test_name}: Accuracy', fontweight='bold', fontsize=12)
        ax_acc.set_xlabel('Round')
        ax_acc.set_ylabel('Accuracy')
        ax_acc.set_ylim(0, 1.0)
        ax_acc.legend(loc='lower right')
        ax_acc.grid(True, linestyle='--', alpha=0.6)

        # Loss styling
        ax_loss.set_title(f'{test_name}: Loss', fontweight='bold', fontsize=12)
        ax_loss.set_xlabel('Round')
        ax_loss.set_ylabel('Loss')
        ax_loss.legend(loc='upper right')
        ax_loss.grid(True, linestyle='--', alpha=0.6)

    plt.tight_layout()
    plt.show()

# Call the updated function
plot_results(all_results)

# %% [markdown]
# ## Plot Divergence

# %%
def plot_divergence(divergence_history, metric='l2'):
    test_names     = list(divergence_history.keys())
    strategy_names = ['FedAvg', 'MOON']
    colors         = [f'C{i}' for i in range(NUM_CLIENTS)]

    fig, axes = plt.subplots(len(test_names), 2, figsize=(14, 4 * len(test_names)))
    if len(test_names) == 1:
        axes = [axes]

    for row, test_name in enumerate(test_names):
        for col, sname in enumerate(strategy_names):
            ax      = axes[row][col]
            div_log = divergence_history[test_name].get(sname, {})
            if not div_log:
                ax.set_visible(False)
                continue

            rounds   = sorted(div_log.keys())
            all_cids = sorted({cid for rd in div_log.values() for cid in rd})

            for cid in all_cids:
                vals = [div_log[r].get(cid, {}).get(metric, np.nan) for r in rounds]
                ax.plot(rounds, vals, marker='o', markersize=4,
                        label=f'Client {cid}', color=colors[cid])

            ylabel = {'l2': 'L2 ‖local − global‖',
                      'cosine': 'Cosine Distance'}[metric]

            ax.set_title(f'{test_name} | {sname} — {ylabel}', fontweight='bold')
            ax.set_xlabel('Round')
            ax.set_ylabel(ylabel)
            ax.legend(loc='upper right', fontsize=8)
            ax.grid(True, linestyle='--', alpha=0.5)

    plt.tight_layout()
    plt.show()

plot_divergence(divergence_history, metric='l2')
plot_divergence(divergence_history, metric='cosine')

# %% [markdown]
# ## Plot Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

def plot_confusion_matrices_over_rounds(snapshots):
    test_loader    = DataLoader(CIFAR10_TEST, batch_size=256, shuffle=False)
    strategy_names = ['FedAvg', 'MOON']

    for test_name in snapshots:
        for sname in strategy_names:
            snap = snapshots[test_name].get(sname, {})
            if not snap:
                continue

            rounds = sorted(snap.keys())
            n_cols = len(rounds)
            fig, axes = plt.subplots(1, n_cols, figsize=(5 * n_cols, 5))
            if n_cols == 1:
                axes = [axes]

            fig.suptitle(f'{test_name} | {sname} — Confusion Matrix per Round',
                         fontweight='bold', fontsize=13)

            for ax, rnd in zip(axes, rounds):
                model = CifarCNN().to(DEVICE)
                set_parameters(model, snap[rnd])
                model.eval()

                all_preds, all_labels = [], []
                with torch.no_grad():
                    for images, labels in test_loader:
                        preds = model(images.to(DEVICE)).argmax(dim=1).cpu().numpy()
                        all_preds.extend(preds)
                        all_labels.extend(labels.numpy())

                cm      = confusion_matrix(all_labels, all_preds)
                cm_norm = cm.astype(float) / cm.sum(axis=1, keepdims=True)

                sns.heatmap(cm_norm, annot=True, fmt='.2f', ax=ax,
                            cmap='Blues', xticklabels=CLASSES, yticklabels=CLASSES,
                            linewidths=0.3, vmin=0, vmax=1, cbar=False)
                acc = np.diag(cm_norm).mean()
                ax.set_title(f'Round {rnd}\nacc={acc:.3f}', fontsize=10)
                ax.set_xlabel('Predicted')
                ax.set_ylabel('True' if rnd == rounds[0] else '')

            plt.tight_layout()
            plt.show()

plot_confusion_matrices_over_rounds(snapshots)

# %% [markdown]
# ## Summary Table

# %%
print(f'\n{"="*65}')
print(f'  FINAL RESULTS SUMMARY')
print(f'{"="*65}')
print(f'{"Test":<35} {"Strategy":<10} {"Final Acc":>10} {"Final Loss":>12}')
print(f'{"-"*65}')

for test_name, strategies in all_results.items():
    for strategy_name, metrics in strategies.items():
        if metrics:
            final = metrics[-1]
            print(f'{test_name:<35} {strategy_name:<10} '
                  f'{final["accuracy"]:>10.4f} {final["loss"]:>12.4f}')
        else:
            print(f'{test_name:<35} {strategy_name:<10} {"N/A":>10} {"N/A":>12}')

print(f'{"="*65}')
# Out:
# =================================================================
#   FINAL RESULTS SUMMARY
# =================================================================
# Test                                Strategy    Final Acc   Final Loss
# -----------------------------------------------------------------
# Test 1  - Non-iid                   FedAvg         0.7315       0.9535
# Test 1  - Non-iid                   MOON           0.6343       1.1021
# Test 2  - Attack                    FedAvg         0.6923       1.0246
# Test 2  - Attack                    MOON           0.5963       1.1397
# =================================================================
