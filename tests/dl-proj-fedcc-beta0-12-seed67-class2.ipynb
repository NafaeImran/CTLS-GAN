# %% [markdown]
# # Federated Learning Experiments: FedAvg vs FedCC
#
# **10 Clients | CIFAR-10**
#
# ## Tests:
# | Test | Description |
# |------|-------------|
# | Test 1 | Non-IID run — all clients get Non-IID CIFAR-10 data |
# | Test 2 | Attack run — Clients 1,2,5 have sythetic data added in to create distribution skew  |
#
#
# Both **FedAvg** and **FedCC** are run on each test for comparison.

# %% [markdown]
# ## Install Dependencies
#
# ---

# %%
# !pip install torch torchvision numpy matplotlib scikit-learn seaborn -q

# %% [markdown]
# ## Imports & Config

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Subset
import torchvision
import torchvision.transforms as transforms
import numpy as np
import matplotlib.pyplot as plt
from typing import List, Tuple, Dict, Optional
from collections import OrderedDict
from functools import reduce
import os, warnings, logging

warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", message=".*upfirdn2d.*")
warnings.filterwarnings("ignore", message=".*bias_act.*")

NUM_CLIENTS = 10
NUM_ROUNDS = 50
LOCAL_EPOCHS= 2
BATCH_SIZE= 256
LEARNING_RATE= 0.001
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

ATTACK_CLIENT_ID   = [1, 5, 2]
GAN_WARMUP_ROUNDS = 0
BETA =0.12# gans ramp up rate
SEED=67 

n_top = 2  # CHANGE THIS to your desired n everywhere

print(f'Device: {DEVICE}')
# Out:
# Device: cuda

# %% [markdown]
# ## CNN Model (CIFAR-10)

# %%
class CifarCNN(nn.Module):
    def __init__(self):
        super(CifarCNN, self).__init__()
        self.conv_block = nn.Sequential(
            nn.Conv2d(3, 32, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(32, 64, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(64, 64, 3, padding=1),
            nn.ReLU()
        )
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(64 * 8 * 8, 256),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, 10)
        )

    def forward(self, x):
        return self.classifier(self.conv_block(x))


def get_parameters(model):
    return [val.cpu().numpy() for val in model.state_dict().values()]


def set_parameters(model, parameters):
    params_dict = zip(model.state_dict().keys(), parameters)
    state_dict = OrderedDict({k: torch.tensor(v) for k, v in params_dict})
    model.load_state_dict(state_dict, strict=True)


print('Model defined. Parameter count:',
      sum(p.numel() for p in CifarCNN().parameters()))
# Out:
# Model defined. Parameter count: 1107722

# %% [markdown]
# ## Data Loading Setup

# %%
from collections import Counter

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

CIFAR10_TRAIN = torchvision.datasets.CIFAR10(
    root='./data', train=True, download=True, transform=transform
)
CIFAR10_TEST = torchvision.datasets.CIFAR10(
    root='./data', train=False, download=True, transform=transform
)

CLASSES = ['airplane','automobile','bird','cat','deer',
           'dog','frog','horse','ship','truck']

def get_all_non_iid_partitions(dataset, num_clients, alpha=0.5):
    np.random.seed(SEED)
    labels = np.array([label for _, label in dataset])
    num_classes = len(np.unique(labels))
    client_indices = [[] for _ in range(num_clients)]
    for k in range(num_classes):
        idx_k = np.where(labels == k)[0]
        np.random.shuffle(idx_k)
        proportions = np.random.dirichlet([alpha] * num_clients)
        splits = (np.cumsum(proportions) * len(idx_k)).astype(int)[:-1]
        for i, chunk in enumerate(np.split(idx_k, splits)):
            client_indices[i].append(chunk)
    return [
        Subset(dataset, np.concatenate(client_indices[i]).tolist())
        for i in range(num_clients)
    ]

ALL_PARTITIONS = get_all_non_iid_partitions(CIFAR10_TRAIN, NUM_CLIENTS, alpha=0.5)

def load_client_data(client_id: int) -> Tuple[DataLoader, DataLoader]:
    train_subset = ALL_PARTITIONS[client_id]
    print(f'  [Client {client_id}]: {len(train_subset)} samples')
    train_loader = DataLoader(train_subset, batch_size=BATCH_SIZE, shuffle=True)
    test_loader  = DataLoader(CIFAR10_TEST,  batch_size=BATCH_SIZE, shuffle=False)
    return train_loader, test_loader

def get_top_n_classes(subset, n=1):
    labels = [subset.dataset.targets[i] for i in subset.indices]
    return [cls for cls, _ in Counter(labels).most_common(n)]

print('Data utilities ready.')
print(f'CIFAR-10 train size: {len(CIFAR10_TRAIN)} | test size: {len(CIFAR10_TEST)}')
# Out:
# 100%|██████████| 170M/170M [07:04<00:00, 401kB/s]
# Data utilities ready.
# CIFAR-10 train size: 50000 | test size: 10000

# %% [markdown]
# ## Pre-trained GANS Setup

# %%
# !git clone https://github.com/NVlabs/stylegan2-ada-pytorch.git
import pickle, requests, os,sys,contextlib
sys.path.insert(0, './stylegan2-ada-pytorch')
stylegan_path = "/kaggle/working/stylegan2-ada-pytorch"

if stylegan_path not in sys.path:
    sys.path.append(stylegan_path)


weights_url = 'https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/cifar10.pkl'
weights_path = 'cifar10.pkl'

if not os.path.exists(weights_path):
    print('Downloading StyleGAN2-ADA CIFAR-10 weights...')
    r = requests.get(weights_url, stream=True)
    with open(weights_path, 'wb') as f:
        for chunk in r.iter_content(chunk_size=8192):
            f.write(chunk)
    print('Done.')

with contextlib.redirect_stderr(open(os.devnull, 'w')), \
     contextlib.redirect_stdout(open(os.devnull, 'w')):
    with open(weights_path, 'rb') as f:
        data = pickle.load(f)
    stylegan_G = data['G_ema'].to(DEVICE)

print('StyleGAN2-ADA generator loaded.')
print(f'  z_dim: {stylegan_G.z_dim} | c_dim: {stylegan_G.c_dim} | img resolution: {stylegan_G.img_resolution}')



def stylegan_generate(class_idx, n_images, truncation_psi=0.7):
    with contextlib.redirect_stderr(open(os.devnull, 'w')), \
         contextlib.redirect_stdout(open(os.devnull, 'w')):
        with torch.no_grad():
            z = torch.randn(n_images, stylegan_G.z_dim).to(DEVICE)
            c = torch.zeros(n_images, stylegan_G.c_dim).to(DEVICE)
            c[:, class_idx] = 1.0
            imgs = stylegan_G(z, c, truncation_psi=truncation_psi)
            imgs = (imgs * 0.5 + 0.5).clamp(0, 1)
            imgs = (imgs - 0.5) / 0.5
    return imgs
warnings.filterwarnings("ignore", category=UserWarning, module="torch_utils")
# Out:
# Cloning into 'stylegan2-ada-pytorch'...
# remote: Enumerating objects: 131, done.
# remote: Counting objects: 100% (2/2), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 131 (delta 0), reused 0 (delta 0), pack-reused 129 (from 2)
# Receiving objects: 100% (131/131), 1.13 MiB | 16.31 MiB/s, done.
# Resolving deltas: 100% (57/57), done.
# Downloading StyleGAN2-ADA CIFAR-10 weights...
# Done.
# StyleGAN2-ADA generator loaded.
#   z_dim: 512 | c_dim: 10 | img resolution: 32

# %% [markdown]
# ## Conditoioning on Client classes

# %%
topn = get_top_n_classes(ALL_PARTITIONS[ATTACK_CLIENT_ID[0]], n=n_top)
print(f'Attacker top-{n_top} classes: {[CLASSES[c] for c in topn]} {topn}')
print('StyleGAN2-ADA will generate only these classes during attack.')
# Out:
# Attacker top-2 classes: ['cat', 'frog'] [3, 6]
# StyleGAN2-ADA will generate only these classes during attack.

# %% [markdown]
# ## GANS Visualization

# %%
import torchvision.utils as vutils
fig, axes = plt.subplots(1, n_top, figsize=(6 * n_top, 5))
axes = [axes] if n_top == 1 else list(axes)

for ax, cls in zip(axes, topn):
    imgs = stylegan_generate(cls, 16, truncation_psi=0.7)
    imgs = (imgs * 0.5 + 0.5).clamp(0, 1)
    grid = vutils.make_grid(imgs, nrow=4, padding=2)
    ax.imshow(grid.permute(1, 2, 0).cpu())
    ax.set_title(f'StyleGAN2 generated: {CLASSES[cls]}', fontweight='bold')
    ax.axis('off')

plt.suptitle('Attack Image Quality Check', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Training and Evaluation Setup

# %%
def train_one_round(model, train_loader, epochs,current_round, client_id, mode='non-iid', topn_classes=None):
    model.to(DEVICE)
    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
    criterion = nn.CrossEntropyLoss()

    is_malicious = (mode == 'attack' and client_id in ATTACK_CLIENT_ID)



    model.train()
    for epoch in range(epochs):
        for images, labels in train_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            batch_size = images.size(0)

            if is_malicious and topn_classes is not None:
              if current_round > GAN_WARMUP_ROUNDS:
                  skew_ratio = min(0.3 + BETA  * current_round, 0.9)
                  n_skew = int(batch_size * skew_ratio)
                  n_real = batch_size - n_skew

                  idx = torch.randint(0, len(topn_classes), (1,)).item()
                  chosen_class = topn_classes[idx]

                  with torch.no_grad():
                      gan_images = stylegan_generate(chosen_class, n_skew).detach()
                  gan_labels = torch.full((n_skew,), chosen_class, dtype=torch.long, device=DEVICE)

                  images = torch.cat([images[:n_real], gan_images], dim=0)
                  labels = torch.cat([labels[:n_real], gan_labels], dim=0)

            optimizer.zero_grad()
            outputs = model(images)
            loss    = criterion(outputs, labels)
            loss.backward()
            optimizer.step()


def evaluate_model(model, test_loader):
    model.to(DEVICE)
    criterion = nn.CrossEntropyLoss()
    model.eval()
    total_loss, correct, total = 0.0, 0, 0
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE)
            outputs = model(images)
            total_loss += criterion(outputs, labels).item()
            predicted = outputs.argmax(dim=1)
            correct += (predicted == labels).sum().item()
            total   += labels.size(0)
    return total_loss / len(test_loader), correct / total

# %% [markdown]
# ## FL Client Class

# %%
class FLClient:

    def __init__(self, client_id: int, mode: str = 'non-iid'):
        self.client_id   = client_id
        self.mode        = mode
        self.model       = CifarCNN()
        self.train_loader, self.test_loader = load_client_data(client_id)

        import sys
        stylegan_path = "/kaggle/working/stylegan2-ada-pytorch"
        if stylegan_path not in sys.path:
            sys.path.insert(0, stylegan_path)

        # Pre-compute top-n classes for the malicious client
        if mode == 'attack' and client_id in ATTACK_CLIENT_ID:
            self.topn_classes = get_top_n_classes(ALL_PARTITIONS[ATTACK_CLIENT_ID[0]], n=n_top)
            print(f'  [Client {client_id}] Top-{n_top} classes for GAN: '
                  f'{[CLASSES[c] for c in self.topn_classes]} {self.topn_classes}')
        else:
            self.topn_classes = None

    def get_parameters(self):
        return get_parameters(self.model)

    def fit(self, parameters, local_epochs=LOCAL_EPOCHS, current_round=0):
        set_parameters(self.model, parameters)
        train_one_round(self.model, self.train_loader,
                        local_epochs, current_round,
                        self.client_id, self.mode, self.topn_classes)
        return (get_parameters(self.model),
                len(self.train_loader.dataset),
                {'client_id': self.client_id, 'mode': self.mode})

    def evaluate(self, parameters):
        set_parameters(self.model, parameters)
        loss, accuracy = evaluate_model(self.model, self.test_loader)
        return (float(loss),
                len(self.test_loader.dataset),
                {'accuracy': float(accuracy), 'client_id': self.client_id})


print('FLClient class defined.')
# Out:
# FLClient class defined.

# %% [markdown]
# ## Divergence calculation

# %%
divergence_history = {}   # {test_name: {strategy_name: {round: {cid: {l2, cosine}}}}}

def l2_divergence(local_params, global_params):
    return float(np.sqrt(sum(
        np.sum((lp - gp) ** 2)
        for lp, gp in zip(local_params, global_params)
    )))

def cosine_divergence(local_params, global_params):
   
    local_vec  = np.concatenate([p.ravel() for p in local_params])
    global_vec = np.concatenate([p.ravel() for p in global_params])

    dot    = np.dot(local_vec, global_vec)
    norm_l = np.linalg.norm(local_vec)
    norm_g = np.linalg.norm(global_vec)

    denom = norm_l * norm_g
    if denom < 1e-10:
        return 0.0
    return float(dot / denom)

def compute_divergence(local_params, global_params):
    local_flat  = np.concatenate([p.ravel() for p in local_params])
    global_flat = np.concatenate([p.ravel() for p in global_params])

    l2 = float(np.sqrt(np.sum((local_flat - global_flat) ** 2)))

    denom = np.linalg.norm(local_flat) * np.linalg.norm(global_flat)
    cosine = float(1.0 - np.dot(local_flat, global_flat) / denom) if denom > 1e-10 else 0.0

    return {'l2': l2, 'cosine': cosine}

def add_divergence_tracking(strategy, div_log):
    strategy._div_log = div_log
    return strategy

def add_param_snapshots(strategy, snapshot_log, every_n=10):
    strategy._snapshot_log = snapshot_log
    strategy._snapshot_every_n = every_n
    return strategy

# %% [markdown]
# ## FedAvg Setup

# %%
class FedAvgStrategy:

    def __init__(self, round_metrics: list):
        self.round_metrics  = round_metrics
        self._global_params = None
        self._div_log         = {}
        self._snapshot_log    = {}
        self._snapshot_every_n = 10

    def aggregate_fit(self, server_round: int, results: list) -> list:
        if not results:
            return self._global_params

        total_samples = sum(n for _, n, _ in results)
        aggregated = [
            sum(params[i] * n / total_samples for params, n, _ in results)
            for i in range(len(results[0][0]))
        ]
        self._global_params = aggregated
        return aggregated

    def aggregate_evaluate(self, server_round: int, results: list):
        if not results:
            return None, {}

        total_samples = sum(n for _, n, _ in results)
        weighted_acc  = sum(m['accuracy'] * n for _, n, m in results) / total_samples
        weighted_loss = sum(loss * n for loss, n, _ in results) / total_samples

        self.round_metrics.append({
            'round': server_round,
            'accuracy': weighted_acc,
            'loss': weighted_loss
        })

        print(f'  [FedAvg] Round {server_round} — '
              f'Acc: {weighted_acc:.4f} | Loss: {weighted_loss:.4f}')

        return weighted_loss, {'accuracy': weighted_acc}


def build_fedavg_strategy(round_metrics: list) -> FedAvgStrategy:
    return FedAvgStrategy(round_metrics)


print('FedAvg strategy builder defined.')
# Out:
# FedAvg strategy builder defined.

# %% [markdown]
# ## FedCC Setup

# %%
import math
import numpy as np
from collections import Counter, OrderedDict
from sklearn.cluster import KMeans

def _centering(K: np.ndarray) -> np.ndarray:
    n = K.shape[0]
    H = np.eye(n) - np.ones((n, n)) / n
    return H @ K @ H


def _rbf(X: np.ndarray, sigma=None) -> np.ndarray:
    GX = np.dot(X, X.T)
    diag_GX = np.diag(GX)
    KX = diag_GX[:, None] - GX + (diag_GX[:, None] - GX).T   # squared distances
    if sigma is None:
        nonzero = KX[KX != 0]
        mdist   = np.median(nonzero) if nonzero.size > 0 else 1.0
        sigma   = math.sqrt(mdist)
    sigma = max(sigma, 1e-10)
    KX = KX * (-0.5 / (sigma * sigma))
    return np.exp(KX)


def _kernel_HSIC(X: np.ndarray, Y: np.ndarray, sigma=None) -> float:
    return float(np.sum(_centering(_rbf(X, sigma)) * _centering(_rbf(Y, sigma))))


def _kernel_CKA(X: np.ndarray, Y: np.ndarray, sigma=None) -> float:
    hsic = _kernel_HSIC(X, Y, sigma)
    var1 = math.sqrt(_kernel_HSIC(X, X, sigma))
    var2 = math.sqrt(_kernel_HSIC(Y, Y, sigma))
    denom = var1 * var2
    if denom < 1e-10:
        return 0.0
    return float(hsic / denom)


class FedCC:

    def __init__(self, round_metrics: list):
        self.round_metrics   = round_metrics
        self._global_params  = None
        self._div_log         = {}
        self._snapshot_log    = {}
        self._snapshot_every_n = 10

    def aggregate_fit(self, server_round: int, results: list) -> list:
        if not results:
            return self._global_params

        all_params = [params for params, _, _ in results]
        num_clients = len(all_params)

        model_ref  = CifarCNN()
        keys       = list(model_ref.state_dict().keys())

        plr_idx = len(keys) - 4

        if self._global_params is None:
            self._global_params = [
                np.mean([p[i] for p in all_params], axis=0)
                for i in range(len(all_params[0]))
            ]

        glob_plr = self._global_params[plr_idx]

        similarities = []
        for params in all_params:
            local_plr = params[plr_idx]
            val = _kernel_CKA(glob_plr, local_plr)
            similarities.append(0.0 if np.isnan(val) else val)

        similarities = np.array(similarities)
        print(f'\n  [FedCC] Round {server_round} — CKA scores per client:')
        for i, s in enumerate(similarities):
            print(f'    Client {i}: {s:.4f}')

        kmeans = KMeans(n_clusters=2, random_state=0, n_init=10).fit(
            similarities.reshape(-1, 1)
        )
        labels  = kmeans.labels_
        counter = Counter(labels)

        exp_sim  = np.exp(similarities)
        norm_sim = exp_sim / exp_sim.sum()

        larger_cluster        = 1 if counter[1] > counter[0] else 0
        larger_cluster_idx    = np.where(labels == larger_cluster)[0]
        smaller_cluster_idx   = np.where(labels != larger_cluster)[0]

        larger_sim         = norm_sim[larger_cluster_idx]
        larger_sim_normed  = larger_sim / larger_sim.sum()

        print(f'  [FedCC] Cluster sizes: {counter[0]} (label 0) | '
              f'{counter[1]} (label 1)  →  trusted = label {larger_cluster}')
        for i in larger_cluster_idx:
            print(f'    Client {i} | CKA={similarities[i]:.4f} | TRUSTED')
        for i in smaller_cluster_idx:
            print(f'    Client {i} | CKA={similarities[i]:.4f} | FILTERED')

        excluded_keys = set(keys[-4:])

        seg_A, seg_B, seg_C = [], [], []
        for params in all_params:
            A = np.concatenate([
                params[i].ravel()
                for i, k in enumerate(keys)
                if k not in excluded_keys
            ])
            B = np.concatenate([params[len(keys) - 4].ravel(),
                                 params[len(keys) - 3].ravel()])
            C = np.concatenate([params[len(keys) - 2].ravel(),
                                 params[len(keys) - 1].ravel()])
            seg_A.append(A)
            seg_B.append(B)
            seg_C.append(C)

        seg_A = np.stack(seg_A)
        seg_B = np.stack(seg_B)
        seg_C = np.stack(seg_C)

        agg_A = np.zeros(seg_A.shape[1])
        for idx in range(num_clients):
            agg_A += norm_sim[idx] * seg_A[idx]

        agg_B = np.zeros(seg_B.shape[1])
        for rank, client_idx in enumerate(larger_cluster_idx):
            agg_B += larger_sim_normed[rank] * seg_B[client_idx]

        agg_C = np.zeros(seg_C.shape[1])
        for idx in range(num_clients):
            agg_C += norm_sim[idx] * seg_C[idx]

        aggregated: List[np.ndarray] = []
        ptr_A, ptr_B, ptr_C = 0, 0, 0
        for i, k in enumerate(keys):
            shape = self._global_params[i].shape
            numel = int(np.prod(shape))
            if k not in excluded_keys:
                aggregated.append(agg_A[ptr_A: ptr_A + numel].reshape(shape))
                ptr_A += numel
            elif k == keys[-4] or k == keys[-3]:
                aggregated.append(agg_B[ptr_B: ptr_B + numel].reshape(shape))
                ptr_B += numel
            else:
                aggregated.append(agg_C[ptr_C: ptr_C + numel].reshape(shape))
                ptr_C += numel

        self._global_params = aggregated

        print(f'  [FedCC] Round {server_round} — '
              f'{len(larger_cluster_idx)}/{num_clients} clients trusted')

        return aggregated

    def aggregate_evaluate(self, server_round: int, results: list):
        if not results:
            return None, {}
        total_samples = sum(n for _, n, _ in results)
        weighted_acc  = sum(m['accuracy'] * n for _, n, m in results) / total_samples
        weighted_loss = sum(loss * n for loss, n, _ in results) / total_samples
        self.round_metrics.append({
            'round': server_round,
            'accuracy': weighted_acc,
            'loss': weighted_loss
        })

        print(f'  [FedCC] Round {server_round} — Acc: {weighted_acc:.4f} | Loss: {weighted_loss:.4f}')

        return weighted_loss, {'accuracy': weighted_acc}


def build_fedcc_strategy(round_metrics: list) -> FedCC:
    return FedCC(round_metrics=round_metrics)

# %% [markdown]
# ## Simulation Runner

# %%
def run_simulation(test_name: str,
                   mode: str,
                   strategy_name: str,
                   strategy) -> None:

    print(f'\n{"="*60}')
    print(f' {test_name} | Strategy: {strategy_name} | Mode: {mode}')
    print(f'{"="*60}')

    clients = [FLClient(client_id=cid, mode=mode) for cid in range(NUM_CLIENTS)]

    global_params = clients[0].get_parameters()
    strategy._global_params = [p.copy() for p in global_params]

    div_log      = getattr(strategy, '_div_log',         {})
    snapshot_log = getattr(strategy, '_snapshot_log',    {})
    every_n      = getattr(strategy, '_snapshot_every_n', 10)

    for server_round in range(1, NUM_ROUNDS + 1):

        global_snap_before = [p.copy() for p in global_params]

        fit_results = []
        for client in clients:
            params, n_samples, metrics = client.fit(
                global_params,
                local_epochs=LOCAL_EPOCHS,
                current_round=server_round
            )
            fit_results.append((params, n_samples, metrics))

        round_divs = {}
        for (local_params, _, meta) in fit_results:
            cid = meta.get('client_id', -1)
            round_divs[cid] = compute_divergence(local_params, global_snap_before)
        div_log[server_round] = round_divs

  
        global_params = strategy.aggregate_fit(server_round, fit_results)


        if server_round % every_n == 0:
            snapshot_log[server_round] = [p.copy() for p in global_params]

        
        eval_results = []
        for client in clients:
            loss, n_samples, metrics = client.evaluate(global_params)
            eval_results.append((loss, n_samples, metrics))

        strategy.aggregate_evaluate(server_round, eval_results)


print('Simulation runner defined.')
# Out:
# Simulation runner defined.

# %% [markdown]
# ## Run All Tests
#
# > **This is the main execution cell.**
# > Runs 8 simulations total: 4 tests × 2 strategies.
# > Results are stored in `all_results` for plotting.

# %%
all_results        = {}
divergence_history = {}
snapshots          = {}
final_params       = {}

    

TESTS = [
    ('Test 1  - Non-iid',   'non-iid'),
    ('Test 2  - Attack',   'attack'),
    


]


for test_name, mode in TESTS:
    all_results[test_name]        = {}
    divergence_history[test_name] = {}
    snapshots[test_name]          = {}
    final_params[test_name]       = {}

    for strategy_name in ['FedAvg', 'FedCC']:
        metrics      = []
        div_log      = {}
        snapshot_log = {}

        divergence_history[test_name][strategy_name] = div_log
        snapshots[test_name][strategy_name]          = snapshot_log

        if strategy_name == 'FedAvg':
            strategy = build_fedavg_strategy(metrics)
        else:
            strategy = build_fedcc_strategy(metrics)

        add_divergence_tracking(strategy, div_log)
        add_param_snapshots(strategy, snapshot_log, every_n=10)

        run_simulation(test_name, mode, strategy_name, strategy)

        all_results[test_name][strategy_name]  = metrics
        final_params[test_name][strategy_name] = strategy._global_params

print('\nAll simulations complete!')
# Out:
# ============================================================
#  Test 1  - Non-iid | Strategy: FedAvg | Mode: non-iid
# ============================================================
#   [Client 0]: 7505 samples
#   [Client 1]: 3766 samples
#   [Client 2]: 2587 samples
#   [Client 3]: 5760 samples
#   [Client 4]: 5691 samples
#   [Client 5]: 7494 samples
#   [Client 6]: 2628 samples
#   [Client 7]: 4624 samples
#   [Client 8]: 5996 samples
#   [Client 9]: 3949 samples
#   [FedAvg] Round 1 — Acc: 0.2765 | Loss: 2.1501
#   [FedAvg] Round 2 — Acc: 0.4200 | Loss: 1.6660
#   [FedAvg] Round 3 — Acc: 0.4515 | Loss: 1.5217
#   [FedAvg] Round 4 — Acc: 0.4892 | Loss: 1.4286
#   [FedAvg] Round 5 — Acc: 0.5089 | Loss: 1.3605
#   [FedAvg] Round 6 — Acc: 0.5397 | Loss: 1.2965
#   [FedAvg] Round 7 — Acc: 0.5562 | Loss: 1.2418
#   [FedAvg] Round 8 — Acc: 0.5696 | Loss: 1.2030
#   [FedAvg] Round 9 — Acc: 0.5836 | Loss: 1.1572
#   [FedAvg] Round 10 — Acc: 0.5989 | Loss: 1.1306
#   [FedAvg] Round 11 — Acc: 0.6119 | Loss: 1.0861
#   [FedAvg] Round 12 — Acc: 0.6250 | Loss: 1.0525
#   [FedAvg] Round 13 — Acc: 0.6313 | Loss: 1.0250
#   [FedAvg] Round 14 — Acc: 0.6417 | Loss: 1.0019
#   [FedAvg] Round 15 — Acc: 0.6510 | Loss: 0.9815
#   [FedAvg] Round 16 — Acc: 0.6568 | Loss: 0.9571
#   [FedAvg] Round 17 — Acc: 0.6639 | Loss: 0.9411
#   [FedAvg] Round 18 — Acc: 0.6728 | Loss: 0.9201
#   [FedAvg] Round 19 — Acc: 0.6784 | Loss: 0.9112
#   [FedAvg] Round 20 — Acc: 0.6819 | Loss: 0.8928
#   [FedAvg] Round 21 — Acc: 0.6873 | Loss: 0.8875
#   [FedAvg] Round 22 — Acc: 0.6885 | Loss: 0.8816
#   [FedAvg] Round 23 — Acc: 0.6961 | Loss: 0.8654
#   [FedAvg] Round 24 — Acc: 0.6988 | Loss: 0.8604
#   [FedAvg] Round 25 — Acc: 0.7021 | Loss: 0.8538
#   [FedAvg] Round 26 — Acc: 0.7062 | Loss: 0.8470
#   [FedAvg] Round 27 — Acc: 0.7081 | Loss: 0.8424
#   [FedAvg] Round 28 — Acc: 0.7096 | Loss: 0.8424
#   [FedAvg] Round 29 — Acc: 0.7114 | Loss: 0.8457
#   [FedAvg] Round 30 — Acc: 0.7120 | Loss: 0.8439
#   [FedAvg] Round 31 — Acc: 0.7118 | Loss: 0.8486
#   [FedAvg] Round 32 — Acc: 0.7172 | Loss: 0.8451
#   [FedAvg] Round 33 — Acc: 0.7174 | Loss: 0.8484
#   [FedAvg] Round 34 — Acc: 0.7213 | Loss: 0.8417
#   [FedAvg] Round 35 — Acc: 0.7183 | Loss: 0.8536
#   [FedAvg] Round 36 — Acc: 0.7213 | Loss: 0.8579
#   [FedAvg] Round 37 — Acc: 0.7248 | Loss: 0.8588
#   [FedAvg] Round 38 — Acc: 0.7235 | Loss: 0.8687
#   [FedAvg] Round 39 — Acc: 0.7231 | Loss: 0.8718
#   [FedAvg] Round 40 — Acc: 0.7225 | Loss: 0.8900
#   [FedAvg] Round 41 — Acc: 0.7222 | Loss: 0.8937
#   [FedAvg] Round 42 — Acc: 0.7250 | Loss: 0.8942
#   [FedAvg] Round 43 — Acc: 0.7238 | Loss: 0.8985
#   [FedAvg] Round 44 — Acc: 0.7244 | Loss: 0.9106
#   [FedAvg] Round 45 — Acc: 0.7272 | Loss: 0.9153
#   [FedAvg] Round 46 — Acc: 0.7277 | Loss: 0.9161
#   [FedAvg] Round 47 — Acc: 0.7249 | Loss: 0.9361
#   [FedAvg] Round 48 — Acc: 0.7279 | Loss: 0.9366
#   [FedAvg] Round 49 — Acc: 0.7281 | Loss: 0.9474
#   [FedAvg] Round 50 — Acc: 0.7241 | Loss: 0.9690
#
# ============================================================
#  Test 1  - Non-iid | Strategy: FedCC | Mode: non-iid
# ============================================================
#   [Client 0]: 7505 samples
#   [Client 1]: 3766 samples
#   [Client 2]: 2587 samples
#   [Client 3]: 5760 samples
#   [Client 4]: 5691 samples
#   [Client 5]: 7494 samples
#   [Client 6]: 2628 samples
#   [Client 7]: 4624 samples
#   [Client 8]: 5996 samples
#   [Client 9]: 3949 samples
#
#   [FedCC] Round 1 — CKA scores per client:
#     Client 0: 0.4784
#     Client 1: 0.6289
#     Client 2: 0.5856
#     Client 3: 0.5384
#     Client 4: 0.5727
#     Client 5: 0.4499
#     Client 6: 0.6545
#     Client 7: 0.5209
#     Client 8: 0.5291
#     Client 9: 0.6283
#   [FedCC] Cluster sizes: 5 (label 0) | 5 (label 1)  →  trusted = label 0
#     Client 0 | CKA=0.4784 | TRUSTED
#     Client 3 | CKA=0.5384 | TRUSTED
#     Client 5 | CKA=0.4499 | TRUSTED
#     Client 7 | CKA=0.5209 | TRUSTED
#     Client 8 | CKA=0.5291 | TRUSTED
#     Client 1 | CKA=0.6289 | FILTERED
#     Client 2 | CKA=0.5856 | FILTERED
#     Client 4 | CKA=0.5727 | FILTERED
#     Client 6 | CKA=0.6545 | FILTERED
#     Client 9 | CKA=0.6283 | FILTERED
#   [FedCC] Round 1 — 5/10 clients trusted
#   [FedCC] Round 1 — Acc: 0.1973 | Loss: 2.1801
#
#   [FedCC] Round 2 — CKA scores per client:
#     Client 0: 0.6936
#     Client 1: 0.7476
#     Client 2: 0.7335
#     Client 3: 0.7024
#     Client 4: 0.7009
#     Client 5: 0.6302
#     Client 6: 0.7559
#     Client 7: 0.7372
#     Client 8: 0.6997
#     Client 9: 0.7485
#   [FedCC] Cluster sizes: 5 (label 0) | 5 (label 1)  →  trusted = label 0
#     Client 0 | CKA=0.6936 | TRUSTED
#     Client 3 | CKA=0.7024 | TRUSTED
#     Client 4 | CKA=0.7009 | TRUSTED
#     Client 5 | CKA=0.6302 | TRUSTED
#     Client 8 | CKA=0.6997 | TRUSTED
#     Client 1 | CKA=0.7476 | FILTERED
#     Client 2 | CKA=0.7335 | FILTERED
#     Client 6 | CKA=0.7559 | FILTERED
#     Client 7 | CKA=0.7372 | FILTERED
#     Client 9 | CKA=0.7485 | FILTERED
#   [FedCC] Round 2 — 5/10 clients trusted
#   [FedCC] Round 2 — Acc: 0.3526 | Loss: 1.7727
#
#   [FedCC] Round 3 — CKA scores per client:
#     Client 0: 0.8557
#     Client 1: 0.8804
#     Client 2: 0.8242
#     Client 3: 0.8330
#     Client 4: 0.8900
#     Client 5: 0.8045
#     Client 6: 0.8715
#     Client 7: 0.8404
#     Client 8: 0.8533
#     Client 9: 0.8636
#   [FedCC] Cluster sizes: 4 (label 0) | 6 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.8557 | TRUSTED
#     Client 1 | CKA=0.8804 | TRUSTED
#     Client 4 | CKA=0.8900 | TRUSTED
#     Client 6 | CKA=0.8715 | TRUSTED
#     Client 8 | CKA=0.8533 | TRUSTED
#     Client 9 | CKA=0.8636 | TRUSTED
#     Client 2 | CKA=0.8242 | FILTERED
#     Client 3 | CKA=0.8330 | FILTERED
#     Client 5 | CKA=0.8045 | FILTERED
#     Client 7 | CKA=0.8404 | FILTERED
#   [FedCC] Round 3 — 6/10 clients trusted
#   [FedCC] Round 3 — Acc: 0.4211 | Loss: 1.5742
#
#   [FedCC] Round 4 — CKA scores per client:
#     Client 0: 0.9079
#     Client 1: 0.9302
#     Client 2: 0.9247
#     Client 3: 0.8993
#     Client 4: 0.9405
#     Client 5: 0.7891
#     Client 6: 0.9266
#     Client 7: 0.9131
#     Client 8: 0.9131
#     Client 9: 0.9341
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9079 | TRUSTED
#     Client 1 | CKA=0.9302 | TRUSTED
#     Client 2 | CKA=0.9247 | TRUSTED
#     Client 3 | CKA=0.8993 | TRUSTED
#     Client 4 | CKA=0.9405 | TRUSTED
#     Client 6 | CKA=0.9266 | TRUSTED
#     Client 7 | CKA=0.9131 | TRUSTED
#     Client 8 | CKA=0.9131 | TRUSTED
#     Client 9 | CKA=0.9341 | TRUSTED
#     Client 5 | CKA=0.7891 | FILTERED
#   [FedCC] Round 4 — 9/10 clients trusted
#   [FedCC] Round 4 — Acc: 0.4595 | Loss: 1.4572
#
#   [FedCC] Round 5 — CKA scores per client:
#     Client 0: 0.9186
#     Client 1: 0.9617
#     Client 2: 0.9536
#     Client 3: 0.9434
#     Client 4: 0.9561
#     Client 5: 0.8511
#     Client 6: 0.9428
#     Client 7: 0.9299
#     Client 8: 0.9403
#     Client 9: 0.9575
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9186 | TRUSTED
#     Client 1 | CKA=0.9617 | TRUSTED
#     Client 2 | CKA=0.9536 | TRUSTED
#     Client 3 | CKA=0.9434 | TRUSTED
#     Client 4 | CKA=0.9561 | TRUSTED
#     Client 6 | CKA=0.9428 | TRUSTED
#     Client 7 | CKA=0.9299 | TRUSTED
#     Client 8 | CKA=0.9403 | TRUSTED
#     Client 9 | CKA=0.9575 | TRUSTED
#     Client 5 | CKA=0.8511 | FILTERED
#   [FedCC] Round 5 — 9/10 clients trusted
#   [FedCC] Round 5 — Acc: 0.4878 | Loss: 1.3871
#
#   [FedCC] Round 6 — CKA scores per client:
#     Client 0: 0.9375
#     Client 1: 0.9701
#     Client 2: 0.9664
#     Client 3: 0.9561
#     Client 4: 0.9634
#     Client 5: 0.8794
#     Client 6: 0.9632
#     Client 7: 0.9429
#     Client 8: 0.9581
#     Client 9: 0.9673
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9375 | TRUSTED
#     Client 1 | CKA=0.9701 | TRUSTED
#     Client 2 | CKA=0.9664 | TRUSTED
#     Client 3 | CKA=0.9561 | TRUSTED
#     Client 4 | CKA=0.9634 | TRUSTED
#     Client 6 | CKA=0.9632 | TRUSTED
#     Client 7 | CKA=0.9429 | TRUSTED
#     Client 8 | CKA=0.9581 | TRUSTED
#     Client 9 | CKA=0.9673 | TRUSTED
#     Client 5 | CKA=0.8794 | FILTERED
#   [FedCC] Round 6 — 9/10 clients trusted
#   [FedCC] Round 6 — Acc: 0.5140 | Loss: 1.3212
#
#   [FedCC] Round 7 — CKA scores per client:
#     Client 0: 0.9486
#     Client 1: 0.9767
#     Client 2: 0.9737
#     Client 3: 0.9679
#     Client 4: 0.9723
#     Client 5: 0.9068
#     Client 6: 0.9692
#     Client 7: 0.9632
#     Client 8: 0.9654
#     Client 9: 0.9758
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9486 | TRUSTED
#     Client 1 | CKA=0.9767 | TRUSTED
#     Client 2 | CKA=0.9737 | TRUSTED
#     Client 3 | CKA=0.9679 | TRUSTED
#     Client 4 | CKA=0.9723 | TRUSTED
#     Client 6 | CKA=0.9692 | TRUSTED
#     Client 7 | CKA=0.9632 | TRUSTED
#     Client 8 | CKA=0.9654 | TRUSTED
#     Client 9 | CKA=0.9758 | TRUSTED
#     Client 5 | CKA=0.9068 | FILTERED
#   [FedCC] Round 7 — 9/10 clients trusted
#   [FedCC] Round 7 — Acc: 0.5265 | Loss: 1.2791
#
#   [FedCC] Round 8 — CKA scores per client:
#     Client 0: 0.9600
#     Client 1: 0.9843
#     Client 2: 0.9824
#     Client 3: 0.9744
#     Client 4: 0.9778
#     Client 5: 0.9192
#     Client 6: 0.9768
#     Client 7: 0.9739
#     Client 8: 0.9737
#     Client 9: 0.9817
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9600 | TRUSTED
#     Client 1 | CKA=0.9843 | TRUSTED
#     Client 2 | CKA=0.9824 | TRUSTED
#     Client 3 | CKA=0.9744 | TRUSTED
#     Client 4 | CKA=0.9778 | TRUSTED
#     Client 6 | CKA=0.9768 | TRUSTED
#     Client 7 | CKA=0.9739 | TRUSTED
#     Client 8 | CKA=0.9737 | TRUSTED
#     Client 9 | CKA=0.9817 | TRUSTED
#     Client 5 | CKA=0.9192 | FILTERED
#   [FedCC] Round 8 — 9/10 clients trusted
#   [FedCC] Round 8 — Acc: 0.5448 | Loss: 1.2413
#
#   [FedCC] Round 9 — CKA scores per client:
#     Client 0: 0.9656
#     Client 1: 0.9867
#     Client 2: 0.9844
#     Client 3: 0.9808
#     Client 4: 0.9815
#     Client 5: 0.9371
#     Client 6: 0.9828
#     Client 7: 0.9789
#     Client 8: 0.9782
#     Client 9: 0.9830
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9656 | TRUSTED
#     Client 1 | CKA=0.9867 | TRUSTED
#     Client 2 | CKA=0.9844 | TRUSTED
#     Client 3 | CKA=0.9808 | TRUSTED
#     Client 4 | CKA=0.9815 | TRUSTED
#     Client 6 | CKA=0.9828 | TRUSTED
#     Client 7 | CKA=0.9789 | TRUSTED
#     Client 8 | CKA=0.9782 | TRUSTED
#     Client 9 | CKA=0.9830 | TRUSTED
#     Client 5 | CKA=0.9371 | FILTERED
#   [FedCC] Round 9 — 9/10 clients trusted
#   [FedCC] Round 9 — Acc: 0.5578 | Loss: 1.2080
#
#   [FedCC] Round 10 — CKA scores per client:
#     Client 0: 0.9727
#     Client 1: 0.9890
#     Client 2: 0.9877
#     Client 3: 0.9826
#     Client 4: 0.9854
#     Client 5: 0.9484
#     Client 6: 0.9857
#     Client 7: 0.9822
#     Client 8: 0.9824
#     Client 9: 0.9883
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9727 | TRUSTED
#     Client 1 | CKA=0.9890 | TRUSTED
#     Client 2 | CKA=0.9877 | TRUSTED
#     Client 3 | CKA=0.9826 | TRUSTED
#     Client 4 | CKA=0.9854 | TRUSTED
#     Client 6 | CKA=0.9857 | TRUSTED
#     Client 7 | CKA=0.9822 | TRUSTED
#     Client 8 | CKA=0.9824 | TRUSTED
#     Client 9 | CKA=0.9883 | TRUSTED
#     Client 5 | CKA=0.9484 | FILTERED
#   [FedCC] Round 10 — 9/10 clients trusted
#   [FedCC] Round 10 — Acc: 0.5750 | Loss: 1.1633
#
#   [FedCC] Round 11 — CKA scores per client:
#     Client 0: 0.9771
#     Client 1: 0.9895
#     Client 2: 0.9894
#     Client 3: 0.9862
#     Client 4: 0.9875
#     Client 5: 0.9528
#     Client 6: 0.9873
#     Client 7: 0.9854
#     Client 8: 0.9860
#     Client 9: 0.9894
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9771 | TRUSTED
#     Client 1 | CKA=0.9895 | TRUSTED
#     Client 2 | CKA=0.9894 | TRUSTED
#     Client 3 | CKA=0.9862 | TRUSTED
#     Client 4 | CKA=0.9875 | TRUSTED
#     Client 6 | CKA=0.9873 | TRUSTED
#     Client 7 | CKA=0.9854 | TRUSTED
#     Client 8 | CKA=0.9860 | TRUSTED
#     Client 9 | CKA=0.9894 | TRUSTED
#     Client 5 | CKA=0.9528 | FILTERED
#   [FedCC] Round 11 — 9/10 clients trusted
#   [FedCC] Round 11 — Acc: 0.5916 | Loss: 1.1252
#
#   [FedCC] Round 12 — CKA scores per client:
#     Client 0: 0.9803
#     Client 1: 0.9923
#     Client 2: 0.9909
#     Client 3: 0.9885
#     Client 4: 0.9877
#     Client 5: 0.9619
#     Client 6: 0.9901
#     Client 7: 0.9869
#     Client 8: 0.9873
#     Client 9: 0.9915
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9803 | TRUSTED
#     Client 1 | CKA=0.9923 | TRUSTED
#     Client 2 | CKA=0.9909 | TRUSTED
#     Client 3 | CKA=0.9885 | TRUSTED
#     Client 4 | CKA=0.9877 | TRUSTED
#     Client 6 | CKA=0.9901 | TRUSTED
#     Client 7 | CKA=0.9869 | TRUSTED
#     Client 8 | CKA=0.9873 | TRUSTED
#     Client 9 | CKA=0.9915 | TRUSTED
#     Client 5 | CKA=0.9619 | FILTERED
#   [FedCC] Round 12 — 9/10 clients trusted
#   [FedCC] Round 12 — Acc: 0.6003 | Loss: 1.0990
#
#   [FedCC] Round 13 — CKA scores per client:
#     Client 0: 0.9834
#     Client 1: 0.9929
#     Client 2: 0.9918
#     Client 3: 0.9900
#     Client 4: 0.9903
#     Client 5: 0.9635
#     Client 6: 0.9917
#     Client 7: 0.9896
#     Client 8: 0.9897
#     Client 9: 0.9926
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9834 | TRUSTED
#     Client 1 | CKA=0.9929 | TRUSTED
#     Client 2 | CKA=0.9918 | TRUSTED
#     Client 3 | CKA=0.9900 | TRUSTED
#     Client 4 | CKA=0.9903 | TRUSTED
#     Client 6 | CKA=0.9917 | TRUSTED
#     Client 7 | CKA=0.9896 | TRUSTED
#     Client 8 | CKA=0.9897 | TRUSTED
#     Client 9 | CKA=0.9926 | TRUSTED
#     Client 5 | CKA=0.9635 | FILTERED
#   [FedCC] Round 13 — 9/10 clients trusted
#   [FedCC] Round 13 — Acc: 0.6085 | Loss: 1.0712
#
#   [FedCC] Round 14 — CKA scores per client:
#     Client 0: 0.9855
#     Client 1: 0.9937
#     Client 2: 0.9936
#     Client 3: 0.9903
#     Client 4: 0.9920
#     Client 5: 0.9713
#     Client 6: 0.9919
#     Client 7: 0.9907
#     Client 8: 0.9915
#     Client 9: 0.9939
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9855 | TRUSTED
#     Client 1 | CKA=0.9937 | TRUSTED
#     Client 2 | CKA=0.9936 | TRUSTED
#     Client 3 | CKA=0.9903 | TRUSTED
#     Client 4 | CKA=0.9920 | TRUSTED
#     Client 6 | CKA=0.9919 | TRUSTED
#     Client 7 | CKA=0.9907 | TRUSTED
#     Client 8 | CKA=0.9915 | TRUSTED
#     Client 9 | CKA=0.9939 | TRUSTED
#     Client 5 | CKA=0.9713 | FILTERED
#   [FedCC] Round 14 — 9/10 clients trusted
#   [FedCC] Round 14 — Acc: 0.6201 | Loss: 1.0393
#
#   [FedCC] Round 15 — CKA scores per client:
#     Client 0: 0.9869
#     Client 1: 0.9949
#     Client 2: 0.9942
#     Client 3: 0.9922
#     Client 4: 0.9934
#     Client 5: 0.9763
#     Client 6: 0.9940
#     Client 7: 0.9925
#     Client 8: 0.9915
#     Client 9: 0.9946
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9869 | TRUSTED
#     Client 1 | CKA=0.9949 | TRUSTED
#     Client 2 | CKA=0.9942 | TRUSTED
#     Client 3 | CKA=0.9922 | TRUSTED
#     Client 4 | CKA=0.9934 | TRUSTED
#     Client 6 | CKA=0.9940 | TRUSTED
#     Client 7 | CKA=0.9925 | TRUSTED
#     Client 8 | CKA=0.9915 | TRUSTED
#     Client 9 | CKA=0.9946 | TRUSTED
#     Client 5 | CKA=0.9763 | FILTERED
#   [FedCC] Round 15 — 9/10 clients trusted
#   [FedCC] Round 15 — Acc: 0.6307 | Loss: 1.0173
#
#   [FedCC] Round 16 — CKA scores per client:
#     Client 0: 0.9891
#     Client 1: 0.9952
#     Client 2: 0.9952
#     Client 3: 0.9928
#     Client 4: 0.9939
#     Client 5: 0.9792
#     Client 6: 0.9943
#     Client 7: 0.9932
#     Client 8: 0.9934
#     Client 9: 0.9951
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9891 | TRUSTED
#     Client 1 | CKA=0.9952 | TRUSTED
#     Client 2 | CKA=0.9952 | TRUSTED
#     Client 3 | CKA=0.9928 | TRUSTED
#     Client 4 | CKA=0.9939 | TRUSTED
#     Client 6 | CKA=0.9943 | TRUSTED
#     Client 7 | CKA=0.9932 | TRUSTED
#     Client 8 | CKA=0.9934 | TRUSTED
#     Client 9 | CKA=0.9951 | TRUSTED
#     Client 5 | CKA=0.9792 | FILTERED
#   [FedCC] Round 16 — 9/10 clients trusted
#   [FedCC] Round 16 — Acc: 0.6409 | Loss: 0.9985
#
#   [FedCC] Round 17 — CKA scores per client:
#     Client 0: 0.9901
#     Client 1: 0.9959
#     Client 2: 0.9957
#     Client 3: 0.9925
#     Client 4: 0.9945
#     Client 5: 0.9812
#     Client 6: 0.9952
#     Client 7: 0.9944
#     Client 8: 0.9935
#     Client 9: 0.9955
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9901 | TRUSTED
#     Client 1 | CKA=0.9959 | TRUSTED
#     Client 2 | CKA=0.9957 | TRUSTED
#     Client 3 | CKA=0.9925 | TRUSTED
#     Client 4 | CKA=0.9945 | TRUSTED
#     Client 6 | CKA=0.9952 | TRUSTED
#     Client 7 | CKA=0.9944 | TRUSTED
#     Client 8 | CKA=0.9935 | TRUSTED
#     Client 9 | CKA=0.9955 | TRUSTED
#     Client 5 | CKA=0.9812 | FILTERED
#   [FedCC] Round 17 — 9/10 clients trusted
#   [FedCC] Round 17 — Acc: 0.6447 | Loss: 0.9829
#
#   [FedCC] Round 18 — CKA scores per client:
#     Client 0: 0.9911
#     Client 1: 0.9965
#     Client 2: 0.9956
#     Client 3: 0.9935
#     Client 4: 0.9951
#     Client 5: 0.9817
#     Client 6: 0.9958
#     Client 7: 0.9945
#     Client 8: 0.9943
#     Client 9: 0.9958
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9911 | TRUSTED
#     Client 1 | CKA=0.9965 | TRUSTED
#     Client 2 | CKA=0.9956 | TRUSTED
#     Client 3 | CKA=0.9935 | TRUSTED
#     Client 4 | CKA=0.9951 | TRUSTED
#     Client 6 | CKA=0.9958 | TRUSTED
#     Client 7 | CKA=0.9945 | TRUSTED
#     Client 8 | CKA=0.9943 | TRUSTED
#     Client 9 | CKA=0.9958 | TRUSTED
#     Client 5 | CKA=0.9817 | FILTERED
#   [FedCC] Round 18 — 9/10 clients trusted
#   [FedCC] Round 18 — Acc: 0.6540 | Loss: 0.9587
#
#   [FedCC] Round 19 — CKA scores per client:
#     Client 0: 0.9914
#     Client 1: 0.9964
#     Client 2: 0.9964
#     Client 3: 0.9944
#     Client 4: 0.9950
#     Client 5: 0.9850
#     Client 6: 0.9961
#     Client 7: 0.9954
#     Client 8: 0.9943
#     Client 9: 0.9965
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9914 | TRUSTED
#     Client 1 | CKA=0.9964 | TRUSTED
#     Client 2 | CKA=0.9964 | TRUSTED
#     Client 3 | CKA=0.9944 | TRUSTED
#     Client 4 | CKA=0.9950 | TRUSTED
#     Client 6 | CKA=0.9961 | TRUSTED
#     Client 7 | CKA=0.9954 | TRUSTED
#     Client 8 | CKA=0.9943 | TRUSTED
#     Client 9 | CKA=0.9965 | TRUSTED
#     Client 5 | CKA=0.9850 | FILTERED
#   [FedCC] Round 19 — 9/10 clients trusted
#   [FedCC] Round 19 — Acc: 0.6582 | Loss: 0.9436
#
#   [FedCC] Round 20 — CKA scores per client:
#     Client 0: 0.9929
#     Client 1: 0.9969
#     Client 2: 0.9966
#     Client 3: 0.9950
#     Client 4: 0.9957
#     Client 5: 0.9861
#     Client 6: 0.9966
#     Client 7: 0.9955
#     Client 8: 0.9949
#     Client 9: 0.9966
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9929 | TRUSTED
#     Client 1 | CKA=0.9969 | TRUSTED
#     Client 2 | CKA=0.9966 | TRUSTED
#     Client 3 | CKA=0.9950 | TRUSTED
#     Client 4 | CKA=0.9957 | TRUSTED
#     Client 6 | CKA=0.9966 | TRUSTED
#     Client 7 | CKA=0.9955 | TRUSTED
#     Client 8 | CKA=0.9949 | TRUSTED
#     Client 9 | CKA=0.9966 | TRUSTED
#     Client 5 | CKA=0.9861 | FILTERED
#   [FedCC] Round 20 — 9/10 clients trusted
#   [FedCC] Round 20 — Acc: 0.6670 | Loss: 0.9252
#
#   [FedCC] Round 21 — CKA scores per client:
#     Client 0: 0.9936
#     Client 1: 0.9972
#     Client 2: 0.9966
#     Client 3: 0.9954
#     Client 4: 0.9963
#     Client 5: 0.9873
#     Client 6: 0.9966
#     Client 7: 0.9961
#     Client 8: 0.9953
#     Client 9: 0.9970
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9936 | TRUSTED
#     Client 1 | CKA=0.9972 | TRUSTED
#     Client 2 | CKA=0.9966 | TRUSTED
#     Client 3 | CKA=0.9954 | TRUSTED
#     Client 4 | CKA=0.9963 | TRUSTED
#     Client 6 | CKA=0.9966 | TRUSTED
#     Client 7 | CKA=0.9961 | TRUSTED
#     Client 8 | CKA=0.9953 | TRUSTED
#     Client 9 | CKA=0.9970 | TRUSTED
#     Client 5 | CKA=0.9873 | FILTERED
#   [FedCC] Round 21 — 9/10 clients trusted
#   [FedCC] Round 21 — Acc: 0.6674 | Loss: 0.9174
#
#   [FedCC] Round 22 — CKA scores per client:
#     Client 0: 0.9931
#     Client 1: 0.9973
#     Client 2: 0.9973
#     Client 3: 0.9957
#     Client 4: 0.9965
#     Client 5: 0.9877
#     Client 6: 0.9972
#     Client 7: 0.9963
#     Client 8: 0.9955
#     Client 9: 0.9970
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9931 | TRUSTED
#     Client 1 | CKA=0.9973 | TRUSTED
#     Client 2 | CKA=0.9973 | TRUSTED
#     Client 3 | CKA=0.9957 | TRUSTED
#     Client 4 | CKA=0.9965 | TRUSTED
#     Client 6 | CKA=0.9972 | TRUSTED
#     Client 7 | CKA=0.9963 | TRUSTED
#     Client 8 | CKA=0.9955 | TRUSTED
#     Client 9 | CKA=0.9970 | TRUSTED
#     Client 5 | CKA=0.9877 | FILTERED
#   [FedCC] Round 22 — 9/10 clients trusted
#   [FedCC] Round 22 — Acc: 0.6692 | Loss: 0.9136
#
#   [FedCC] Round 23 — CKA scores per client:
#     Client 0: 0.9941
#     Client 1: 0.9975
#     Client 2: 0.9972
#     Client 3: 0.9957
#     Client 4: 0.9966
#     Client 5: 0.9887
#     Client 6: 0.9973
#     Client 7: 0.9967
#     Client 8: 0.9959
#     Client 9: 0.9974
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9941 | TRUSTED
#     Client 1 | CKA=0.9975 | TRUSTED
#     Client 2 | CKA=0.9972 | TRUSTED
#     Client 3 | CKA=0.9957 | TRUSTED
#     Client 4 | CKA=0.9966 | TRUSTED
#     Client 6 | CKA=0.9973 | TRUSTED
#     Client 7 | CKA=0.9967 | TRUSTED
#     Client 8 | CKA=0.9959 | TRUSTED
#     Client 9 | CKA=0.9974 | TRUSTED
#     Client 5 | CKA=0.9887 | FILTERED
#   [FedCC] Round 23 — 9/10 clients trusted
#   [FedCC] Round 23 — Acc: 0.6775 | Loss: 0.8976
#
#   [FedCC] Round 24 — CKA scores per client:
#     Client 0: 0.9948
#     Client 1: 0.9975
#     Client 2: 0.9974
#     Client 3: 0.9961
#     Client 4: 0.9967
#     Client 5: 0.9891
#     Client 6: 0.9971
#     Client 7: 0.9968
#     Client 8: 0.9964
#     Client 9: 0.9976
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9948 | TRUSTED
#     Client 1 | CKA=0.9975 | TRUSTED
#     Client 2 | CKA=0.9974 | TRUSTED
#     Client 3 | CKA=0.9961 | TRUSTED
#     Client 4 | CKA=0.9967 | TRUSTED
#     Client 6 | CKA=0.9971 | TRUSTED
#     Client 7 | CKA=0.9968 | TRUSTED
#     Client 8 | CKA=0.9964 | TRUSTED
#     Client 9 | CKA=0.9976 | TRUSTED
#     Client 5 | CKA=0.9891 | FILTERED
#   [FedCC] Round 24 — 9/10 clients trusted
#   [FedCC] Round 24 — Acc: 0.6788 | Loss: 0.8951
#
#   [FedCC] Round 25 — CKA scores per client:
#     Client 0: 0.9949
#     Client 1: 0.9980
#     Client 2: 0.9976
#     Client 3: 0.9964
#     Client 4: 0.9970
#     Client 5: 0.9909
#     Client 6: 0.9975
#     Client 7: 0.9970
#     Client 8: 0.9965
#     Client 9: 0.9978
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9949 | TRUSTED
#     Client 1 | CKA=0.9980 | TRUSTED
#     Client 2 | CKA=0.9976 | TRUSTED
#     Client 3 | CKA=0.9964 | TRUSTED
#     Client 4 | CKA=0.9970 | TRUSTED
#     Client 6 | CKA=0.9975 | TRUSTED
#     Client 7 | CKA=0.9970 | TRUSTED
#     Client 8 | CKA=0.9965 | TRUSTED
#     Client 9 | CKA=0.9978 | TRUSTED
#     Client 5 | CKA=0.9909 | FILTERED
#   [FedCC] Round 25 — 9/10 clients trusted
#   [FedCC] Round 25 — Acc: 0.6900 | Loss: 0.8805
#
#   [FedCC] Round 26 — CKA scores per client:
#     Client 0: 0.9956
#     Client 1: 0.9980
#     Client 2: 0.9979
#     Client 3: 0.9967
#     Client 4: 0.9971
#     Client 5: 0.9907
#     Client 6: 0.9978
#     Client 7: 0.9973
#     Client 8: 0.9965
#     Client 9: 0.9978
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9956 | TRUSTED
#     Client 1 | CKA=0.9980 | TRUSTED
#     Client 2 | CKA=0.9979 | TRUSTED
#     Client 3 | CKA=0.9967 | TRUSTED
#     Client 4 | CKA=0.9971 | TRUSTED
#     Client 6 | CKA=0.9978 | TRUSTED
#     Client 7 | CKA=0.9973 | TRUSTED
#     Client 8 | CKA=0.9965 | TRUSTED
#     Client 9 | CKA=0.9978 | TRUSTED
#     Client 5 | CKA=0.9907 | FILTERED
#   [FedCC] Round 26 — 9/10 clients trusted
#   [FedCC] Round 26 — Acc: 0.6900 | Loss: 0.8809
#
#   [FedCC] Round 27 — CKA scores per client:
#     Client 0: 0.9953
#     Client 1: 0.9979
#     Client 2: 0.9981
#     Client 3: 0.9969
#     Client 4: 0.9972
#     Client 5: 0.9918
#     Client 6: 0.9979
#     Client 7: 0.9973
#     Client 8: 0.9970
#     Client 9: 0.9979
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9953 | TRUSTED
#     Client 1 | CKA=0.9979 | TRUSTED
#     Client 2 | CKA=0.9981 | TRUSTED
#     Client 3 | CKA=0.9969 | TRUSTED
#     Client 4 | CKA=0.9972 | TRUSTED
#     Client 6 | CKA=0.9979 | TRUSTED
#     Client 7 | CKA=0.9973 | TRUSTED
#     Client 8 | CKA=0.9970 | TRUSTED
#     Client 9 | CKA=0.9979 | TRUSTED
#     Client 5 | CKA=0.9918 | FILTERED
#   [FedCC] Round 27 — 9/10 clients trusted
#   [FedCC] Round 27 — Acc: 0.6892 | Loss: 0.8775
#
#   [FedCC] Round 28 — CKA scores per client:
#     Client 0: 0.9958
#     Client 1: 0.9982
#     Client 2: 0.9983
#     Client 3: 0.9969
#     Client 4: 0.9974
#     Client 5: 0.9921
#     Client 6: 0.9980
#     Client 7: 0.9975
#     Client 8: 0.9970
#     Client 9: 0.9980
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9958 | TRUSTED
#     Client 1 | CKA=0.9982 | TRUSTED
#     Client 2 | CKA=0.9983 | TRUSTED
#     Client 3 | CKA=0.9969 | TRUSTED
#     Client 4 | CKA=0.9974 | TRUSTED
#     Client 6 | CKA=0.9980 | TRUSTED
#     Client 7 | CKA=0.9975 | TRUSTED
#     Client 8 | CKA=0.9970 | TRUSTED
#     Client 9 | CKA=0.9980 | TRUSTED
#     Client 5 | CKA=0.9921 | FILTERED
#   [FedCC] Round 28 — 9/10 clients trusted
#   [FedCC] Round 28 — Acc: 0.6925 | Loss: 0.8654
#
#   [FedCC] Round 29 — CKA scores per client:
#     Client 0: 0.9958
#     Client 1: 0.9983
#     Client 2: 0.9981
#     Client 3: 0.9970
#     Client 4: 0.9975
#     Client 5: 0.9920
#     Client 6: 0.9979
#     Client 7: 0.9977
#     Client 8: 0.9970
#     Client 9: 0.9982
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9958 | TRUSTED
#     Client 1 | CKA=0.9983 | TRUSTED
#     Client 2 | CKA=0.9981 | TRUSTED
#     Client 3 | CKA=0.9970 | TRUSTED
#     Client 4 | CKA=0.9975 | TRUSTED
#     Client 6 | CKA=0.9979 | TRUSTED
#     Client 7 | CKA=0.9977 | TRUSTED
#     Client 8 | CKA=0.9970 | TRUSTED
#     Client 9 | CKA=0.9982 | TRUSTED
#     Client 5 | CKA=0.9920 | FILTERED
#   [FedCC] Round 29 — 9/10 clients trusted
#   [FedCC] Round 29 — Acc: 0.6995 | Loss: 0.8648
#
#   [FedCC] Round 30 — CKA scores per client:
#     Client 0: 0.9961
#     Client 1: 0.9984
#     Client 2: 0.9984
#     Client 3: 0.9974
#     Client 4: 0.9977
#     Client 5: 0.9925
#     Client 6: 0.9982
#     Client 7: 0.9978
#     Client 8: 0.9975
#     Client 9: 0.9983
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9961 | TRUSTED
#     Client 1 | CKA=0.9984 | TRUSTED
#     Client 2 | CKA=0.9984 | TRUSTED
#     Client 3 | CKA=0.9974 | TRUSTED
#     Client 4 | CKA=0.9977 | TRUSTED
#     Client 6 | CKA=0.9982 | TRUSTED
#     Client 7 | CKA=0.9978 | TRUSTED
#     Client 8 | CKA=0.9975 | TRUSTED
#     Client 9 | CKA=0.9983 | TRUSTED
#     Client 5 | CKA=0.9925 | FILTERED
#   [FedCC] Round 30 — 9/10 clients trusted
#   [FedCC] Round 30 — Acc: 0.7025 | Loss: 0.8561
#
#   [FedCC] Round 31 — CKA scores per client:
#     Client 0: 0.9965
#     Client 1: 0.9985
#     Client 2: 0.9985
#     Client 3: 0.9975
#     Client 4: 0.9977
#     Client 5: 0.9937
#     Client 6: 0.9984
#     Client 7: 0.9977
#     Client 8: 0.9976
#     Client 9: 0.9984
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9965 | TRUSTED
#     Client 1 | CKA=0.9985 | TRUSTED
#     Client 2 | CKA=0.9985 | TRUSTED
#     Client 3 | CKA=0.9975 | TRUSTED
#     Client 4 | CKA=0.9977 | TRUSTED
#     Client 6 | CKA=0.9984 | TRUSTED
#     Client 7 | CKA=0.9977 | TRUSTED
#     Client 8 | CKA=0.9976 | TRUSTED
#     Client 9 | CKA=0.9984 | TRUSTED
#     Client 5 | CKA=0.9937 | FILTERED
#   [FedCC] Round 31 — 9/10 clients trusted
#   [FedCC] Round 31 — Acc: 0.7075 | Loss: 0.8586
#
#   [FedCC] Round 32 — CKA scores per client:
#     Client 0: 0.9966
#     Client 1: 0.9985
#     Client 2: 0.9986
#     Client 3: 0.9975
#     Client 4: 0.9980
#     Client 5: 0.9934
#     Client 6: 0.9985
#     Client 7: 0.9980
#     Client 8: 0.9975
#     Client 9: 0.9985
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9966 | TRUSTED
#     Client 1 | CKA=0.9985 | TRUSTED
#     Client 2 | CKA=0.9986 | TRUSTED
#     Client 3 | CKA=0.9975 | TRUSTED
#     Client 4 | CKA=0.9980 | TRUSTED
#     Client 6 | CKA=0.9985 | TRUSTED
#     Client 7 | CKA=0.9980 | TRUSTED
#     Client 8 | CKA=0.9975 | TRUSTED
#     Client 9 | CKA=0.9985 | TRUSTED
#     Client 5 | CKA=0.9934 | FILTERED
#   [FedCC] Round 32 — 9/10 clients trusted
#   [FedCC] Round 32 — Acc: 0.7082 | Loss: 0.8574
#
#   [FedCC] Round 33 — CKA scores per client:
#     Client 0: 0.9966
#     Client 1: 0.9985
#     Client 2: 0.9986
#     Client 3: 0.9977
#     Client 4: 0.9980
#     Client 5: 0.9937
#     Client 6: 0.9985
#     Client 7: 0.9979
#     Client 8: 0.9977
#     Client 9: 0.9985
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9966 | TRUSTED
#     Client 1 | CKA=0.9985 | TRUSTED
#     Client 2 | CKA=0.9986 | TRUSTED
#     Client 3 | CKA=0.9977 | TRUSTED
#     Client 4 | CKA=0.9980 | TRUSTED
#     Client 6 | CKA=0.9985 | TRUSTED
#     Client 7 | CKA=0.9979 | TRUSTED
#     Client 8 | CKA=0.9977 | TRUSTED
#     Client 9 | CKA=0.9985 | TRUSTED
#     Client 5 | CKA=0.9937 | FILTERED
#   [FedCC] Round 33 — 9/10 clients trusted
#   [FedCC] Round 33 — Acc: 0.7104 | Loss: 0.8537
#
#   [FedCC] Round 34 — CKA scores per client:
#     Client 0: 0.9969
#     Client 1: 0.9987
#     Client 2: 0.9986
#     Client 3: 0.9978
#     Client 4: 0.9981
#     Client 5: 0.9943
#     Client 6: 0.9985
#     Client 7: 0.9982
#     Client 8: 0.9979
#     Client 9: 0.9986
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9969 | TRUSTED
#     Client 1 | CKA=0.9987 | TRUSTED
#     Client 2 | CKA=0.9986 | TRUSTED
#     Client 3 | CKA=0.9978 | TRUSTED
#     Client 4 | CKA=0.9981 | TRUSTED
#     Client 6 | CKA=0.9985 | TRUSTED
#     Client 7 | CKA=0.9982 | TRUSTED
#     Client 8 | CKA=0.9979 | TRUSTED
#     Client 9 | CKA=0.9986 | TRUSTED
#     Client 5 | CKA=0.9943 | FILTERED
#   [FedCC] Round 34 — 9/10 clients trusted
#   [FedCC] Round 34 — Acc: 0.7140 | Loss: 0.8518
#
#   [FedCC] Round 35 — CKA scores per client:
#     Client 0: 0.9971
#     Client 1: 0.9987
#     Client 2: 0.9988
#     Client 3: 0.9980
#     Client 4: 0.9981
#     Client 5: 0.9946
#     Client 6: 0.9986
#     Client 7: 0.9982
#     Client 8: 0.9978
#     Client 9: 0.9986
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9971 | TRUSTED
#     Client 1 | CKA=0.9987 | TRUSTED
#     Client 2 | CKA=0.9988 | TRUSTED
#     Client 3 | CKA=0.9980 | TRUSTED
#     Client 4 | CKA=0.9981 | TRUSTED
#     Client 6 | CKA=0.9986 | TRUSTED
#     Client 7 | CKA=0.9982 | TRUSTED
#     Client 8 | CKA=0.9978 | TRUSTED
#     Client 9 | CKA=0.9986 | TRUSTED
#     Client 5 | CKA=0.9946 | FILTERED
#   [FedCC] Round 35 — 9/10 clients trusted
#   [FedCC] Round 35 — Acc: 0.7076 | Loss: 0.8596
#
#   [FedCC] Round 36 — CKA scores per client:
#     Client 0: 0.9971
#     Client 1: 0.9987
#     Client 2: 0.9988
#     Client 3: 0.9979
#     Client 4: 0.9982
#     Client 5: 0.9946
#     Client 6: 0.9988
#     Client 7: 0.9982
#     Client 8: 0.9979
#     Client 9: 0.9986
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9971 | TRUSTED
#     Client 1 | CKA=0.9987 | TRUSTED
#     Client 2 | CKA=0.9988 | TRUSTED
#     Client 3 | CKA=0.9979 | TRUSTED
#     Client 4 | CKA=0.9982 | TRUSTED
#     Client 6 | CKA=0.9988 | TRUSTED
#     Client 7 | CKA=0.9982 | TRUSTED
#     Client 8 | CKA=0.9979 | TRUSTED
#     Client 9 | CKA=0.9986 | TRUSTED
#     Client 5 | CKA=0.9946 | FILTERED
#   [FedCC] Round 36 — 9/10 clients trusted
#   [FedCC] Round 36 — Acc: 0.7162 | Loss: 0.8528
#
#   [FedCC] Round 37 — CKA scores per client:
#     Client 0: 0.9973
#     Client 1: 0.9988
#     Client 2: 0.9989
#     Client 3: 0.9981
#     Client 4: 0.9983
#     Client 5: 0.9953
#     Client 6: 0.9987
#     Client 7: 0.9983
#     Client 8: 0.9981
#     Client 9: 0.9987
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9973 | TRUSTED
#     Client 1 | CKA=0.9988 | TRUSTED
#     Client 2 | CKA=0.9989 | TRUSTED
#     Client 3 | CKA=0.9981 | TRUSTED
#     Client 4 | CKA=0.9983 | TRUSTED
#     Client 6 | CKA=0.9987 | TRUSTED
#     Client 7 | CKA=0.9983 | TRUSTED
#     Client 8 | CKA=0.9981 | TRUSTED
#     Client 9 | CKA=0.9987 | TRUSTED
#     Client 5 | CKA=0.9953 | FILTERED
#   [FedCC] Round 37 — 9/10 clients trusted
#   [FedCC] Round 37 — Acc: 0.7186 | Loss: 0.8534
#
#   [FedCC] Round 38 — CKA scores per client:
#     Client 0: 0.9974
#     Client 1: 0.9989
#     Client 2: 0.9989
#     Client 3: 0.9981
#     Client 4: 0.9984
#     Client 5: 0.9956
#     Client 6: 0.9988
#     Client 7: 0.9985
#     Client 8: 0.9982
#     Client 9: 0.9988
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9974 | TRUSTED
#     Client 1 | CKA=0.9989 | TRUSTED
#     Client 2 | CKA=0.9989 | TRUSTED
#     Client 3 | CKA=0.9981 | TRUSTED
#     Client 4 | CKA=0.9984 | TRUSTED
#     Client 6 | CKA=0.9988 | TRUSTED
#     Client 7 | CKA=0.9985 | TRUSTED
#     Client 8 | CKA=0.9982 | TRUSTED
#     Client 9 | CKA=0.9988 | TRUSTED
#     Client 5 | CKA=0.9956 | FILTERED
#   [FedCC] Round 38 — 9/10 clients trusted
#   [FedCC] Round 38 — Acc: 0.7166 | Loss: 0.8552
#
#   [FedCC] Round 39 — CKA scores per client:
#     Client 0: 0.9976
#     Client 1: 0.9989
#     Client 2: 0.9989
#     Client 3: 0.9983
#     Client 4: 0.9985
#     Client 5: 0.9955
#     Client 6: 0.9988
#     Client 7: 0.9986
#     Client 8: 0.9982
#     Client 9: 0.9988
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9976 | TRUSTED
#     Client 1 | CKA=0.9989 | TRUSTED
#     Client 2 | CKA=0.9989 | TRUSTED
#     Client 3 | CKA=0.9983 | TRUSTED
#     Client 4 | CKA=0.9985 | TRUSTED
#     Client 6 | CKA=0.9988 | TRUSTED
#     Client 7 | CKA=0.9986 | TRUSTED
#     Client 8 | CKA=0.9982 | TRUSTED
#     Client 9 | CKA=0.9988 | TRUSTED
#     Client 5 | CKA=0.9955 | FILTERED
#   [FedCC] Round 39 — 9/10 clients trusted
#   [FedCC] Round 39 — Acc: 0.7200 | Loss: 0.8501
#
#   [FedCC] Round 40 — CKA scores per client:
#     Client 0: 0.9977
#     Client 1: 0.9989
#     Client 2: 0.9990
#     Client 3: 0.9982
#     Client 4: 0.9986
#     Client 5: 0.9958
#     Client 6: 0.9989
#     Client 7: 0.9986
#     Client 8: 0.9983
#     Client 9: 0.9988
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9977 | TRUSTED
#     Client 1 | CKA=0.9989 | TRUSTED
#     Client 2 | CKA=0.9990 | TRUSTED
#     Client 3 | CKA=0.9982 | TRUSTED
#     Client 4 | CKA=0.9986 | TRUSTED
#     Client 6 | CKA=0.9989 | TRUSTED
#     Client 7 | CKA=0.9986 | TRUSTED
#     Client 8 | CKA=0.9983 | TRUSTED
#     Client 9 | CKA=0.9988 | TRUSTED
#     Client 5 | CKA=0.9958 | FILTERED
#   [FedCC] Round 40 — 9/10 clients trusted
#   [FedCC] Round 40 — Acc: 0.7180 | Loss: 0.8732
#
#   [FedCC] Round 41 — CKA scores per client:
#     Client 0: 0.9978
#     Client 1: 0.9990
#     Client 2: 0.9991
#     Client 3: 0.9983
#     Client 4: 0.9985
#     Client 5: 0.9961
#     Client 6: 0.9989
#     Client 7: 0.9986
#     Client 8: 0.9984
#     Client 9: 0.9989
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9978 | TRUSTED
#     Client 1 | CKA=0.9990 | TRUSTED
#     Client 2 | CKA=0.9991 | TRUSTED
#     Client 3 | CKA=0.9983 | TRUSTED
#     Client 4 | CKA=0.9985 | TRUSTED
#     Client 6 | CKA=0.9989 | TRUSTED
#     Client 7 | CKA=0.9986 | TRUSTED
#     Client 8 | CKA=0.9984 | TRUSTED
#     Client 9 | CKA=0.9989 | TRUSTED
#     Client 5 | CKA=0.9961 | FILTERED
#   [FedCC] Round 41 — 9/10 clients trusted
#   [FedCC] Round 41 — Acc: 0.7182 | Loss: 0.8834
#
#   [FedCC] Round 42 — CKA scores per client:
#     Client 0: 0.9978
#     Client 1: 0.9990
#     Client 2: 0.9990
#     Client 3: 0.9985
#     Client 4: 0.9986
#     Client 5: 0.9960
#     Client 6: 0.9990
#     Client 7: 0.9986
#     Client 8: 0.9984
#     Client 9: 0.9989
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9978 | TRUSTED
#     Client 1 | CKA=0.9990 | TRUSTED
#     Client 2 | CKA=0.9990 | TRUSTED
#     Client 3 | CKA=0.9985 | TRUSTED
#     Client 4 | CKA=0.9986 | TRUSTED
#     Client 6 | CKA=0.9990 | TRUSTED
#     Client 7 | CKA=0.9986 | TRUSTED
#     Client 8 | CKA=0.9984 | TRUSTED
#     Client 9 | CKA=0.9989 | TRUSTED
#     Client 5 | CKA=0.9960 | FILTERED
#   [FedCC] Round 42 — 9/10 clients trusted
#   [FedCC] Round 42 — Acc: 0.7196 | Loss: 0.8781
#
#   [FedCC] Round 43 — CKA scores per client:
#     Client 0: 0.9979
#     Client 1: 0.9990
#     Client 2: 0.9991
#     Client 3: 0.9985
#     Client 4: 0.9986
#     Client 5: 0.9963
#     Client 6: 0.9990
#     Client 7: 0.9986
#     Client 8: 0.9985
#     Client 9: 0.9990
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9979 | TRUSTED
#     Client 1 | CKA=0.9990 | TRUSTED
#     Client 2 | CKA=0.9991 | TRUSTED
#     Client 3 | CKA=0.9985 | TRUSTED
#     Client 4 | CKA=0.9986 | TRUSTED
#     Client 6 | CKA=0.9990 | TRUSTED
#     Client 7 | CKA=0.9986 | TRUSTED
#     Client 8 | CKA=0.9985 | TRUSTED
#     Client 9 | CKA=0.9990 | TRUSTED
#     Client 5 | CKA=0.9963 | FILTERED
#   [FedCC] Round 43 — 9/10 clients trusted
#   [FedCC] Round 43 — Acc: 0.7216 | Loss: 0.8753
#
#   [FedCC] Round 44 — CKA scores per client:
#     Client 0: 0.9980
#     Client 1: 0.9991
#     Client 2: 0.9992
#     Client 3: 0.9985
#     Client 4: 0.9987
#     Client 5: 0.9962
#     Client 6: 0.9991
#     Client 7: 0.9988
#     Client 8: 0.9986
#     Client 9: 0.9990
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9980 | TRUSTED
#     Client 1 | CKA=0.9991 | TRUSTED
#     Client 2 | CKA=0.9992 | TRUSTED
#     Client 3 | CKA=0.9985 | TRUSTED
#     Client 4 | CKA=0.9987 | TRUSTED
#     Client 6 | CKA=0.9991 | TRUSTED
#     Client 7 | CKA=0.9988 | TRUSTED
#     Client 8 | CKA=0.9986 | TRUSTED
#     Client 9 | CKA=0.9990 | TRUSTED
#     Client 5 | CKA=0.9962 | FILTERED
#   [FedCC] Round 44 — 9/10 clients trusted
#   [FedCC] Round 44 — Acc: 0.7164 | Loss: 0.8969
#
#   [FedCC] Round 45 — CKA scores per client:
#     Client 0: 0.9982
#     Client 1: 0.9991
#     Client 2: 0.9991
#     Client 3: 0.9987
#     Client 4: 0.9987
#     Client 5: 0.9962
#     Client 6: 0.9990
#     Client 7: 0.9988
#     Client 8: 0.9986
#     Client 9: 0.9991
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9982 | TRUSTED
#     Client 1 | CKA=0.9991 | TRUSTED
#     Client 2 | CKA=0.9991 | TRUSTED
#     Client 3 | CKA=0.9987 | TRUSTED
#     Client 4 | CKA=0.9987 | TRUSTED
#     Client 6 | CKA=0.9990 | TRUSTED
#     Client 7 | CKA=0.9988 | TRUSTED
#     Client 8 | CKA=0.9986 | TRUSTED
#     Client 9 | CKA=0.9991 | TRUSTED
#     Client 5 | CKA=0.9962 | FILTERED
#   [FedCC] Round 45 — 9/10 clients trusted
#   [FedCC] Round 45 — Acc: 0.7218 | Loss: 0.9024
#
#   [FedCC] Round 46 — CKA scores per client:
#     Client 0: 0.9981
#     Client 1: 0.9992
#     Client 2: 0.9992
#     Client 3: 0.9987
#     Client 4: 0.9988
#     Client 5: 0.9966
#     Client 6: 0.9991
#     Client 7: 0.9989
#     Client 8: 0.9988
#     Client 9: 0.9991
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9981 | TRUSTED
#     Client 1 | CKA=0.9992 | TRUSTED
#     Client 2 | CKA=0.9992 | TRUSTED
#     Client 3 | CKA=0.9987 | TRUSTED
#     Client 4 | CKA=0.9988 | TRUSTED
#     Client 6 | CKA=0.9991 | TRUSTED
#     Client 7 | CKA=0.9989 | TRUSTED
#     Client 8 | CKA=0.9988 | TRUSTED
#     Client 9 | CKA=0.9991 | TRUSTED
#     Client 5 | CKA=0.9966 | FILTERED
#   [FedCC] Round 46 — 9/10 clients trusted
#   [FedCC] Round 46 — Acc: 0.7203 | Loss: 0.8958
#
#   [FedCC] Round 47 — CKA scores per client:
#     Client 0: 0.9982
#     Client 1: 0.9992
#     Client 2: 0.9992
#     Client 3: 0.9987
#     Client 4: 0.9988
#     Client 5: 0.9967
#     Client 6: 0.9991
#     Client 7: 0.9989
#     Client 8: 0.9986
#     Client 9: 0.9991
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9982 | TRUSTED
#     Client 1 | CKA=0.9992 | TRUSTED
#     Client 2 | CKA=0.9992 | TRUSTED
#     Client 3 | CKA=0.9987 | TRUSTED
#     Client 4 | CKA=0.9988 | TRUSTED
#     Client 6 | CKA=0.9991 | TRUSTED
#     Client 7 | CKA=0.9989 | TRUSTED
#     Client 8 | CKA=0.9986 | TRUSTED
#     Client 9 | CKA=0.9991 | TRUSTED
#     Client 5 | CKA=0.9967 | FILTERED
#   [FedCC] Round 47 — 9/10 clients trusted
#   [FedCC] Round 47 — Acc: 0.7207 | Loss: 0.9061
#
#   [FedCC] Round 48 — CKA scores per client:
#     Client 0: 0.9982
#     Client 1: 0.9993
#     Client 2: 0.9992
#     Client 3: 0.9987
#     Client 4: 0.9989
#     Client 5: 0.9967
#     Client 6: 0.9991
#     Client 7: 0.9989
#     Client 8: 0.9987
#     Client 9: 0.9991
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9982 | TRUSTED
#     Client 1 | CKA=0.9993 | TRUSTED
#     Client 2 | CKA=0.9992 | TRUSTED
#     Client 3 | CKA=0.9987 | TRUSTED
#     Client 4 | CKA=0.9989 | TRUSTED
#     Client 6 | CKA=0.9991 | TRUSTED
#     Client 7 | CKA=0.9989 | TRUSTED
#     Client 8 | CKA=0.9987 | TRUSTED
#     Client 9 | CKA=0.9991 | TRUSTED
#     Client 5 | CKA=0.9967 | FILTERED
#   [FedCC] Round 48 — 9/10 clients trusted
#   [FedCC] Round 48 — Acc: 0.7220 | Loss: 0.9262
#
#   [FedCC] Round 49 — CKA scores per client:
#     Client 0: 0.9982
#     Client 1: 0.9992
#     Client 2: 0.9993
#     Client 3: 0.9988
#     Client 4: 0.9989
#     Client 5: 0.9966
#     Client 6: 0.9991
#     Client 7: 0.9989
#     Client 8: 0.9988
#     Client 9: 0.9991
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9982 | TRUSTED
#     Client 1 | CKA=0.9992 | TRUSTED
#     Client 2 | CKA=0.9993 | TRUSTED
#     Client 3 | CKA=0.9988 | TRUSTED
#     Client 4 | CKA=0.9989 | TRUSTED
#     Client 6 | CKA=0.9991 | TRUSTED
#     Client 7 | CKA=0.9989 | TRUSTED
#     Client 8 | CKA=0.9988 | TRUSTED
#     Client 9 | CKA=0.9991 | TRUSTED
#     Client 5 | CKA=0.9966 | FILTERED
#   [FedCC] Round 49 — 9/10 clients trusted
#   [FedCC] Round 49 — Acc: 0.7242 | Loss: 0.9231
#
#   [FedCC] Round 50 — CKA scores per client:
#     Client 0: 0.9983
#     Client 1: 0.9992
#     Client 2: 0.9993
#     Client 3: 0.9989
#     Client 4: 0.9989
#     Client 5: 0.9970
#     Client 6: 0.9993
#     Client 7: 0.9989
#     Client 8: 0.9988
#     Client 9: 0.9992
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9983 | TRUSTED
#     Client 1 | CKA=0.9992 | TRUSTED
#     Client 2 | CKA=0.9993 | TRUSTED
#     Client 3 | CKA=0.9989 | TRUSTED
#     Client 4 | CKA=0.9989 | TRUSTED
#     Client 6 | CKA=0.9993 | TRUSTED
#     Client 7 | CKA=0.9989 | TRUSTED
#     Client 8 | CKA=0.9988 | TRUSTED
#     Client 9 | CKA=0.9992 | TRUSTED
#     Client 5 | CKA=0.9970 | FILTERED
#   [FedCC] Round 50 — 9/10 clients trusted
#   [FedCC] Round 50 — Acc: 0.7215 | Loss: 0.9263
#
# ============================================================
#  Test 2  - Attack | Strategy: FedAvg | Mode: attack
# ============================================================
#   [Client 0]: 7505 samples
#   [Client 1]: 3766 samples
#   [Client 1] Top-2 classes for GAN: ['cat', 'frog'] [3, 6]
#   [Client 2]: 2587 samples
#   [Client 2] Top-2 classes for GAN: ['cat', 'frog'] [3, 6]
#   [Client 3]: 5760 samples
#   [Client 4]: 5691 samples
#   [Client 5]: 7494 samples
#   [Client 5] Top-2 classes for GAN: ['cat', 'frog'] [3, 6]
#   [Client 6]: 2628 samples
#   [Client 7]: 4624 samples
#   [Client 8]: 5996 samples
#   [Client 9]: 3949 samples
#   [FedAvg] Round 1 — Acc: 0.2430 | Loss: 2.1770
#   [FedAvg] Round 2 — Acc: 0.4000 | Loss: 1.7469
#   [FedAvg] Round 3 — Acc: 0.4308 | Loss: 1.6044
#   [FedAvg] Round 4 — Acc: 0.4373 | Loss: 1.5402
#   [FedAvg] Round 5 — Acc: 0.4269 | Loss: 1.5298
#   [FedAvg] Round 6 — Acc: 0.4292 | Loss: 1.5252
#   [FedAvg] Round 7 — Acc: 0.4753 | Loss: 1.4049
#   [FedAvg] Round 8 — Acc: 0.4824 | Loss: 1.3910
#   [FedAvg] Round 9 — Acc: 0.5025 | Loss: 1.3437
#   [FedAvg] Round 10 — Acc: 0.4968 | Loss: 1.3742
#   [FedAvg] Round 11 — Acc: 0.5454 | Loss: 1.2261
#   [FedAvg] Round 12 — Acc: 0.5418 | Loss: 1.2431
#   [FedAvg] Round 13 — Acc: 0.5526 | Loss: 1.2163
#   [FedAvg] Round 14 — Acc: 0.5625 | Loss: 1.2128
#   [FedAvg] Round 15 — Acc: 0.5778 | Loss: 1.1445
#   [FedAvg] Round 16 — Acc: 0.5934 | Loss: 1.1211
#   [FedAvg] Round 17 — Acc: 0.6054 | Loss: 1.0774
#   [FedAvg] Round 18 — Acc: 0.5858 | Loss: 1.1427
#   [FedAvg] Round 19 — Acc: 0.6123 | Loss: 1.0565
#   [FedAvg] Round 20 — Acc: 0.6266 | Loss: 1.0332
#   [FedAvg] Round 21 — Acc: 0.6204 | Loss: 1.0525
#   [FedAvg] Round 22 — Acc: 0.6380 | Loss: 1.0020
#   [FedAvg] Round 23 — Acc: 0.6453 | Loss: 0.9775
#   [FedAvg] Round 24 — Acc: 0.6483 | Loss: 0.9664
#   [FedAvg] Round 25 — Acc: 0.6412 | Loss: 0.9990
#   [FedAvg] Round 26 — Acc: 0.6542 | Loss: 0.9565
#   [FedAvg] Round 27 — Acc: 0.6550 | Loss: 0.9684
#   [FedAvg] Round 28 — Acc: 0.6472 | Loss: 1.0002
#   [FedAvg] Round 29 — Acc: 0.6589 | Loss: 0.9593
#   [FedAvg] Round 30 — Acc: 0.6668 | Loss: 0.9411
#   [FedAvg] Round 31 — Acc: 0.6734 | Loss: 0.9261
#   [FedAvg] Round 32 — Acc: 0.6760 | Loss: 0.9260
#   [FedAvg] Round 33 — Acc: 0.6651 | Loss: 0.9467
#   [FedAvg] Round 34 — Acc: 0.6589 | Loss: 0.9843
#   [FedAvg] Round 35 — Acc: 0.6823 | Loss: 0.9245
#   [FedAvg] Round 36 — Acc: 0.6838 | Loss: 0.9255
#   [FedAvg] Round 37 — Acc: 0.6882 | Loss: 0.9156
#   [FedAvg] Round 38 — Acc: 0.6718 | Loss: 0.9601
#   [FedAvg] Round 39 — Acc: 0.6924 | Loss: 0.9052
#   [FedAvg] Round 40 — Acc: 0.6930 | Loss: 0.9444
#   [FedAvg] Round 41 — Acc: 0.6742 | Loss: 0.9943
#   [FedAvg] Round 42 — Acc: 0.6906 | Loss: 0.9479
#   [FedAvg] Round 43 — Acc: 0.6932 | Loss: 0.9399
#   [FedAvg] Round 44 — Acc: 0.6978 | Loss: 0.9326
#   [FedAvg] Round 45 — Acc: 0.6881 | Loss: 0.9660
#   [FedAvg] Round 46 — Acc: 0.6916 | Loss: 0.9633
#   [FedAvg] Round 47 — Acc: 0.6939 | Loss: 0.9671
#   [FedAvg] Round 48 — Acc: 0.7012 | Loss: 0.9416
#   [FedAvg] Round 49 — Acc: 0.7061 | Loss: 0.9189
#   [FedAvg] Round 50 — Acc: 0.7020 | Loss: 0.9426
#
# ============================================================
#  Test 2  - Attack | Strategy: FedCC | Mode: attack
# ============================================================
#   [Client 0]: 7505 samples
#   [Client 1]: 3766 samples
#   [Client 1] Top-2 classes for GAN: ['cat', 'frog'] [3, 6]
#   [Client 2]: 2587 samples
#   [Client 2] Top-2 classes for GAN: ['cat', 'frog'] [3, 6]
#   [Client 3]: 5760 samples
#   [Client 4]: 5691 samples
#   [Client 5]: 7494 samples
#   [Client 5] Top-2 classes for GAN: ['cat', 'frog'] [3, 6]
#   [Client 6]: 2628 samples
#   [Client 7]: 4624 samples
#   [Client 8]: 5996 samples
#   [Client 9]: 3949 samples
#
#   [FedCC] Round 1 — CKA scores per client:
#     Client 0: 0.4543
#     Client 1: 0.5199
#     Client 2: 0.4863
#     Client 3: 0.5144
#     Client 4: 0.5678
#     Client 5: 0.5041
#     Client 6: 0.6418
#     Client 7: 0.5553
#     Client 8: 0.5108
#     Client 9: 0.6353
#   [FedCC] Cluster sizes: 4 (label 0) | 6 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.4543 | TRUSTED
#     Client 1 | CKA=0.5199 | TRUSTED
#     Client 2 | CKA=0.4863 | TRUSTED
#     Client 3 | CKA=0.5144 | TRUSTED
#     Client 5 | CKA=0.5041 | TRUSTED
#     Client 8 | CKA=0.5108 | TRUSTED
#     Client 4 | CKA=0.5678 | FILTERED
#     Client 6 | CKA=0.6418 | FILTERED
#     Client 7 | CKA=0.5553 | FILTERED
#     Client 9 | CKA=0.6353 | FILTERED
#   [FedCC] Round 1 — 6/10 clients trusted
#   [FedCC] Round 1 — Acc: 0.1156 | Loss: 2.2531
#
#   [FedCC] Round 2 — CKA scores per client:
#     Client 0: 0.5553
#     Client 1: 0.7862
#     Client 2: 0.8600
#     Client 3: 0.7305
#     Client 4: 0.6347
#     Client 5: 0.6713
#     Client 6: 0.7037
#     Client 7: 0.6197
#     Client 8: 0.5990
#     Client 9: 0.7382
#   [FedCC] Cluster sizes: 5 (label 0) | 5 (label 1)  →  trusted = label 0
#     Client 0 | CKA=0.5553 | TRUSTED
#     Client 4 | CKA=0.6347 | TRUSTED
#     Client 5 | CKA=0.6713 | TRUSTED
#     Client 7 | CKA=0.6197 | TRUSTED
#     Client 8 | CKA=0.5990 | TRUSTED
#     Client 1 | CKA=0.7862 | FILTERED
#     Client 2 | CKA=0.8600 | FILTERED
#     Client 3 | CKA=0.7305 | FILTERED
#     Client 6 | CKA=0.7037 | FILTERED
#     Client 9 | CKA=0.7382 | FILTERED
#   [FedCC] Round 2 — 5/10 clients trusted
#   [FedCC] Round 2 — Acc: 0.3376 | Loss: 1.8545
#
#   [FedCC] Round 3 — CKA scores per client:
#     Client 0: 0.7989
#     Client 1: 0.7986
#     Client 2: 0.8264
#     Client 3: 0.8127
#     Client 4: 0.8712
#     Client 5: 0.8078
#     Client 6: 0.8398
#     Client 7: 0.8685
#     Client 8: 0.8400
#     Client 9: 0.8538
#   [FedCC] Cluster sizes: 5 (label 0) | 5 (label 1)  →  trusted = label 0
#     Client 0 | CKA=0.7989 | TRUSTED
#     Client 1 | CKA=0.7986 | TRUSTED
#     Client 2 | CKA=0.8264 | TRUSTED
#     Client 3 | CKA=0.8127 | TRUSTED
# ...
#     Client 7 | CKA=0.9977 | TRUSTED
#     Client 8 | CKA=0.9972 | TRUSTED
#     Client 9 | CKA=0.9983 | TRUSTED
#     Client 0 | CKA=0.9955 | FILTERED
#     Client 1 | CKA=0.9962 | FILTERED
#     Client 2 | CKA=0.9957 | FILTERED
#     Client 5 | CKA=0.9953 | FILTERED
#   [FedCC] Round 30 — 6/10 clients trusted
#   [FedCC] Round 30 — Acc: 0.6427 | Loss: 0.9957
#
#   [FedCC] Round 31 — CKA scores per client:
#     Client 0: 0.9959
#     Client 1: 0.9946
#     Client 2: 0.9972
#     Client 3: 0.9977
#     Client 4: 0.9979
#     Client 5: 0.9939
#     Client 6: 0.9984
#     Client 7: 0.9979
#     Client 8: 0.9975
#     Client 9: 0.9983
#   [FedCC] Cluster sizes: 3 (label 0) | 7 (label 1)  →  trusted = label 1
#     Client 2 | CKA=0.9972 | TRUSTED
#     Client 3 | CKA=0.9977 | TRUSTED
#     Client 4 | CKA=0.9979 | TRUSTED
#     Client 6 | CKA=0.9984 | TRUSTED
#     Client 7 | CKA=0.9979 | TRUSTED
#     Client 8 | CKA=0.9975 | TRUSTED
#     Client 9 | CKA=0.9983 | TRUSTED
#     Client 0 | CKA=0.9959 | FILTERED
#     Client 1 | CKA=0.9946 | FILTERED
#     Client 5 | CKA=0.9939 | FILTERED
#   [FedCC] Round 31 — 7/10 clients trusted
#   [FedCC] Round 31 — Acc: 0.6199 | Loss: 1.0601
#
#   [FedCC] Round 32 — CKA scores per client:
#     Client 0: 0.9956
#     Client 1: 0.9937
#     Client 2: 0.9979
#     Client 3: 0.9978
#     Client 4: 0.9978
#     Client 5: 0.9961
#     Client 6: 0.9986
#     Client 7: 0.9978
#     Client 8: 0.9974
#     Client 9: 0.9987
#   [FedCC] Cluster sizes: 3 (label 0) | 7 (label 1)  →  trusted = label 1
#     Client 2 | CKA=0.9979 | TRUSTED
#     Client 3 | CKA=0.9978 | TRUSTED
#     Client 4 | CKA=0.9978 | TRUSTED
#     Client 6 | CKA=0.9986 | TRUSTED
#     Client 7 | CKA=0.9978 | TRUSTED
#     Client 8 | CKA=0.9974 | TRUSTED
#     Client 9 | CKA=0.9987 | TRUSTED
#     Client 0 | CKA=0.9956 | FILTERED
#     Client 1 | CKA=0.9937 | FILTERED
#     Client 5 | CKA=0.9961 | FILTERED
#   [FedCC] Round 32 — 7/10 clients trusted
#   [FedCC] Round 32 — Acc: 0.6356 | Loss: 1.0030
#
#   [FedCC] Round 33 — CKA scores per client:
#     Client 0: 0.9963
#     Client 1: 0.9980
#     Client 2: 0.9978
#     Client 3: 0.9978
#     Client 4: 0.9981
#     Client 5: 0.9962
#     Client 6: 0.9985
#     Client 7: 0.9983
#     Client 8: 0.9976
#     Client 9: 0.9987
#   [FedCC] Cluster sizes: 2 (label 0) | 8 (label 1)  →  trusted = label 1
#     Client 1 | CKA=0.9980 | TRUSTED
#     Client 2 | CKA=0.9978 | TRUSTED
#     Client 3 | CKA=0.9978 | TRUSTED
#     Client 4 | CKA=0.9981 | TRUSTED
#     Client 6 | CKA=0.9985 | TRUSTED
#     Client 7 | CKA=0.9983 | TRUSTED
#     Client 8 | CKA=0.9976 | TRUSTED
#     Client 9 | CKA=0.9987 | TRUSTED
#     Client 0 | CKA=0.9963 | FILTERED
#     Client 5 | CKA=0.9962 | FILTERED
#   [FedCC] Round 33 — 8/10 clients trusted
#   [FedCC] Round 33 — Acc: 0.6217 | Loss: 1.0547
#
#   [FedCC] Round 34 — CKA scores per client:
#     Client 0: 0.9965
#     Client 1: 0.9959
#     Client 2: 0.9982
#     Client 3: 0.9978
#     Client 4: 0.9981
#     Client 5: 0.9966
#     Client 6: 0.9986
#     Client 7: 0.9981
#     Client 8: 0.9975
#     Client 9: 0.9987
#   [FedCC] Cluster sizes: 3 (label 0) | 7 (label 1)  →  trusted = label 1
#     Client 2 | CKA=0.9982 | TRUSTED
#     Client 3 | CKA=0.9978 | TRUSTED
#     Client 4 | CKA=0.9981 | TRUSTED
#     Client 6 | CKA=0.9986 | TRUSTED
#     Client 7 | CKA=0.9981 | TRUSTED
#     Client 8 | CKA=0.9975 | TRUSTED
#     Client 9 | CKA=0.9987 | TRUSTED
#     Client 0 | CKA=0.9965 | FILTERED
#     Client 1 | CKA=0.9959 | FILTERED
#     Client 5 | CKA=0.9966 | FILTERED
#   [FedCC] Round 34 — 7/10 clients trusted
#   [FedCC] Round 34 — Acc: 0.6329 | Loss: 1.0213
#
#   [FedCC] Round 35 — CKA scores per client:
#     Client 0: 0.9965
#     Client 1: 0.9974
#     Client 2: 0.9965
#     Client 3: 0.9981
#     Client 4: 0.9983
#     Client 5: 0.9962
#     Client 6: 0.9987
#     Client 7: 0.9984
#     Client 8: 0.9979
#     Client 9: 0.9988
#   [FedCC] Cluster sizes: 3 (label 0) | 7 (label 1)  →  trusted = label 1
#     Client 1 | CKA=0.9974 | TRUSTED
#     Client 3 | CKA=0.9981 | TRUSTED
#     Client 4 | CKA=0.9983 | TRUSTED
#     Client 6 | CKA=0.9987 | TRUSTED
#     Client 7 | CKA=0.9984 | TRUSTED
#     Client 8 | CKA=0.9979 | TRUSTED
#     Client 9 | CKA=0.9988 | TRUSTED
#     Client 0 | CKA=0.9965 | FILTERED
#     Client 2 | CKA=0.9965 | FILTERED
#     Client 5 | CKA=0.9962 | FILTERED
#   [FedCC] Round 35 — 7/10 clients trusted
#   [FedCC] Round 35 — Acc: 0.6412 | Loss: 1.0030
#
#   [FedCC] Round 36 — CKA scores per client:
#     Client 0: 0.9969
#     Client 1: 0.9960
#     Client 2: 0.9962
#     Client 3: 0.9981
#     Client 4: 0.9984
#     Client 5: 0.9966
#     Client 6: 0.9989
#     Client 7: 0.9985
#     Client 8: 0.9980
#     Client 9: 0.9989
#   [FedCC] Cluster sizes: 4 (label 0) | 6 (label 1)  →  trusted = label 1
#     Client 3 | CKA=0.9981 | TRUSTED
#     Client 4 | CKA=0.9984 | TRUSTED
#     Client 6 | CKA=0.9989 | TRUSTED
#     Client 7 | CKA=0.9985 | TRUSTED
#     Client 8 | CKA=0.9980 | TRUSTED
#     Client 9 | CKA=0.9989 | TRUSTED
#     Client 0 | CKA=0.9969 | FILTERED
#     Client 1 | CKA=0.9960 | FILTERED
#     Client 2 | CKA=0.9962 | FILTERED
#     Client 5 | CKA=0.9966 | FILTERED
#   [FedCC] Round 36 — 6/10 clients trusted
#   [FedCC] Round 36 — Acc: 0.6601 | Loss: 0.9601
#
#   [FedCC] Round 37 — CKA scores per client:
#     Client 0: 0.9973
#     Client 1: 0.9981
#     Client 2: 0.9971
#     Client 3: 0.9983
#     Client 4: 0.9986
#     Client 5: 0.9951
#     Client 6: 0.9990
#     Client 7: 0.9985
#     Client 8: 0.9983
#     Client 9: 0.9990
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9973 | TRUSTED
#     Client 1 | CKA=0.9981 | TRUSTED
#     Client 2 | CKA=0.9971 | TRUSTED
#     Client 3 | CKA=0.9983 | TRUSTED
#     Client 4 | CKA=0.9986 | TRUSTED
#     Client 6 | CKA=0.9990 | TRUSTED
#     Client 7 | CKA=0.9985 | TRUSTED
#     Client 8 | CKA=0.9983 | TRUSTED
#     Client 9 | CKA=0.9990 | TRUSTED
#     Client 5 | CKA=0.9951 | FILTERED
#   [FedCC] Round 37 — 9/10 clients trusted
#   [FedCC] Round 37 — Acc: 0.6403 | Loss: 1.0160
#
#   [FedCC] Round 38 — CKA scores per client:
#     Client 0: 0.9973
#     Client 1: 0.9973
#     Client 2: 0.9979
#     Client 3: 0.9983
#     Client 4: 0.9985
#     Client 5: 0.9954
#     Client 6: 0.9989
#     Client 7: 0.9987
#     Client 8: 0.9983
#     Client 9: 0.9990
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9973 | TRUSTED
#     Client 1 | CKA=0.9973 | TRUSTED
#     Client 2 | CKA=0.9979 | TRUSTED
#     Client 3 | CKA=0.9983 | TRUSTED
#     Client 4 | CKA=0.9985 | TRUSTED
#     Client 6 | CKA=0.9989 | TRUSTED
#     Client 7 | CKA=0.9987 | TRUSTED
#     Client 8 | CKA=0.9983 | TRUSTED
#     Client 9 | CKA=0.9990 | TRUSTED
#     Client 5 | CKA=0.9954 | FILTERED
#   [FedCC] Round 38 — 9/10 clients trusted
#   [FedCC] Round 38 — Acc: 0.6411 | Loss: 1.0087
#
#   [FedCC] Round 39 — CKA scores per client:
#     Client 0: 0.9973
#     Client 1: 0.9980
#     Client 2: 0.9981
#     Client 3: 0.9984
#     Client 4: 0.9985
#     Client 5: 0.9958
#     Client 6: 0.9990
#     Client 7: 0.9987
#     Client 8: 0.9983
#     Client 9: 0.9990
#   [FedCC] Cluster sizes: 2 (label 0) | 8 (label 1)  →  trusted = label 1
#     Client 1 | CKA=0.9980 | TRUSTED
#     Client 2 | CKA=0.9981 | TRUSTED
#     Client 3 | CKA=0.9984 | TRUSTED
#     Client 4 | CKA=0.9985 | TRUSTED
#     Client 6 | CKA=0.9990 | TRUSTED
#     Client 7 | CKA=0.9987 | TRUSTED
#     Client 8 | CKA=0.9983 | TRUSTED
#     Client 9 | CKA=0.9990 | TRUSTED
#     Client 0 | CKA=0.9973 | FILTERED
#     Client 5 | CKA=0.9958 | FILTERED
#   [FedCC] Round 39 — 8/10 clients trusted
#   [FedCC] Round 39 — Acc: 0.6325 | Loss: 1.0465
#
#   [FedCC] Round 40 — CKA scores per client:
#     Client 0: 0.9974
#     Client 1: 0.9979
#     Client 2: 0.9985
#     Client 3: 0.9985
#     Client 4: 0.9986
#     Client 5: 0.9968
#     Client 6: 0.9990
#     Client 7: 0.9987
#     Client 8: 0.9983
#     Client 9: 0.9990
#   [FedCC] Cluster sizes: 3 (label 0) | 7 (label 1)  →  trusted = label 1
#     Client 2 | CKA=0.9985 | TRUSTED
#     Client 3 | CKA=0.9985 | TRUSTED
#     Client 4 | CKA=0.9986 | TRUSTED
#     Client 6 | CKA=0.9990 | TRUSTED
#     Client 7 | CKA=0.9987 | TRUSTED
#     Client 8 | CKA=0.9983 | TRUSTED
#     Client 9 | CKA=0.9990 | TRUSTED
#     Client 0 | CKA=0.9974 | FILTERED
#     Client 1 | CKA=0.9979 | FILTERED
#     Client 5 | CKA=0.9968 | FILTERED
#   [FedCC] Round 40 — 7/10 clients trusted
#   [FedCC] Round 40 — Acc: 0.6556 | Loss: 0.9886
#
#   [FedCC] Round 41 — CKA scores per client:
#     Client 0: 0.9976
#     Client 1: 0.9973
#     Client 2: 0.9974
#     Client 3: 0.9986
#     Client 4: 0.9986
#     Client 5: 0.9970
#     Client 6: 0.9991
#     Client 7: 0.9986
#     Client 8: 0.9984
#     Client 9: 0.9991
#   [FedCC] Cluster sizes: 4 (label 0) | 6 (label 1)  →  trusted = label 1
#     Client 3 | CKA=0.9986 | TRUSTED
#     Client 4 | CKA=0.9986 | TRUSTED
#     Client 6 | CKA=0.9991 | TRUSTED
#     Client 7 | CKA=0.9986 | TRUSTED
#     Client 8 | CKA=0.9984 | TRUSTED
#     Client 9 | CKA=0.9991 | TRUSTED
#     Client 0 | CKA=0.9976 | FILTERED
#     Client 1 | CKA=0.9973 | FILTERED
#     Client 2 | CKA=0.9974 | FILTERED
#     Client 5 | CKA=0.9970 | FILTERED
#   [FedCC] Round 41 — 6/10 clients trusted
#   [FedCC] Round 41 — Acc: 0.6600 | Loss: 0.9673
#
#   [FedCC] Round 42 — CKA scores per client:
#     Client 0: 0.9977
#     Client 1: 0.9971
#     Client 2: 0.9980
#     Client 3: 0.9986
#     Client 4: 0.9990
#     Client 5: 0.9975
#     Client 6: 0.9991
#     Client 7: 0.9990
#     Client 8: 0.9987
#     Client 9: 0.9992
#   [FedCC] Cluster sizes: 4 (label 0) | 6 (label 1)  →  trusted = label 1
#     Client 3 | CKA=0.9986 | TRUSTED
#     Client 4 | CKA=0.9990 | TRUSTED
#     Client 6 | CKA=0.9991 | TRUSTED
#     Client 7 | CKA=0.9990 | TRUSTED
#     Client 8 | CKA=0.9987 | TRUSTED
#     Client 9 | CKA=0.9992 | TRUSTED
#     Client 0 | CKA=0.9977 | FILTERED
#     Client 1 | CKA=0.9971 | FILTERED
#     Client 2 | CKA=0.9980 | FILTERED
#     Client 5 | CKA=0.9975 | FILTERED
#   [FedCC] Round 42 — 6/10 clients trusted
#   [FedCC] Round 42 — Acc: 0.6640 | Loss: 0.9605
#
#   [FedCC] Round 43 — CKA scores per client:
#     Client 0: 0.9980
#     Client 1: 0.9970
#     Client 2: 0.9981
#     Client 3: 0.9987
#     Client 4: 0.9990
#     Client 5: 0.9971
#     Client 6: 0.9992
#     Client 7: 0.9989
#     Client 8: 0.9988
#     Client 9: 0.9993
#   [FedCC] Cluster sizes: 4 (label 0) | 6 (label 1)  →  trusted = label 1
#     Client 3 | CKA=0.9987 | TRUSTED
#     Client 4 | CKA=0.9990 | TRUSTED
#     Client 6 | CKA=0.9992 | TRUSTED
#     Client 7 | CKA=0.9989 | TRUSTED
#     Client 8 | CKA=0.9988 | TRUSTED
#     Client 9 | CKA=0.9993 | TRUSTED
#     Client 0 | CKA=0.9980 | FILTERED
#     Client 1 | CKA=0.9970 | FILTERED
#     Client 2 | CKA=0.9981 | FILTERED
#     Client 5 | CKA=0.9971 | FILTERED
#   [FedCC] Round 43 — 6/10 clients trusted
#   [FedCC] Round 43 — Acc: 0.6683 | Loss: 0.9595
#
#   [FedCC] Round 44 — CKA scores per client:
#     Client 0: 0.9983
#     Client 1: 0.9982
#     Client 2: 0.9986
#     Client 3: 0.9988
#     Client 4: 0.9990
#     Client 5: 0.9976
#     Client 6: 0.9993
#     Client 7: 0.9990
#     Client 8: 0.9988
#     Client 9: 0.9993
#   [FedCC] Cluster sizes: 3 (label 0) | 7 (label 1)  →  trusted = label 1
#     Client 2 | CKA=0.9986 | TRUSTED
#     Client 3 | CKA=0.9988 | TRUSTED
#     Client 4 | CKA=0.9990 | TRUSTED
#     Client 6 | CKA=0.9993 | TRUSTED
#     Client 7 | CKA=0.9990 | TRUSTED
#     Client 8 | CKA=0.9988 | TRUSTED
#     Client 9 | CKA=0.9993 | TRUSTED
#     Client 0 | CKA=0.9983 | FILTERED
#     Client 1 | CKA=0.9982 | FILTERED
#     Client 5 | CKA=0.9976 | FILTERED
#   [FedCC] Round 44 — 7/10 clients trusted
#   [FedCC] Round 44 — Acc: 0.6544 | Loss: 1.0051
#
#   [FedCC] Round 45 — CKA scores per client:
#     Client 0: 0.9981
#     Client 1: 0.9984
#     Client 2: 0.9985
#     Client 3: 0.9990
#     Client 4: 0.9991
#     Client 5: 0.9982
#     Client 6: 0.9993
#     Client 7: 0.9990
#     Client 8: 0.9989
#     Client 9: 0.9993
#   [FedCC] Cluster sizes: 4 (label 0) | 6 (label 1)  →  trusted = label 1
#     Client 3 | CKA=0.9990 | TRUSTED
#     Client 4 | CKA=0.9991 | TRUSTED
#     Client 6 | CKA=0.9993 | TRUSTED
#     Client 7 | CKA=0.9990 | TRUSTED
#     Client 8 | CKA=0.9989 | TRUSTED
#     Client 9 | CKA=0.9993 | TRUSTED
#     Client 0 | CKA=0.9981 | FILTERED
#     Client 1 | CKA=0.9984 | FILTERED
#     Client 2 | CKA=0.9985 | FILTERED
#     Client 5 | CKA=0.9982 | FILTERED
#   [FedCC] Round 45 — 6/10 clients trusted
#   [FedCC] Round 45 — Acc: 0.6705 | Loss: 0.9620
#
#   [FedCC] Round 46 — CKA scores per client:
#     Client 0: 0.9983
#     Client 1: 0.9986
#     Client 2: 0.9987
#     Client 3: 0.9990
#     Client 4: 0.9992
#     Client 5: 0.9977
#     Client 6: 0.9993
#     Client 7: 0.9991
#     Client 8: 0.9989
#     Client 9: 0.9994
#   [FedCC] Cluster sizes: 3 (label 0) | 7 (label 1)  →  trusted = label 1
#     Client 2 | CKA=0.9987 | TRUSTED
#     Client 3 | CKA=0.9990 | TRUSTED
#     Client 4 | CKA=0.9992 | TRUSTED
#     Client 6 | CKA=0.9993 | TRUSTED
#     Client 7 | CKA=0.9991 | TRUSTED
#     Client 8 | CKA=0.9989 | TRUSTED
#     Client 9 | CKA=0.9994 | TRUSTED
#     Client 0 | CKA=0.9983 | FILTERED
#     Client 1 | CKA=0.9986 | FILTERED
#     Client 5 | CKA=0.9977 | FILTERED
#   [FedCC] Round 46 — 7/10 clients trusted
#   [FedCC] Round 46 — Acc: 0.6507 | Loss: 1.0485
#
#   [FedCC] Round 47 — CKA scores per client:
#     Client 0: 0.9981
#     Client 1: 0.9984
#     Client 2: 0.9988
#     Client 3: 0.9990
#     Client 4: 0.9991
#     Client 5: 0.9984
#     Client 6: 0.9994
#     Client 7: 0.9991
#     Client 8: 0.9990
#     Client 9: 0.9994
#   [FedCC] Cluster sizes: 3 (label 0) | 7 (label 1)  →  trusted = label 1
#     Client 2 | CKA=0.9988 | TRUSTED
#     Client 3 | CKA=0.9990 | TRUSTED
#     Client 4 | CKA=0.9991 | TRUSTED
#     Client 6 | CKA=0.9994 | TRUSTED
#     Client 7 | CKA=0.9991 | TRUSTED
#     Client 8 | CKA=0.9990 | TRUSTED
#     Client 9 | CKA=0.9994 | TRUSTED
#     Client 0 | CKA=0.9981 | FILTERED
#     Client 1 | CKA=0.9984 | FILTERED
#     Client 5 | CKA=0.9984 | FILTERED
#   [FedCC] Round 47 — 7/10 clients trusted
#   [FedCC] Round 47 — Acc: 0.6581 | Loss: 1.0067
#
#   [FedCC] Round 48 — CKA scores per client:
#     Client 0: 0.9983
#     Client 1: 0.9981
#     Client 2: 0.9986
#     Client 3: 0.9990
#     Client 4: 0.9991
#     Client 5: 0.9958
#     Client 6: 0.9994
#     Client 7: 0.9991
#     Client 8: 0.9990
#     Client 9: 0.9994
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9983 | TRUSTED
#     Client 1 | CKA=0.9981 | TRUSTED
#     Client 2 | CKA=0.9986 | TRUSTED
#     Client 3 | CKA=0.9990 | TRUSTED
#     Client 4 | CKA=0.9991 | TRUSTED
#     Client 6 | CKA=0.9994 | TRUSTED
#     Client 7 | CKA=0.9991 | TRUSTED
#     Client 8 | CKA=0.9990 | TRUSTED
#     Client 9 | CKA=0.9994 | TRUSTED
#     Client 5 | CKA=0.9958 | FILTERED
#   [FedCC] Round 48 — 9/10 clients trusted
#   [FedCC] Round 48 — Acc: 0.6510 | Loss: 1.0274
#
#   [FedCC] Round 49 — CKA scores per client:
#     Client 0: 0.9983
#     Client 1: 0.9981
#     Client 2: 0.9980
#     Client 3: 0.9990
#     Client 4: 0.9991
#     Client 5: 0.9965
#     Client 6: 0.9994
#     Client 7: 0.9991
#     Client 8: 0.9990
#     Client 9: 0.9994
#   [FedCC] Cluster sizes: 1 (label 0) | 9 (label 1)  →  trusted = label 1
#     Client 0 | CKA=0.9983 | TRUSTED
#     Client 1 | CKA=0.9981 | TRUSTED
#     Client 2 | CKA=0.9980 | TRUSTED
#     Client 3 | CKA=0.9990 | TRUSTED
#     Client 4 | CKA=0.9991 | TRUSTED
#     Client 6 | CKA=0.9994 | TRUSTED
#     Client 7 | CKA=0.9991 | TRUSTED
#     Client 8 | CKA=0.9990 | TRUSTED
#     Client 9 | CKA=0.9994 | TRUSTED
#     Client 5 | CKA=0.9965 | FILTERED
#   [FedCC] Round 49 — 9/10 clients trusted
#   [FedCC] Round 49 — Acc: 0.6550 | Loss: 1.0204
#
#   [FedCC] Round 50 — CKA scores per client:
#     Client 0: 0.9985
#     Client 1: 0.9985
#     Client 2: 0.9984
#     Client 3: 0.9990
#     Client 4: 0.9991
#     Client 5: 0.9982
#     Client 6: 0.9994
#     Client 7: 0.9991
#     Client 8: 0.9990
#     Client 9: 0.9994
#   [FedCC] Cluster sizes: 4 (label 0) | 6 (label 1)  →  trusted = label 1
#     Client 3 | CKA=0.9990 | TRUSTED
#     Client 4 | CKA=0.9991 | TRUSTED
#     Client 6 | CKA=0.9994 | TRUSTED
#     Client 7 | CKA=0.9991 | TRUSTED
#     Client 8 | CKA=0.9990 | TRUSTED
#     Client 9 | CKA=0.9994 | TRUSTED
#     Client 0 | CKA=0.9985 | FILTERED
#     Client 1 | CKA=0.9985 | FILTERED
#     Client 2 | CKA=0.9984 | FILTERED
#     Client 5 | CKA=0.9982 | FILTERED
#   [FedCC] Round 50 — 6/10 clients trusted
#   [FedCC] Round 50 — Acc: 0.6719 | Loss: 0.9760
#
# All simulations complete!

# %% [markdown]
# ## Results Visualization

# %%
def plot_results(all_results: dict):
    test_names = list(all_results.keys())
    num_tests = len(test_names)

    fig, axes = plt.subplots(num_tests, 2, figsize=(14, 4 * num_tests))
    fig.suptitle('FedAvg vs FedCC — CIFAR-10 Federated Learning\nEvaluation across Data Heterogeneity & Attacks',
                 fontsize=16, fontweight='bold', y=1.02)

    colors = {'FedAvg': '#2196F3', 'FedCC': '#FF5722'}
    markers = {'FedAvg': 'o', 'FedCC': 's'}

    for row, test_name in enumerate(test_names):
        ax_acc = axes[row][0] if num_tests > 1 else axes[0]
        ax_loss = axes[row][1] if num_tests > 1 else axes[1]

        plot_data = {}

        for strategy_name, metrics in all_results[test_name].items():
            if not metrics:
                continue
            rounds = [m['round'] for m in metrics]
            accs = [m['accuracy'] for m in metrics]
            losses = [m['loss'] for m in metrics]

            plot_data[strategy_name] = (rounds, accs, losses)

            color = colors[strategy_name]
            marker = markers[strategy_name]
            final_acc = accs[-1] if accs else 0

            ax_acc.plot(rounds, accs, color=color, marker=marker,
                        label=f'{strategy_name} (final: {final_acc:.3f})',
                        linewidth=2.5, markersize=6)
            ax_loss.plot(rounds, losses, color=color, marker=marker,
                         label=strategy_name, linewidth=2.5, markersize=6)

        # A
        ax_acc.set_title(f'{test_name}: Accuracy', fontweight='bold', fontsize=12)
        ax_acc.set_xlabel('Round')
        ax_acc.set_ylabel('Accuracy')
        ax_acc.set_ylim(0, 1.0)
        ax_acc.legend(loc='lower right')
        ax_acc.grid(True, linestyle='--', alpha=0.6)

        ax_loss.set_title(f'{test_name}: Loss', fontweight='bold', fontsize=12)
        ax_loss.set_xlabel('Round')
        ax_loss.set_ylabel('Loss')
        ax_loss.legend(loc='upper right')
        ax_loss.grid(True, linestyle='--', alpha=0.6)

    plt.tight_layout()
    plt.show()

plot_results(all_results)

# %% [markdown]
# ## Plot Divergence

# %%
def plot_divergence(divergence_history, metric='l2'):
    test_names     = list(divergence_history.keys())
    strategy_names = ['FedAvg', 'FedCC']
    colors         = [f'C{i}' for i in range(NUM_CLIENTS)]

    fig, axes = plt.subplots(len(test_names), 2, figsize=(14, 4 * len(test_names)))
    if len(test_names) == 1:
        axes = [axes]

    for row, test_name in enumerate(test_names):
        for col, sname in enumerate(strategy_names):
            ax      = axes[row][col]
            div_log = divergence_history[test_name].get(sname, {})
            if not div_log:
                ax.set_visible(False)
                continue

            rounds   = sorted(div_log.keys())
            all_cids = sorted({cid for rd in div_log.values() for cid in rd})

            for cid in all_cids:
                vals = [div_log[r].get(cid, {}).get(metric, np.nan) for r in rounds]
                ax.plot(rounds, vals, marker='o', markersize=4,
                        label=f'Client {cid}', color=colors[cid])

            ylabel = {'l2': 'L2 ‖local − global‖',
                      'cosine': 'Cosine Distance'}[metric]

            ax.set_title(f'{test_name} | {sname} — {ylabel}', fontweight='bold')
            ax.set_xlabel('Round')
            ax.set_ylabel(ylabel)
            ax.legend(loc='upper right', fontsize=8)
            ax.grid(True, linestyle='--', alpha=0.5)

    plt.tight_layout()
    plt.show()

plot_divergence(divergence_history, metric='l2')
plot_divergence(divergence_history, metric='cosine')

# %% [markdown]
# ## Plot Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

def plot_confusion_matrices_over_rounds(snapshots):
    test_loader    = DataLoader(CIFAR10_TEST, batch_size=256, shuffle=False)
    strategy_names = ['FedAvg', 'FedCC']

    for test_name in snapshots:
        for sname in strategy_names:
            snap = snapshots[test_name].get(sname, {})
            if not snap:
                continue

            rounds = sorted(snap.keys())
            n_cols = len(rounds)
            fig, axes = plt.subplots(1, n_cols, figsize=(5 * n_cols, 5))
            if n_cols == 1:
                axes = [axes]

            fig.suptitle(f'{test_name} | {sname} — Confusion Matrix per Round',
                         fontweight='bold', fontsize=13)

            for ax, rnd in zip(axes, rounds):
                model = CifarCNN().to(DEVICE)
                set_parameters(model, snap[rnd])
                model.eval()

                all_preds, all_labels = [], []
                with torch.no_grad():
                    for images, labels in test_loader:
                        preds = model(images.to(DEVICE)).argmax(dim=1).cpu().numpy()
                        all_preds.extend(preds)
                        all_labels.extend(labels.numpy())

                cm      = confusion_matrix(all_labels, all_preds)
                cm_norm = cm.astype(float) / cm.sum(axis=1, keepdims=True)

                sns.heatmap(cm_norm, annot=True, fmt='.2f', ax=ax,
                            cmap='Blues', xticklabels=CLASSES, yticklabels=CLASSES,
                            linewidths=0.3, vmin=0, vmax=1, cbar=False)
                acc = np.diag(cm_norm).mean()
                ax.set_title(f'Round {rnd}\nacc={acc:.3f}', fontsize=10)
                ax.set_xlabel('Predicted')
                ax.set_ylabel('True' if rnd == rounds[0] else '')

            plt.tight_layout()
            plt.show()

plot_confusion_matrices_over_rounds(snapshots)

# %% [markdown]
# ## Summary Table

# %%
print(f'\n{"="*65}')
print(f'  FINAL RESULTS SUMMARY')
print(f'{"="*65}')
print(f'{"Test":<35} {"Strategy":<10} {"Final Acc":>10} {"Final Loss":>12}')
print(f'{"-"*65}')

for test_name, strategies in all_results.items():
    for strategy_name, metrics in strategies.items():
        if metrics:
            final = metrics[-1]
            print(f'{test_name:<35} {strategy_name:<10} '
                  f'{final["accuracy"]:>10.4f} {final["loss"]:>12.4f}')
        else:
            print(f'{test_name:<35} {strategy_name:<10} {"N/A":>10} {"N/A":>12}')

print(f'{"="*65}')
# Out:
# =================================================================
#   FINAL RESULTS SUMMARY
# =================================================================
# Test                                Strategy    Final Acc   Final Loss
# -----------------------------------------------------------------
# Test 1  - Non-iid                   FedAvg         0.7241       0.9690
# Test 1  - Non-iid                   FedCC          0.7215       0.9263
# Test 2  - Attack                    FedAvg         0.7020       0.9426
# Test 2  - Attack                    FedCC          0.6719       0.9760
# =================================================================
